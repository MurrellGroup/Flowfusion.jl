# %%
using Pkg
Pkg.activate(@__DIR__)
Pkg.instantiate()
using Revise

using Random
using Statistics
using Adapt
using Functors
using Flux
using Onion
using RandomFeatureMaps
using Zygote

Pkg.develop(path=joinpath(@__DIR__, ".."))
using Flowfusion
const FF = Flowfusion

include(joinpath(@__DIR__, "prob_model.jl"))
include(joinpath(@__DIR__, "helper_funcs.jl"))
# Out:
#   Activating project at `~/dev/Flowfusion.jl/editflow_code`
# Precompiling project...
#    2645.6 ms  ✓ Flowfusion
#   1 dependency successfully precompiled in 4 seconds. 470 already precompiled.
#   1 dependency precompiled but a different version is currently loaded. Restart julia to access the new version. Otherwise, loading dependents of this package may trigger further precompilation to work with the unexpected version.
#    Resolving package versions...
#   No Changes to `~/dev/Flowfusion.jl/editflow_code/Project.toml`
#   No Changes to `~/dev/Flowfusion.jl/editflow_code/Manifest.toml`
# WARNING: redefinition of constant Main.AA20. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant Main.TOK2ID_AA. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant Main.PM. This may fail, cause incorrect answers, or produce other errors.
# plot_len_dist (generic function with 1 method)

# %%
import CUDA

# Device helpers
const _gpu_enabled = try
    CUDA.has_cuda()
catch
    false
end

to_dev(x) = _gpu_enabled ? Adapt.adapt(CUDA.CuArray, x) : x
to_cpu(x) = _gpu_enabled ? Adapt.adapt(Array, x) : x
# move x to the same device type as y (Array or CuArray)
to_same_device(x, y) = (_gpu_enabled && (y isa CUDA.CuArray)) ? Adapt.adapt(CUDA.CuArray, x) : Adapt.adapt(Array, x)
# Out:
# to_same_device (generic function with 1 method)

# %%
# Minibatch builder (uses true PM)
function make_minibatch(B::Int, P::FF.EditFlow; rng=Random.default_rng())
    K = P.k
    x0s = Vector{FF.DiscreteState}(undef, B)
    x1s = Vector{FF.DiscreteState}(undef, B)
    for b in 1:B
        # x1 from true PM
        seq1 = sample(PM; rng=rng)
        @assert all(1 .<= seq1 .<= K)
        x1s[b] = FF.DiscreteState(K, seq1)
        # x0: uniform tokens with random length in 1:10 (no BOS in x0)
        L0 = rand(rng, 1:10)
        seq0 = rand(rng, 1:K, L0)
        x0s[b] = FF.DiscreteState(K, seq0)
    end
    ts = rand(rng, Float32, B)
    return x0s, x1s, ts
end
# Out:
# make_minibatch (generic function with 1 method)

# %%
# Model definition
struct EditFlowModel{L}
    layers::L
end
Flux.@layer EditFlowModel
#=
function EditFlowModel(; d=128, num_heads=8, nlayers=6, rff_dim=128, cond_dim=128, K::Int)
    embedding   = Flux.Embedding(K + 2 => d)
    time_embed  = Flux.Chain(RandomFourierFeatures(1 => rff_dim, 1.0f0), Dense(rff_dim => cond_dim))
    blocks      = [Onion.AdaTransformerBlock(d, cond_dim, num_heads) for _ in 1:nlayers]
    head_combined = Dense(d => 2K + 1, bias=false)
    rope        = RoPE(d ÷ num_heads, 4096)
    return EditFlowModel((; embedding, time_embed, blocks, head_combined, rope, K))
end
=#
function EditFlowModel(; d=128, num_heads=8, nlayers=6, rff_dim=128, cond_dim=128, K::Int)
    embedding   = Flux.Embedding(K + 2 => d)
    time_embed  = Flux.Chain(RandomFourierFeatures(1 => rff_dim, 1.0f0), Dense(rff_dim => cond_dim))
    blocks      = [Onion.AdaTransformerBlock(d, cond_dim, num_heads) for _ in 1:nlayers]
    ins_q = Dense(d => K, bias=false)
    sub_q = Dense(d => K, bias=false)
    ins_lambda = Dense(d => 1, bias=false)
    sub_lambda = Dense(d => 1, bias=false)
    del_lambda = Dense(d => 1, bias=false)
    rope        = RoPE(d ÷ num_heads, 4096)
    return EditFlowModel((; embedding, time_embed, blocks, ins_q, sub_q, ins_lambda, sub_lambda, del_lambda, rope, K))
end
# Out:
# EditFlowModel

# %%
# Forward pass
function (model::EditFlowModel)(t, Xt_ms)
    m = model.layers
    X = FF.tensor(Xt_ms)
    X = ndims(X) == 1 ? reshape(X, :, 1) : X
    L, B = size(X)

    pmask = Zygote.@ignore FF.getlmask(Xt_ms)
    Xp = X .+ 1
    #println("min/max X: ", minimum(X), " / ", maximum(X), "  pad=", P.padding_token, "  lat=", P.latent_token)
    if maximum(X) > P.padding_token
        error("X contains values greater than the padding token; illegal token values in input")
    end

    H = m.embedding(Xp)

    t = ndims(t) == 0 ? fill(Float32(t), B) : Float32.(t)
    cond = m.time_embed(reshape(t, 1, B))

    cond  = to_same_device(cond, H)
    pmask = Zygote.@ignore to_same_device(pmask, H)
    rope  = Zygote.@ignore to_same_device(m.rope[1:L], H)

    for blk in m.blocks
        H = blk(H; cond, rope, kpad_mask=pmask)
    end

    ins_head = m.ins_q(H)
    sub_head = m.sub_q(H)
    lambda_ins = m.ins_lambda(H)
    lambda_sub = m.sub_lambda(H)
    lambda_del = m.del_lambda(H)
    return (ins_head, sub_head, lambda_ins, lambda_sub, lambda_del)
end

# %%
# Forward pass
# function (model::EditFlowModel)(t, Xt_ms)
#     m = model.layers
#     X = FF.tensor(Xt_ms)
#     X = ndims(X) == 1 ? reshape(X, :, 1) : X
#     L, B = size(X)

#     pmask = Zygote.@ignore FF.getlmask(Xt_ms)
#     Xp = X .+ 1
#     #println("min/max X: ", minimum(X), " / ", maximum(X), "  pad=", P.padding_token, "  lat=", P.latent_token)
#     #@assert all((0 .<= X) .& (X .<= P.padding_token))
#     mX = Zygote.@ignore maximum(X)
#     nX = Zygote.@ignore minimum(X)
#     @assert (0 <= nX) && (mX <= P.padding_token)

    
#     H = m.embedding(Xp)

#     t = ndims(t) == 0 ? fill(Float32(t), B) : Float32.(t)
#     cond = m.time_embed(reshape(t, 1, B))

#     cond  = to_same_device(cond, H)
#     pmask = Zygote.@ignore to_same_device(pmask, H)
#     rope  = Zygote.@ignore to_same_device(m.rope[1:L], H)

#     for blk in m.blocks
#         H = blk(H; cond, rope, kpad_mask=pmask)
#     end
#     return m.head_combined(H)
# end

# %%
# Training (GPU if available)
function train_editflow!(P::FF.EditFlow,
                        model;
                        epochs::Int=1,
                        steps_per_epoch::Int=100,
                        batch_size::Int=64,
                        lr::Float32=1f-2,
                        seed::Int=42,
                        print_every::Int=25)

    rng = Random.MersenneTwister(seed)
    Random.seed!(seed)

    # Move model to device (GPU if available)
    model = Functors.fmap(to_dev, model)
    opt_state = Flux.setup(Flux.Adam(lr), model)

    for epoch in 1:epochs
        for step in 1:steps_per_epoch

            # 1) Minibatch Sampling
            x0s, x1s, ts = make_minibatch(batch_size, P; rng=rng)

            # 2) Align and batch
            Z0, Z1 = FF.align_and_batch(P, x0s, x1s)

            # 3) Interpolate
            Zt, Xt = FF.interpolate_Z_elementwise(P, Z0, Z1, ts)

            # 4) Prepend BOS
            bos = P.bos_token
            Zt = vcat(fill(bos, 1, batch_size), Zt)
            Xt = vcat(fill(bos, 1, batch_size), Xt)
            Z1 = vcat(fill(bos, 1, batch_size), Z1)
            
            # 5) Masks and multipliers
            transition_mask = FF.transition_mask_from_Xt(P, Xt)
            edit_multiplier = FF.remaining_edits(P, Zt, Z1, Xt)
            #@assert size(transition_mask) == size(edit_multiplier)

            # 6) Scheduler scaling
            den = 1f0 .- P.κ.(ts)
            den = max.(den, 1f-3)
            scheduler_scaling = P.dκ.(ts) ./ den

            # 7) Masked state
            lmask = Xt .!= P.padding_token
            cmask = trues(size(lmask))
            Xt_ms = FF.MaskedState(FF.DiscreteState(P.k, Xt), cmask, lmask)

            ts_d    = to_dev(ts)
            Xt_ms_d = to_dev(Xt_ms)
            Tmask_d = to_dev(transition_mask)
            Emult_d = to_dev(edit_multiplier)
            sched_d = to_dev(reshape(Float32.(scheduler_scaling), 1, 1, :))

            # 8) Forward + loss + update
            loss, grad = Flux.withgradient(model) do m
                M = m(ts_d, Xt_ms_d)
                l = FF.edit_loss(P, M, Tmask_d, Emult_d, sched_d; eps=1f-8)
                if isnan(l)
                    println("Maximum element of M: ", maximum(M))
                end
                l
            end
            Flux.update!(opt_state, model, grad[1])

            if step % print_every == 0
                @info "train" epoch step loss=Float32(loss)
            end
        end
    end

    return Functors.fmap(to_cpu, model)
end
# Out:
# train_editflow! (generic function with 1 method)

# %%
# Init process and model
K = PM.K
P = FF.EditFlow(K; bos_token=0, impl="positionwise_reparam")
model = EditFlowModel(; d=128, num_heads=8, nlayers=4, rff_dim=128, cond_dim=128, K=K)
nothing

# %%
model = train_editflow!(P, model; epochs=50, steps_per_epoch=150, batch_size=256, lr=1f-4)
# Out:
# ┌ Info: train
# │   epoch = 1
# │   step = 25
# └   loss = 25.972092f0
# ┌ Info: train
# │   epoch = 1
# │   step = 50
# └   loss = 24.547047f0
# ┌ Info: train
# │   epoch = 1
# │   step = 75
# └   loss = 26.814123f0
# ┌ Info: train
# │   epoch = 1
# │   step = 100
# └   loss = 24.86299f0
# ┌ Info: train
# │   epoch = 1
# │   step = 125
# └   loss = 23.428902f0
# ┌ Info: train
# │   epoch = 1
# │   step = 150
# └   loss = 25.44519f0
# ┌ Info: train
# │   epoch = 2
# │   step = 25
# └   loss = 26.755375f0
# ┌ Info: train
# │   epoch = 2
# │   step = 50
# └   loss = 24.63697f0
# ┌ Info: train
# │   epoch = 2
# │   step = 75
# └   loss = 25.66145f0
# ┌ Info: train
# │   epoch = 2
# │   step = 100
# └   loss = 26.980005f0
# ┌ Info: train
# │   epoch = 2
# │   step = 125
# └   loss = 24.676495f0
# ┌ Info: train
# │   epoch = 2
# │   step = 150
# └   loss = 21.823967f0
# ┌ Info: train
# │   epoch = 3
# │   step = 25
# └   loss = 25.604435f0
# ┌ Info: train
# │   epoch = 3
# │   step = 50
# └   loss = 26.628433f0
# ┌ Info: train
# │   epoch = 3
# │   step = 75
# └   loss = 24.269749f0
# ┌ Info: train
# │   epoch = 3
# │   step = 100
# └   loss = 24.370718f0
# ┌ Info: train
# │   epoch = 3
# │   step = 125
# └   loss = 26.981895f0
# ┌ Info: train
# │   epoch = 3
# │   step = 150
# └   loss = 22.29564f0
# ┌ Info: train
# │   epoch = 4
# │   step = 25
# └   loss = 25.05313f0
# ┌ Info: train
# │   epoch = 4
# │   step = 50
# └   loss = 26.661705f0
# ┌ Info: train
# │   epoch = 4
# │   step = 75
# └   loss = 26.352457f0
# ┌ Info: train
# │   epoch = 4
# │   step = 100
# └   loss = 23.975006f0
# ┌ Info: train
# │   epoch = 4
# │   step = 125
# └   loss = 25.44165f0
# ┌ Info: train
# │   epoch = 4
# │   step = 150
# └   loss = 25.114304f0
# ┌ Info: train
# │   epoch = 5
# │   step = 25
# └   loss = 20.830158f0
# ┌ Info: train
# │   epoch = 5
# │   step = 50
# └   loss = 25.29099f0
# ┌ Info: train
# │   epoch = 5
# │   step = 75
# └   loss = 23.880302f0
# ┌ Info: train
# │   epoch = 5
# │   step = 100
# └   loss = 23.773508f0
# ┌ Info: train
# │   epoch = 5
# │   step = 125
# └   loss = 28.42518f0
# ┌ Info: train
# │   epoch = 5
# │   step = 150
# └   loss = 28.253447f0
# ┌ Info: train
# │   epoch = 6
# │   step = 25
# └   loss = 25.465221f0
# ┌ Info: train
# │   epoch = 6
# │   step = 50
# └   loss = 22.716324f0
# ┌ Info: train
# │   epoch = 6
# │   step = 75
# └   loss = 26.315796f0
# ┌ Info: train
# │   epoch = 6
# │   step = 100
# └   loss = 26.590342f0
# ┌ Info: train
# │   epoch = 6
# │   step = 125
# └   loss = 25.11945f0
# ┌ Info: train
# │   epoch = 6
# │   step = 150
# └   loss = 24.802334f0
# ┌ Info: train
# │   epoch = 7
# │   step = 25
# └   loss = 24.715399f0
# ┌ Info: train
# │   epoch = 7
# │   step = 50
# └   loss = 20.133106f0
# ┌ Info: train
# │   epoch = 7
# │   step = 75
# └   loss = 25.506771f0
# ┌ Info: train
# │   epoch = 7
# │   step = 100
# └   loss = 28.31068f0
# ┌ Info: train
# │   epoch = 7
# │   step = 125
# └   loss = 23.549904f0
# ┌ Info: train
# │   epoch = 7
# │   step = 150
# └   loss = 27.21441f0
# ┌ Info: train
# │   epoch = 8
# │   step = 25
# └   loss = 26.020954f0
# ┌ Info: train
# │   epoch = 8
# │   step = 50
# └   loss = 21.809784f0
# ┌ Info: train
# │   epoch = 8
# │   step = 75
# └   loss = 23.816322f0
# ┌ Info: train
# │   epoch = 8
# │   step = 100
# └   loss = 11.10005f0
# ┌ Info: train
# │   epoch = 8
# │   step = 125
# └   loss = 26.037218f0
# ┌ Info: train
# │   epoch = 8
# │   step = 150
# └   loss = 25.556658f0
# ┌ Info: train
# │   epoch = 9
# │   step = 25
# └   loss = 24.747284f0
# ┌ Info: train
# │   epoch = 9
# │   step = 50
# └   loss = 25.18045f0
# ┌ Info: train
# │   epoch = 9
# │   step = 75
# └   loss = 24.459362f0
# ┌ Info: train
# │   epoch = 9
# │   step = 100
# └   loss = 24.183155f0
# ┌ Info: train
# │   epoch = 9
# │   step = 125
# └   loss = 26.935974f0
# ┌ Info: train
# │   epoch = 9
# │   step = 150
# └   loss = 22.975842f0
# ┌ Info: train
# │   epoch = 10
# │   step = 25
# └   loss = 25.257816f0
# ┌ Info: train
# │   epoch = 10
# │   step = 50
# └   loss = 28.16243f0
# ┌ Info: train
# │   epoch = 10
# │   step = 75
# └   loss = 23.237125f0
# ┌ Info: train
# │   epoch = 10
# │   step = 100
# └   loss = 23.72068f0
# ┌ Info: train
# │   epoch = 10
# │   step = 125
# └   loss = 26.045029f0
# ┌ Info: train
# │   epoch = 10
# │   step = 150
# └   loss = 22.03865f0
# ┌ Info: train
# │   epoch = 11
# │   step = 25
# └   loss = 22.980974f0
# ┌ Info: train
# │   epoch = 11
# │   step = 50
# └   loss = 24.974388f0
# ┌ Info: train
# │   epoch = 11
# │   step = 75
# └   loss = 23.994131f0
# ┌ Info: train
# │   epoch = 11
# │   step = 100
# └   loss = 25.29249f0
# ┌ Info: train
# │   epoch = 11
# │   step = 125
# └   loss = 23.863419f0
# ┌ Info: train
# │   epoch = 11
# │   step = 150
# └   loss = 24.127146f0
# ┌ Info: train
# │   epoch = 12
# │   step = 25
# └   loss = 27.681866f0
# ┌ Info: train
# │   epoch = 12
# │   step = 50
# └   loss = 25.440746f0
# ┌ Info: train
# │   epoch = 12
# │   step = 75
# └   loss = 27.46564f0
# ┌ Info: train
# │   epoch = 12
# │   step = 100
# └   loss = 25.074389f0
# ┌ Info: train
# │   epoch = 12
# │   step = 125
# └   loss = 25.455484f0
# ┌ Info: train
# │   epoch = 12
# │   step = 150
# └   loss = 27.068605f0
# ┌ Info: train
# │   epoch = 13
# │   step = 25
# └   loss = 24.59634f0
# ┌ Info: train
# │   epoch = 13
# │   step = 50
# └   loss = 27.282074f0
# ┌ Info: train
# │   epoch = 13
# │   step = 75
# └   loss = 23.803133f0
# ┌ Info: train
# │   epoch = 13
# │   step = 100
# └   loss = 26.92038f0
# ┌ Info: train
# │   epoch = 13
# │   step = 125
# └   loss = 25.747942f0
# ┌ Info: train
# │   epoch = 13
# │   step = 150
# └   loss = 23.94925f0
# ┌ Info: train
# │   epoch = 14
# │   step = 25
# └   loss = 26.425396f0
# ┌ Info: train
# │   epoch = 14
# │   step = 50
# └   loss = 23.448444f0
# ┌ Info: train
# │   epoch = 14
# │   step = 75
# └   loss = 25.657696f0
# ┌ Info: train
# │   epoch = 14
# │   step = 100
# └   loss = 26.587557f0
# ┌ Info: train
# │   epoch = 14
# │   step = 125
# └   loss = 21.831514f0
# ┌ Info: train
# │   epoch = 14
# │   step = 150
# └   loss = 23.390194f0
# ┌ Info: train
# │   epoch = 15
# │   step = 25
# └   loss = 26.020035f0
# ┌ Info: train
# │   epoch = 15
# │   step = 50
# └   loss = 25.410772f0
# ┌ Info: train
# │   epoch = 15
# │   step = 75
# └   loss = 27.76912f0
# ┌ Info: train
# │   epoch = 15
# │   step = 100
# └   loss = 24.478642f0
# ┌ Info: train
# │   epoch = 15
# │   step = 125
# └   loss = 18.846231f0
# ┌ Info: train
# │   epoch = 15
# │   step = 150
# └   loss = 24.842266f0
# ┌ Info: train
# │   epoch = 16
# │   step = 25
# └   loss = 30.358135f0
# ┌ Info: train
# │   epoch = 16
# │   step = 50
# └   loss = 21.717499f0
# ┌ Info: train
# │   epoch = 16
# │   step = 75
# └   loss = 24.117746f0
# ┌ Info: train
# │   epoch = 16
# │   step = 100
# └   loss = 26.582458f0
# ┌ Info: train
# │   epoch = 16
# │   step = 125
# └   loss = 22.147333f0
# ┌ Info: train
# │   epoch = 16
# │   step = 150
# └   loss = 25.345675f0
# ┌ Info: train
# │   epoch = 17
# │   step = 25
# └   loss = 25.380396f0
# ┌ Info: train
# │   epoch = 17
# │   step = 50
# └   loss = 25.366549f0
# ┌ Info: train
# │   epoch = 17
# │   step = 75
# └   loss = 22.646837f0
# ┌ Info: train
# │   epoch = 17
# │   step = 100
# └   loss = 23.5616f0
# ┌ Info: train
# │   epoch = 17
# │   step = 125
# └   loss = 24.525606f0
# ┌ Info: train
# │   epoch = 17
# │   step = 150
# └   loss = 22.963268f0
# ┌ Info: train
# │   epoch = 18
# │   step = 25
# └   loss = 21.720358f0
# ┌ Info: train
# │   epoch = 18
# │   step = 50
# └   loss = 26.79974f0
# ┌ Info: train
# │   epoch = 18
# │   step = 75
# └   loss = 26.13392f0
# ┌ Info: train
# │   epoch = 18
# │   step = 100
# └   loss = 22.455585f0
# ┌ Info: train
# │   epoch = 18
# │   step = 125
# └   loss = 22.213562f0
# ┌ Info: train
# │   epoch = 18
# │   step = 150
# └   loss = 24.929577f0
# ┌ Info: train
# │   epoch = 19
# │   step = 25
# └   loss = 18.667606f0
# ┌ Info: train
# │   epoch = 19
# │   step = 50
# └   loss = 22.59198f0
# ┌ Info: train
# │   epoch = 19
# │   step = 75
# └   loss = 25.14951f0
# ┌ Info: train
# │   epoch = 19
# │   step = 100
# └   loss = 29.727703f0
# ┌ Info: train
# │   epoch = 19
# │   step = 125
# └   loss = 27.535524f0
# ┌ Info: train
# │   epoch = 19
# │   step = 150
# └   loss = 25.531374f0
# ┌ Info: train
# │   epoch = 20
# │   step = 25
# └   loss = 25.03439f0
# ┌ Info: train
# │   epoch = 20
# │   step = 50
# └   loss = 21.629353f0
# ┌ Info: train
# │   epoch = 20
# │   step = 75
# └   loss = 21.897205f0
# ┌ Info: train
# │   epoch = 20
# │   step = 100
# └   loss = 26.220057f0
# ┌ Info: train
# │   epoch = 20
# │   step = 125
# └   loss = 26.027626f0
# ┌ Info: train
# │   epoch = 20
# │   step = 150
# └   loss = 25.112152f0
# ┌ Info: train
# │   epoch = 21
# │   step = 25
# └   loss = 24.379562f0
# ┌ Info: train
# │   epoch = 21
# │   step = 50
# └   loss = 25.807442f0
# ┌ Info: train
# │   epoch = 21
# │   step = 75
# └   loss = 23.60457f0
# ┌ Info: train
# │   epoch = 21
# │   step = 100
# └   loss = 23.335194f0
# ┌ Info: train
# │   epoch = 21
# │   step = 125
# └   loss = 25.965631f0
# ┌ Info: train
# │   epoch = 21
# │   step = 150
# └   loss = 24.327007f0
# ┌ Info: train
# │   epoch = 22
# │   step = 25
# └   loss = 24.268284f0
# ┌ Info: train
# │   epoch = 22
# │   step = 50
# └   loss = 22.73925f0
# ┌ Info: train
# │   epoch = 22
# │   step = 75
# └   loss = 24.675303f0
# ┌ Info: train
# │   epoch = 22
# │   step = 100
# └   loss = 23.893906f0
# ┌ Info: train
# │   epoch = 22
# │   step = 125
# └   loss = 24.89526f0
# ┌ Info: train
# │   epoch = 22
# │   step = 150
# └   loss = 23.98605f0
# ┌ Info: train
# │   epoch = 23
# │   step = 25
# └   loss = 26.154684f0
# ┌ Info: train
# │   epoch = 23
# │   step = 50
# └   loss = 23.895681f0
# ┌ Info: train
# │   epoch = 23
# │   step = 75
# └   loss = 22.107021f0
# ┌ Info: train
# │   epoch = 23
# │   step = 100
# └   loss = 24.837322f0
# ┌ Info: train
# │   epoch = 23
# │   step = 125
# └   loss = 21.70697f0
# ┌ Info: train
# │   epoch = 23
# │   step = 150
# └   loss = 25.26533f0
# ┌ Info: train
# │   epoch = 24
# │   step = 25
# └   loss = 24.145313f0
# ┌ Info: train
# │   epoch = 24
# │   step = 50
# └   loss = 24.1321f0
# ┌ Info: train
# │   epoch = 24
# │   step = 75
# └   loss = 21.53107f0
# ┌ Info: train
# │   epoch = 24
# │   step = 100
# └   loss = 27.040863f0
# ┌ Info: train
# │   epoch = 24
# │   step = 125
# └   loss = 26.176334f0
# ┌ Info: train
# │   epoch = 24
# │   step = 150
# └   loss = 26.094204f0
# ┌ Info: train
# │   epoch = 25
# │   step = 25
# └   loss = 24.033104f0
# ┌ Info: train
# │   epoch = 25
# │   step = 50
# └   loss = 24.512857f0
# ┌ Info: train
# │   epoch = 25
# │   step = 75
# └   loss = 25.793964f0
# ┌ Info: train
# │   epoch = 25
# │   step = 100
# └   loss = 24.60687f0
# ┌ Info: train
# │   epoch = 25
# │   step = 125
# └   loss = 25.829811f0
# ┌ Info: train
# │   epoch = 25
# │   step = 150
# └   loss = 23.069487f0
# ┌ Info: train
# │   epoch = 26
# │   step = 25
# └   loss = 17.734646f0
# ┌ Info: train
# │   epoch = 26
# │   step = 50
# └   loss = 23.18549f0
# ┌ Info: train
# │   epoch = 26
# │   step = 75
# └   loss = 25.256248f0
# ┌ Info: train
# │   epoch = 26
# │   step = 100
# └   loss = 24.401571f0
# ┌ Info: train
# │   epoch = 26
# │   step = 125
# └   loss = 24.009022f0
# ┌ Info: train
# │   epoch = 26
# │   step = 150
# └   loss = 26.209995f0
# ┌ Info: train
# │   epoch = 27
# │   step = 25
# └   loss = 27.12656f0
# ┌ Info: train
# │   epoch = 27
# │   step = 50
# └   loss = 23.539986f0
# ┌ Info: train
# │   epoch = 27
# │   step = 75
# └   loss = 25.397396f0
# ┌ Info: train
# │   epoch = 27
# │   step = 100
# └   loss = 26.079025f0
# ┌ Info: train
# │   epoch = 27
# │   step = 125
# └   loss = 23.479889f0
# ┌ Info: train
# │   epoch = 27
# │   step = 150
# └   loss = 24.610525f0
# ┌ Info: train
# │   epoch = 28
# │   step = 25
# └   loss = 24.227245f0
# ┌ Info: train
# │   epoch = 28
# │   step = 50
# └   loss = 23.67744f0
# ┌ Info: train
# │   epoch = 28
# │   step = 75
# └   loss = 23.710548f0
# ┌ Info: train
# │   epoch = 28
# │   step = 100
# └   loss = 21.983185f0
# ┌ Info: train
# │   epoch = 28
# │   step = 125
# └   loss = 22.211796f0
# ┌ Info: train
# │   epoch = 28
# │   step = 150
# └   loss = 24.314728f0
# ┌ Info: train
# │   epoch = 29
# │   step = 25
# └   loss = 23.877901f0
# ┌ Info: train
# │   epoch = 29
# │   step = 50
# └   loss = 20.496384f0
# ┌ Info: train
# │   epoch = 29
# │   step = 75
# └   loss = 23.785358f0
# ┌ Info: train
# │   epoch = 29
# │   step = 100
# └   loss = 26.737282f0
# ┌ Info: train
# │   epoch = 29
# │   step = 125
# └   loss = 22.9102f0
# ┌ Info: train
# │   epoch = 29
# │   step = 150
# └   loss = 22.662106f0
# ┌ Info: train
# │   epoch = 30
# │   step = 25
# └   loss = 16.906403f0
# ┌ Info: train
# │   epoch = 30
# │   step = 50
# └   loss = 24.716015f0
# ┌ Info: train
# │   epoch = 30
# │   step = 75
# └   loss = 25.618082f0
# ┌ Info: train
# │   epoch = 30
# │   step = 100
# └   loss = 21.765678f0
# ┌ Info: train
# │   epoch = 30
# │   step = 125
# └   loss = 25.711426f0
# ┌ Info: train
# │   epoch = 30
# │   step = 150
# └   loss = 21.011974f0
# ┌ Info: train
# │   epoch = 31
# │   step = 25
# └   loss = 27.7238f0
# ┌ Info: train
# │   epoch = 31
# │   step = 50
# └   loss = 25.592659f0
# ┌ Info: train
# │   epoch = 31
# │   step = 75
# └   loss = 23.709558f0
# ┌ Info: train
# │   epoch = 31
# │   step = 100
# └   loss = 25.07872f0
# ┌ Info: train
# │   epoch = 31
# │   step = 125
# └   loss = 23.348526f0
# ┌ Info: train
# │   epoch = 31
# │   step = 150
# └   loss = 27.064106f0
# ┌ Info: train
# │   epoch = 32
# │   step = 25
# └   loss = 25.897255f0
# ┌ Info: train
# │   epoch = 32
# │   step = 50
# └   loss = 26.324472f0
# ┌ Info: train
# │   epoch = 32
# │   step = 75
# └   loss = 24.630274f0
# ┌ Info: train
# │   epoch = 32
# │   step = 100
# └   loss = 24.075851f0
# ┌ Info: train
# │   epoch = 32
# │   step = 125
# └   loss = 23.555912f0
# ┌ Info: train
# │   epoch = 32
# │   step = 150
# └   loss = 23.24704f0
# ┌ Info: train
# │   epoch = 33
# │   step = 25
# └   loss = 21.994556f0
# ┌ Info: train
# │   epoch = 33
# │   step = 50
# └   loss = 21.781471f0
# ┌ Info: train
# │   epoch = 33
# │   step = 75
# └   loss = 22.19625f0
# ┌ Info: train
# │   epoch = 33
# │   step = 100
# └   loss = 21.328653f0
# ┌ Info: train
# │   epoch = 33
# │   step = 125
# └   loss = 25.941914f0
# ┌ Info: train
# │   epoch = 33
# │   step = 150
# └   loss = 23.934614f0
# ┌ Info: train
# │   epoch = 34
# │   step = 25
# └   loss = 25.049961f0
# ┌ Info: train
# │   epoch = 34
# │   step = 50
# └   loss = 24.934216f0
# ┌ Info: train
# │   epoch = 34
# │   step = 75
# └   loss = 24.771145f0
# ┌ Info: train
# │   epoch = 34
# │   step = 100
# └   loss = 25.813606f0
# ┌ Info: train
# │   epoch = 34
# │   step = 125
# └   loss = 24.86628f0
# ┌ Info: train
# │   epoch = 34
# │   step = 150
# └   loss = 25.586544f0
# ┌ Info: train
# │   epoch = 35
# │   step = 25
# └   loss = 25.481121f0
# ┌ Info: train
# │   epoch = 35
# │   step = 50
# └   loss = 24.066532f0
# ┌ Info: train
# │   epoch = 35
# │   step = 75
# └   loss = 23.385017f0
# ┌ Info: train
# │   epoch = 35
# │   step = 100
# └   loss = 24.676384f0
# ┌ Info: train
# │   epoch = 35
# │   step = 125
# └   loss = 24.874306f0
# ┌ Info: train
# │   epoch = 35
# │   step = 150
# └   loss = 24.355312f0
# ┌ Info: train
# │   epoch = 36
# │   step = 25
# └   loss = 24.09821f0
# ┌ Info: train
# │   epoch = 36
# │   step = 50
# └   loss = 23.159306f0
# ┌ Info: train
# │   epoch = 36
# │   step = 75
# └   loss = 21.657879f0
# ┌ Info: train
# │   epoch = 36
# │   step = 100
# └   loss = 21.845825f0
# ┌ Info: train
# │   epoch = 36
# │   step = 125
# └   loss = 22.372375f0
# ┌ Info: train
# │   epoch = 36
# │   step = 150
# └   loss = 24.752993f0
# ┌ Info: train
# │   epoch = 37
# │   step = 25
# └   loss = 25.873785f0
# ┌ Info: train
# │   epoch = 37
# │   step = 50
# └   loss = 21.484112f0
# ┌ Info: train
# │   epoch = 37
# │   step = 75
# └   loss = 25.912094f0
# ┌ Info: train
# │   epoch = 37
# │   step = 100
# └   loss = 25.653551f0
# ┌ Info: train
# │   epoch = 37
# │   step = 125
# └   loss = 25.556973f0
# ┌ Info: train
# │   epoch = 37
# │   step = 150
# └   loss = 22.944939f0
# ┌ Info: train
# │   epoch = 38
# │   step = 25
# └   loss = 24.665516f0
# ┌ Info: train
# │   epoch = 38
# │   step = 50
# └   loss = 20.347084f0
# ┌ Info: train
# │   epoch = 38
# │   step = 75
# └   loss = 24.694008f0
# ┌ Info: train
# │   epoch = 38
# │   step = 100
# └   loss = 24.613409f0
# ┌ Info: train
# │   epoch = 38
# │   step = 125
# └   loss = 24.544956f0
# ┌ Info: train
# │   epoch = 38
# │   step = 150
# └   loss = 22.902126f0
# ┌ Info: train
# │   epoch = 39
# │   step = 25
# └   loss = 23.099602f0
# ┌ Info: train
# │   epoch = 39
# │   step = 50
# └   loss = 25.433033f0
# ┌ Info: train
# │   epoch = 39
# │   step = 75
# └   loss = 24.63831f0
# ┌ Info: train
# │   epoch = 39
# │   step = 100
# └   loss = 26.330196f0
# ┌ Info: train
# │   epoch = 39
# │   step = 125
# └   loss = 25.579561f0
# ┌ Info: train
# │   epoch = 39
# │   step = 150
# └   loss = 23.511242f0
# ┌ Info: train
# │   epoch = 40
# │   step = 25
# └   loss = 26.326582f0
# ┌ Info: train
# │   epoch = 40
# │   step = 50
# └   loss = 21.177572f0
# ┌ Info: train
# │   epoch = 40
# │   step = 75
# └   loss = 25.340986f0
# ┌ Info: train
# │   epoch = 40
# │   step = 100
# └   loss = 25.477205f0
# ┌ Info: train
# │   epoch = 40
# │   step = 125
# └   loss = 25.986431f0
# ┌ Info: train
# │   epoch = 40
# │   step = 150
# └   loss = 22.133919f0
# ┌ Info: train
# │   epoch = 41
# │   step = 25
# └   loss = 22.872013f0
# ┌ Info: train
# │   epoch = 41
# │   step = 50
# └   loss = 22.14673f0
# ┌ Info: train
# │   epoch = 41
# │   step = 75
# └   loss = 18.704659f0
# ┌ Info: train
# │   epoch = 41
# │   step = 100
# └   loss = 19.198008f0
# ┌ Info: train
# │   epoch = 41
# │   step = 125
# └   loss = 22.918495f0
# ┌ Info: train
# │   epoch = 41
# │   step = 150
# └   loss = 23.065418f0
# ┌ Info: train
# │   epoch = 42
# │   step = 25
# └   loss = 24.116703f0
# ┌ Info: train
# │   epoch = 42
# │   step = 50
# └   loss = 23.001947f0
# ┌ Info: train
# │   epoch = 42
# │   step = 75
# └   loss = 23.781761f0
# ┌ Info: train
# │   epoch = 42
# │   step = 100
# └   loss = 19.540459f0
# ┌ Info: train
# │   epoch = 42
# │   step = 125
# └   loss = 24.281252f0
# ┌ Info: train
# │   epoch = 42
# │   step = 150
# └   loss = 20.846443f0
# ┌ Info: train
# │   epoch = 43
# │   step = 25
# └   loss = 26.743122f0
# ┌ Info: train
# │   epoch = 43
# │   step = 50
# └   loss = 23.816837f0
# ┌ Info: train
# │   epoch = 43
# │   step = 75
# └   loss = 23.741148f0
# ┌ Info: train
# │   epoch = 43
# │   step = 100
# └   loss = 25.262049f0
# ┌ Info: train
# │   epoch = 43
# │   step = 125
# └   loss = 22.01141f0
# ┌ Info: train
# │   epoch = 43
# │   step = 150
# └   loss = 23.787575f0
# ┌ Info: train
# │   epoch = 44
# │   step = 25
# └   loss = 24.283468f0
# ┌ Info: train
# │   epoch = 44
# │   step = 50
# └   loss = 26.458675f0
# ┌ Info: train
# │   epoch = 44
# │   step = 75
# └   loss = 22.277485f0
# ┌ Info: train
# │   epoch = 44
# │   step = 100
# └   loss = 23.03348f0
# ┌ Info: train
# │   epoch = 44
# │   step = 125
# └   loss = 20.936434f0
# ┌ Info: train
# │   epoch = 44
# │   step = 150
# └   loss = 21.165476f0
# ┌ Info: train
# │   epoch = 45
# │   step = 25
# └   loss = 25.269474f0
# ┌ Info: train
# │   epoch = 45
# │   step = 50
# └   loss = 22.315693f0
# ┌ Info: train
# │   epoch = 45
# │   step = 75
# └   loss = 25.033718f0
# ┌ Info: train
# │   epoch = 45
# │   step = 100
# └   loss = 23.826042f0
# ┌ Info: train
# │   epoch = 45
# │   step = 125
# └   loss = 25.53991f0
# ┌ Info: train
# │   epoch = 45
# │   step = 150
# └   loss = 23.090122f0
# ┌ Info: train
# │   epoch = 46
# │   step = 25
# └   loss = 26.082125f0
# ┌ Info: train
# │   epoch = 46
# │   step = 50
# └   loss = 22.51723f0
# ┌ Info: train
# │   epoch = 46
# │   step = 75
# └   loss = 24.586445f0
# ┌ Info: train
# │   epoch = 46
# │   step = 100
# └   loss = 24.018702f0
# ┌ Info: train
# │   epoch = 46
# │   step = 125
# └   loss = 22.69442f0
# ┌ Info: train
# │   epoch = 46
# │   step = 150
# └   loss = 23.83265f0
# ┌ Info: train
# │   epoch = 47
# │   step = 25
# └   loss = 23.189922f0
# ┌ Info: train
# │   epoch = 47
# │   step = 50
# └   loss = 26.178204f0
# ┌ Info: train
# │   epoch = 47
# │   step = 75
# └   loss = 20.848724f0
# ┌ Info: train
# │   epoch = 47
# │   step = 100
# └   loss = 25.149426f0
# ┌ Info: train
# │   epoch = 47
# │   step = 125
# └   loss = 23.197594f0
# ┌ Info: train
# │   epoch = 47
# │   step = 150
# └   loss = 23.3241f0
# ┌ Info: train
# │   epoch = 48
# │   step = 25
# └   loss = 23.188025f0
# ┌ Info: train
# │   epoch = 48
# │   step = 50
# └   loss = 23.411463f0
# ┌ Info: train
# │   epoch = 48
# │   step = 75
# └   loss = 23.432335f0
# ┌ Info: train
# │   epoch = 48
# │   step = 100
# └   loss = 22.71156f0
# ┌ Info: train
# │   epoch = 48
# │   step = 125
# └   loss = 23.088894f0
# ┌ Info: train
# │   epoch = 48
# │   step = 150
# └   loss = 24.21531f0
# ┌ Info: train
# │   epoch = 49
# │   step = 25
# └   loss = 19.149452f0
# ┌ Info: train
# │   epoch = 49
# │   step = 50
# └   loss = 21.175003f0
# ┌ Info: train
# │   epoch = 49
# │   step = 75
# └   loss = 25.178764f0
# ┌ Info: train
# │   epoch = 49
# │   step = 100
# └   loss = 21.635054f0
# ┌ Info: train
# │   epoch = 49
# │   step = 125
# └   loss = 24.653725f0
# ┌ Info: train
# │   epoch = 49
# │   step = 150
# └   loss = 24.785437f0
# ┌ Info: train
# │   epoch = 50
# │   step = 25
# └   loss = 26.671728f0
# ┌ Info: train
# │   epoch = 50
# │   step = 50
# └   loss = 23.6824f0
# ┌ Info: train
# │   epoch = 50
# │   step = 75
# └   loss = 24.098778f0
# ┌ Info: train
# │   epoch = 50
# │   step = 100
# └   loss = 24.858032f0
# ┌ Info: train
# │   epoch = 50
# │   step = 125
# └   loss = 23.040945f0
# ┌ Info: train
# │   epoch = 50
# │   step = 150
# └   loss = 22.54076f0
# EditFlowModel(
#   Embedding(22 => 128),                 # 2_816 parameters
#   Chain(
#     RandomFourierFeatures{Float32, Matrix{Float32}}(Float32[-4.5109034 -3.5286963 … 9.479959 7.8329725]),
#     Dense(128 => 128),                  # 16_512 parameters
#   ),
#   [
#     TransformerBlock(
#       Attention(
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         identity,
#         identity,
#         Onion.var"#32#34"(),
#         16,
#         16,
#         8,
#         8,
#       ),
#       StarGLU(
#         Dense(128 => 512; bias=false),  # 65_536 parameters
#         Dense(512 => 128; bias=false),  # 65_536 parameters
#         Dense(128 => 512; bias=false),  # 65_536 parameters
#         NNlib.swish,
#       ),
#       AdaLN(
#         Onion.LayerNorm{Vector{Float32}, Vector{Float32}, Float32}(Float32[0.9967958, 0.9869625, 0.99037206, 0.9952497, 0.9702036, 0.9800837, 0.9745326, 0.9878916, 0.9594757, 0.9897762  …  0.9973829, 0.98189306, 0.99930227, 0.9924687, 0.96413124, 0.98626226, 0.98451954, 0.99558693, 0.98469424, 0.9983752], Float32[-0.0005225724, 0.008076679, -0.004573487, -0.008991586, -0.0022569797, 0.00772917, 0.022327727, 0.0013664486, -0.006174539, 0.00085590524  …  -0.0055099158, 0.0036732075, -0.001059735, 0.012229179, -0.00652443, 0.000418949, 0.0061954665, 0.0028194247, -0.0041092695, 0.00022841303], 1.0f-6),  # 256 parameters
#         Dense(128 => 128),              # 16_512 parameters
#         Dense(128 => 128),              # 16_512 parameters
#       ),
#       AdaLN(
#         Onion.LayerNorm{Vector{Float32}, Vector{Float32}, Float32}(Float32[0.98412365, 0.98356694, 0.9991844, 0.98061776, 1.0074458, 1.0001413, 0.98833823, 0.9987704, 0.991204, 0.99532646  …  0.9848799, 1.0059643, 0.98044896, 0.98279643, 1.0155826, 0.9848778, 0.9933505, 0.9947882, 0.9984975, 0.99049044], Float32[0.0103082, 0.010853426, -7.58663f-5, 0.009344174, 0.004389455, -0.0016753467, 0.0062471745, -0.0046117036, -0.016211234, 0.015867772  …  -0.012600643, -0.0019048655, 0.0023564878, 0.008244524, -0.00075314543, 0.0050747017, -0.006136866, -0.0053728544, -0.0018225668, 0.023820948], 1.0f-6),  # 256 parameters
#         Dense(128 => 128),              # 16_512 parameters
#         Dense(128 => 128),              # 16_512 parameters
#       ),
#       identity,
#     ),
#     TransformerBlock(
#       Attention(
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         identity,
#         identity,
#         Onion.var"#32#34"(),
#         16,
#         16,
#         8,
#         8,
#       ),
#       StarGLU(
#         Dense(128 => 512; bias=false),  # 65_536 parameters
#         Dense(512 => 128; bias=false),  # 65_536 parameters
#         Dense(128 => 512; bias=false),  # 65_536 parameters
#         NNlib.swish,
#       ),
#       AdaLN(
#         Onion.LayerNorm{Vector{Float32}, Vector{Float32}, Float32}(Float32[0.99398494, 0.99072254, 0.98964727, 0.9913998, 0.96825975, 0.9956356, 0.9806926, 0.9927313, 0.9783374, 1.0013367  …  0.9955111, 0.9714232, 0.9932761, 0.9916518, 0.97599345, 0.99484235, 0.9863062, 0.9868813, 0.99386036, 0.9897667], Float32[0.002271547, 0.0012500598, -0.0013109404, -0.009307533, -0.005532772, 0.00332578, -0.0062586013, -0.004487046, -0.009959927, -0.001968619  …  -0.0092587015, 0.0016701458, 0.004358063, -0.0034356923, 0.008127138, -0.0012910413, 0.01754202, 0.01152308, -0.0062666866, 0.011563656], 1.0f-6),  # 256 parameters
#         Dense(128 => 128),              # 16_512 parameters
#         Dense(128 => 128),              # 16_512 parameters
#       ),
#       AdaLN(
#         Onion.LayerNorm{Vector{Float32}, Vector{Float32}, Float32}(Float32[1.0095794, 1.0033473, 1.0020524, 1.0036801, 1.0157589, 1.0096356, 1.0005842, 1.0092266, 0.9975341, 0.98216057  …  1.0134289, 0.9880383, 1.0035987, 1.0086101, 1.008442, 1.0066518, 1.0115547, 1.0150577, 0.9883698, 1.0045927], Float32[0.0018625382, 0.0074362713, 0.010829576, 0.00023766467, -0.009477628, -0.005826937, -0.001142101, -0.016898308, -0.012365104, 0.01040461  …  -0.0031639615, -0.008584582, -0.012951189, 0.0051505445, -0.0012443908, 0.008775254, 0.002358304, 7.299369f-5, -0.0044311574, 0.01911879], 1.0f-6),  # 256 parameters
#         Dense(128 => 128),              # 16_512 parameters
#         Dense(128 => 128),              # 16_512 parameters
#       ),
#       identity,
#     ),
#     TransformerBlock(
#       Attention(
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         identity,
#         identity,
#         Onion.var"#32#34"(),
#         16,
#         16,
#         8,
#         8,
#       ),
#       StarGLU(
#         Dense(128 => 512; bias=false),  # 65_536 parameters
#         Dense(512 => 128; bias=false),  # 65_536 parameters
#         Dense(128 => 512; bias=false),  # 65_536 parameters
#         NNlib.swish,
#       ),
#       AdaLN(
#         Onion.LayerNorm{Vector{Float32}, Vector{Float32}, Float32}(Float32[0.9964801, 0.9907213, 0.9829918, 0.9904836, 1.0075997, 0.9931966, 0.967814, 0.994991, 0.99343467, 0.9698302  …  1.0127897, 0.98682904, 0.9882866, 0.9758389, 0.9728117, 1.0221164, 0.97261125, 0.9949346, 1.0151469, 0.99335915], Float32[-0.014417081, 0.006284324, -0.009420766, 0.0028740377, -0.007851509, -0.0016916802, 0.00028211612, 0.004104854, -0.0010160299, 0.0028311377  …  0.0061248355, -0.003470834, 0.0037332277, -0.00510081, 0.00078595727, -0.0052126795, 0.0049999044, -0.007494009, -0.0076053017, -0.0034516104], 1.0f-6),  # 256 parameters
#         Dense(128 => 128),              # 16_512 parameters
#         Dense(128 => 128),              # 16_512 parameters
#       ),
#       AdaLN(
#         Onion.LayerNorm{Vector{Float32}, Vector{Float32}, Float32}(Float32[0.98102707, 0.9881729, 1.0145462, 1.0161818, 1.010741, 1.0101572, 1.0054857, 0.9960153, 1.0076207, 0.9982568  …  1.0110102, 0.97780424, 1.0103778, 1.0270656, 1.0007466, 1.0155469, 1.0250667, 0.9943188, 1.0158885, 0.9926699], Float32[-0.020408258, -0.007663947, -0.002164433, 0.0045097587, -0.004046006, -0.0084987385, -0.0032783668, -0.0019530786, -0.0018806072, 0.0014927586  …  0.002657746, -0.004882839, -0.0094046, 0.0029575205, -0.010758868, 0.005579408, -0.00012946833, -0.0011488283, -0.0051159984, 0.012121034], 1.0f-6),  # 256 parameters
#         Dense(128 => 128),              # 16_512 parameters
#         Dense(128 => 128),              # 16_512 parameters
#       ),
#       identity,
#     ),
#     TransformerBlock(
#       Attention(
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         identity,
#         identity,
#         Onion.var"#32#34"(),
#         16,
#         16,
#         8,
#         8,
#       ),
#       StarGLU(
#         Dense(128 => 512; bias=false),  # 65_536 parameters
#         Dense(512 => 128; bias=false),  # 65_536 parameters
#         Dense(128 => 512; bias=false),  # 65_536 parameters
#         NNlib.swish,
#       ),
#       AdaLN(
#         Onion.LayerNorm{Vector{Float32}, Vector{Float32}, Float32}(Float32[0.97678447, 0.9843075, 0.97703946, 1.0089988, 0.9998969, 0.99314827, 1.005877, 0.9890229, 0.98229724, 0.9969458  …  0.9900987, 0.99567735, 0.9876625, 0.99173796, 1.0165083, 0.9832781, 0.9971774, 1.0104102, 0.9998328, 0.99126804], Float32[-0.0036148801, -0.0061858366, 0.0043971017, 0.0063074683, 0.005699646, 0.0021153758, -0.0040238057, 0.005645371, 0.001263952, 0.009946144  …  -0.0067127184, -0.0050887824, -0.0009767002, -0.016533986, 0.011165631, -0.00066996843, 0.0014427631, -0.007045365, -0.0015280164, -0.0040101036], 1.0f-6),  # 256 parameters
#         Dense(128 => 128),              # 16_512 parameters
#         Dense(128 => 128),              # 16_512 parameters
#       ),
#       AdaLN(
#         Onion.LayerNorm{Vector{Float32}, Vector{Float32}, Float32}(Float32[1.0210867, 1.0158178, 1.0208023, 1.047025, 1.0237092, 1.018517, 1.0044487, 0.9989978, 0.99009013, 1.0100825  …  1.01286, 1.0051826, 1.0109634, 1.0528429, 1.0127131, 1.0134708, 1.0189143, 0.9862647, 1.0223742, 0.98723614], Float32[-0.0045142854, -0.008482742, -0.0018320186, 0.0036619315, -0.010827755, -0.0021696852, -0.010647439, -0.0046669086, -0.007829798, 0.005749223  …  -0.005271609, -0.015943931, 0.00100527, -0.01039895, -0.005209468, 0.00091932324, 0.0036592623, 0.009832175, -0.005363889, 0.01747159], 1.0f-6),  # 256 parameters
#         Dense(128 => 128),              # 16_512 parameters
#         Dense(128 => 128),              # 16_512 parameters
#       ),
#       identity,
#     ),
#   ],
#   Dense(128 => 20; bias=false),         # 2_560 parameters
#   Dense(128 => 20; bias=false),         # 2_560 parameters
#   Dense(128 => 1; bias=false),          # 128 parameters
#   Dense(128 => 1; bias=false),          # 128 parameters
#   Dense(128 => 1; bias=false),          # 128 parameters
#   RoPE{Matrix{Float32}}(Float32[1.0 0.5403023 … -0.87528455 -0.065975994; 1.0 0.95041525 … 0.9552474 0.8159282; … ; 1.0 0.9999995 … -0.57972294 -0.5789079; 1.0 0.99999994 … 0.2726629 0.27235872], Float32[0.0 0.84147096 … -0.48360822 -0.9978212; 0.0 0.3109836 … 0.29580808 0.5781532; … ; 0.0 0.0009999999 … -0.8148137 -0.8153929; 0.0 0.0003162278 … 0.9621096 0.9621958]),
#   20,
# )         # Total: 84 trainable arrays, 1_339_648 parameters,
#           # plus 3 non-trainable, 65_600 parameters, summarysize 5.365 MiB.

# %%
rng=Random.MersenneTwister(42)
# Out:
# MersenneTwister(42)

# %%
model_samples_any = sample_gen_n(P, model; n=10, ts=0f0:0.01f0:1f0, rng)
model_final_states = map(final_state_from_gen, model_samples_any)
model_strings = [state_to_PM_string(P, s) for s in model_final_states]
# Out:
# 10-element Vector{String}:
#  "EVQLVEWGGGLVQPVRS"
#  "QVQLVKSGSPLKKPGADKV"
#  "QVQLVESGGGLVKCG"
#  "QMQLQESGPGLVKPGASVK"
#  "EVQEVGGGLVQPGGLSLSL"
#  "EVTL"
#  "QVQLVESGGGVVQPGRSGA"
#  "EVQLVQKGGL"
#  "NTLQESSGVGLV"
#  "EVYVVEHGGGL"

# %%
train_states = [FF.DiscreteState(P.k, sample(PM; rng=rng)) for i in 1:10]
train_strings = [state_to_PM_string(P, s) for s in train_states]
# Out:
# 10-element Vector{String}:
#  "EVQLVESGGGLVKPPGQLR"
#  "QVQLVQSKAEVKKPGASVKV"
#  "EGQRVECGGGGGQRG"
#  "EVQLVESGGGLV"
#  "QVQLVQSGAAV"
#  "EVQLVESGGGLVQPGGSLTL"
#  "QVQLVESGGGVVQPCR"
#  "QVLLVQSGTEVFKPGASMKV"
#  "QVLLVQSTAEVKK"
#  "QITLKESDPTLVKP"

# %%
# Sampling and Levenshtein plot
using Random
n = 1000
# 100 model samples (final states → strings)
model_samples_any = sample_gen_n(P, model; n=n, ts=0f0:0.01f0:1f0, rng=rng)
model_final_states = map(final_state_from_gen, model_samples_any)
model_strings = [state_to_PM_string(P, s) for s in model_final_states]
# Out:
# 1000-element Vector{String}:
#  "EVLHVVEGGG"
#  "QVQLVQSGAEAK"
#  "QVQLQESGPGLAKPSEVLSLV"
#  "EVQLVESGGGLVKPGHSLR"
#  "QVQLVKTGMEVKKPGASVK"
#  "QVQLQESTPGLVKPSVSETL"
#  "QVQLVQSGAAVKTPGASV"
#  "EVQLVESGGGLV"
#  "QVQLVQSGGALV"
#  "MVMLVPSGAEVKKP"
#  "QVQLVRSGQALVK"
#  "QVQLVQSGAAV"
#  "QKQLLQSGGVLVKPSTLSL"
#  ⋮
#  "EVQLVESCSGGLVKPGGGS"
#  "QVQHVQSGAEYKKPGASK"
#  "QVQLVQSDAEV"
#  "QVQLVQSGAEVEQP"
#  "QNLKQPSGAEVKV"
#  "QVQLVKSGAGLVKPGASVKV"
#  "QVQLVQYGQGNVKKPGASVRT"
#  "QVQLVYSGAEVK"
#  "QVLLVESGGGVVQTGAS"
#  "QVQLVQSGHAEVKRPGA"
#  "QVQLQQSGPAEVKPKPCSL"
#  "QLQLVQSGAEVKK"

# %%
m = 1000
p=100000
# Build training strings from PM parents (the data PM was built on)
train_states = [FF.DiscreteState(P.k, sample(PM; rng=rng)) for i in 1:m]
train_strings = [state_to_PM_string(P, s) for s in train_states]

# Independent validation strings sampled from PM
val_states = [FF.DiscreteState(P.k, sample(PM; rng=rng)) for i in 1:p]
val_strings = [state_to_PM_string(P, s) for s in val_states]
#val_strings = [s for s in val_strings if !(s in train_strings)]

# Plot normalized Levenshtein vs. training set (distinct val/train)
plt = plot_lev_dist("model_vs_true", val_strings, model_strings, train_strings; title="Model vs True (normalized Levenshtein)")
display(plt)
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00

# %%
model_strings_bos = [">" * state_to_PM_string(P, s) for s in model_final_states]
plt = plot_lev_dist("model_vs_true", val_strings, model_strings_bos, train_strings; title="Model vs True (normalized Levenshtein)")
display(plt)
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00

# %%
n=1000000
val_states = [FF.DiscreteState(P.k, sample(PM; rng)) for i in 1:n]
val_strings = [state_to_PM_string(P, s) for s in val_states]



pLen = plot_len_dist("model_vs_true_len", val_strings, model_strings; title="Length distribution: Natural vs Generated")
display(pLen)

pAA = plot_AA_dist("model_vs_true_AA", val_strings, model_strings; title="AA frequency: Natural vs Generated")
display(pAA)

# %%
println("Natural 'A' frequency: ", (isdefined(Main, :val_strings) ? sum(count(==('A'), s) for s in val_strings) / sum(length.(val_strings)) : sum(count(==('A'), s) for s in val_strings) / sum(length.(val_strings))))
# Out:
# Natural 'A' frequency: 0.047142480905978404

# %%
println("Natural 'A' frequency: ", (isdefined(Main, :model_strings) ? sum(count(==('A'), s) for s in model_strings) / sum(length.(model_strings)) : sum(count(==('A'), s) for s in model_strings) / sum(length.(model_strings))))
# Out:
# Natural 'A' frequency: 0.04109772423025435

# %%
rng = Random.MersenneTwister(42)
# Out:
# MersenneTwister(42)

# %%
n=1000000
val_states = [FF.DiscreteState(P.k, sample(PM; rng)) for i in 1:n]
val_strings = [state_to_PM_string(P, s) for s in val_states]
pLen = plot_len_dist("model_vs_true_len", val_strings, val_strings; title="Length distribution: Natural vs Generated")
