# %%
using Pkg
Pkg.activate(@__DIR__)
Pkg.instantiate()
using Revise

using Random
using Statistics
using Adapt
using Functors
using Flux
using Onion
using RandomFeatureMaps
using Zygote

Pkg.develop(path=joinpath(@__DIR__, ".."))
using Flowfusion
const FF = Flowfusion

include(joinpath(@__DIR__, "prob_model.jl"))
include(joinpath(@__DIR__, "helper_funcs.jl"))
# Out:
#   Activating project at `~/dev/Flowfusion.jl/editflow_code`
#    Resolving package versions...
#   No Changes to `~/dev/Flowfusion.jl/editflow_code/Project.toml`
#   No Changes to `~/dev/Flowfusion.jl/editflow_code/Manifest.toml`
# WARNING: using StatsBase.sample in module Main conflicts with an existing identifier.
# plot_len_dist (generic function with 1 method)

# %%
import CUDA

# Device helpers
const _gpu_enabled = try
    CUDA.has_cuda()
catch
    false
end

to_dev(x) = _gpu_enabled ? Adapt.adapt(CUDA.CuArray, x) : x
to_cpu(x) = _gpu_enabled ? Adapt.adapt(Array, x) : x
# move x to the same device type as y (Array or CuArray)
to_same_device(x, y) = (_gpu_enabled && (y isa CUDA.CuArray)) ? Adapt.adapt(CUDA.CuArray, x) : Adapt.adapt(Array, x)
# Out:
# to_same_device (generic function with 1 method)

# %%
# Minibatch builder (uses true PM)
function make_minibatch(B::Int, P::FF.EditFlow; rng=Random.default_rng())
    K = P.k
    x0s = Vector{FF.DiscreteState}(undef, B)
    x1s = Vector{FF.DiscreteState}(undef, B)
    for b in 1:B
        # x1 from true PM
        seq1 = sample(PM; rng=rng)
        @assert all(1 .<= seq1 .<= K)
        x1s[b] = FF.DiscreteState(K, seq1)
        # x0: uniform tokens with random length in 1:10 (no BOS in x0)
        L0 = rand(rng, 1:10)
        seq0 = rand(rng, 1:K, L0)
        x0s[b] = FF.DiscreteState(K, seq0)
    end
    ts = rand(rng, Float32, B)
    return x0s, x1s, ts
end
# Out:
# make_minibatch (generic function with 1 method)

# %%
# Model definition
struct EditFlowModel{L}
    layers::L
end
Flux.@layer EditFlowModel

function EditFlowModel(; d=128, num_heads=8, nlayers=6, rff_dim=128, cond_dim=128, K::Int)
    embedding   = Flux.Embedding(K + 2 => d)
    time_embed  = Flux.Chain(RandomFourierFeatures(1 => rff_dim, 1.0f0), Dense(rff_dim => cond_dim))
    blocks      = [Onion.AdaTransformerBlock(d, cond_dim, num_heads) for _ in 1:nlayers]
    head_combined = Dense(d => 2K + 1, bias=false)
    rope        = RoPE(d ÷ num_heads, 4096)
    return EditFlowModel((; embedding, time_embed, blocks, head_combined, rope, K))
end
# Out:
# EditFlowModel

# %%
# Forward pass
function (model::EditFlowModel)(t, Xt_ms)
    m = model.layers
    X = FF.tensor(Xt_ms)
    X = ndims(X) == 1 ? reshape(X, :, 1) : X
    L, B = size(X)

    pmask = Zygote.@ignore FF.getlmask(Xt_ms)
    Xp = X .+ 1
    H = m.embedding(Xp)

    t = ndims(t) == 0 ? fill(Float32(t), B) : Float32.(t)
    cond = m.time_embed(reshape(t, 1, B))

    cond  = to_same_device(cond, H)
    pmask = Zygote.@ignore to_same_device(pmask, H)
    rope  = Zygote.@ignore to_same_device(m.rope[1:L], H)

    for blk in m.blocks
        H = blk(H; cond, rope, kpad_mask=pmask)
    end
    return m.head_combined(H)
end

# %%
# Training (GPU if available)
function train_editflow!(P::FF.EditFlow,
                        model;
                        epochs::Int=1,
                        steps_per_epoch::Int=100,
                        batch_size::Int=64,
                        lr::Float32=1f-2,
                        seed::Int=42,
                        print_every::Int=25)

    rng = Random.MersenneTwister(seed)
    Random.seed!(seed)

    # Move model to device (GPU if available)
    model = Functors.fmap(to_dev, model)
    opt_state = Flux.setup(Flux.Adam(lr), model)

    for epoch in 1:epochs
        for step in 1:steps_per_epoch

            # 1) Minibatch Sampling
            x0s, x1s, ts = make_minibatch(batch_size, P; rng=rng)

            # 2) Align and batch
            Z0, Z1 = FF.align_and_batch(P, x0s, x1s)

            # 3) Interpolate
            Zt, Xt = FF.interpolate_Z_elementwise(P, Z0, Z1, ts)

            # 4) Prepend BOS
            bos = P.bos_token
            Zt = vcat(fill(bos, 1, batch_size), Zt)
            Xt = vcat(fill(bos, 1, batch_size), Xt)
            Z1 = vcat(fill(bos, 1, batch_size), Z1)
            
            # 5) Masks and multipliers
            transition_mask = FF.transition_mask_from_Xt(P, Xt)
            edit_multiplier = FF.remaining_edits(P, Zt, Z1, Xt)
            @assert size(transition_mask) == size(edit_multiplier)

            # 6) Scheduler scaling
            den = 1f0 .- P.κ.(ts)
            den = max.(den, 1f-3)
            scheduler_scaling = P.dκ.(ts) ./ den

            # 7) Masked state
            lmask = Xt .!= P.padding_token
            cmask = trues(size(lmask))
            Xt_ms = FF.MaskedState(FF.DiscreteState(P.k, Xt), cmask, lmask)

            ts_d    = to_dev(ts)
            Xt_ms_d = to_dev(Xt_ms)
            Tmask_d = to_dev(transition_mask)
            Emult_d = to_dev(edit_multiplier)
            sched_d = to_dev(reshape(Float32.(scheduler_scaling), 1, 1, :))

            # 8) Forward + loss + update
            loss, grad = Flux.withgradient(model) do m
                M = m(ts_d, Xt_ms_d)
                l = FF.edit_loss(P, M, Tmask_d, Emult_d, sched_d; eps=1f-8)
                if isnan(l)
                    println("Maximum element of M: ", maximum(M))
                end
                l
            end
            Flux.update!(opt_state, model, grad[1])

            if step % print_every == 0
                @info "train" epoch step loss=Float32(loss)
            end
        end
    end

    return Functors.fmap(to_cpu, model)
end
# Out:
# train_editflow! (generic function with 1 method)

# %%
# Init process and model
K = PM.K
P = FF.EditFlow(K; bos_token=0, gap_wise=false)
model = EditFlowModel(; d=128, num_heads=8, nlayers=4, rff_dim=128, cond_dim=128, K=K)
nothing

# %%
model = train_editflow!(P, model; epochs=100, steps_per_epoch=150, batch_size=256, lr=1f-4)
# Out:
# ┌ Info: train
# │   epoch = 1
# │   step = 25
# └   loss = 20.746237f0
# ┌ Info: train
# │   epoch = 1
# │   step = 50
# └   loss = 23.981628f0
# ┌ Info: train
# │   epoch = 1
# │   step = 75
# └   loss = 23.213884f0
# ┌ Info: train
# │   epoch = 1
# │   step = 100
# └   loss = 23.454155f0
# ┌ Info: train
# │   epoch = 1
# │   step = 125
# └   loss = 18.665428f0
# ┌ Info: train
# │   epoch = 1
# │   step = 150
# └   loss = 20.873983f0
# ┌ Info: train
# │   epoch = 2
# │   step = 25
# └   loss = 23.157003f0
# ┌ Info: train
# │   epoch = 2
# │   step = 50
# └   loss = 15.275973f0
# ┌ Info: train
# │   epoch = 2
# │   step = 75
# └   loss = 22.903381f0
# ┌ Info: train
# │   epoch = 2
# │   step = 100
# └   loss = 24.729305f0
# ┌ Info: train
# │   epoch = 2
# │   step = 125
# └   loss = 19.102013f0
# ┌ Info: train
# │   epoch = 2
# │   step = 150
# └   loss = 19.672424f0
# ┌ Info: train
# │   epoch = 3
# │   step = 25
# └   loss = 23.530746f0
# ┌ Info: train
# │   epoch = 3
# │   step = 50
# └   loss = 21.67213f0
# ┌ Info: train
# │   epoch = 3
# │   step = 75
# └   loss = 21.382526f0
# ┌ Info: train
# │   epoch = 3
# │   step = 100
# └   loss = 21.963814f0
# ┌ Info: train
# │   epoch = 3
# │   step = 125
# └   loss = 22.835972f0
# ┌ Info: train
# │   epoch = 3
# │   step = 150
# └   loss = 21.291992f0
# ┌ Info: train
# │   epoch = 4
# │   step = 25
# └   loss = 21.19426f0
# ┌ Info: train
# │   epoch = 4
# │   step = 50
# └   loss = 25.382185f0
# ┌ Info: train
# │   epoch = 4
# │   step = 75
# └   loss = 23.135967f0
# ┌ Info: train
# │   epoch = 4
# │   step = 100
# └   loss = 21.92569f0
# ┌ Info: train
# │   epoch = 4
# │   step = 125
# └   loss = 23.028893f0
# ┌ Info: train
# │   epoch = 4
# │   step = 150
# └   loss = 18.427214f0
# ┌ Info: train
# │   epoch = 5
# │   step = 25
# └   loss = 17.69117f0
# ┌ Info: train
# │   epoch = 5
# │   step = 50
# └   loss = 23.73476f0
# ┌ Info: train
# │   epoch = 5
# │   step = 75
# └   loss = 21.384754f0
# ┌ Info: train
# │   epoch = 5
# │   step = 100
# └   loss = 23.658775f0
# ┌ Info: train
# │   epoch = 5
# │   step = 125
# └   loss = 24.132454f0
# ┌ Info: train
# │   epoch = 5
# │   step = 150
# └   loss = 23.998142f0
# ┌ Info: train
# │   epoch = 6
# │   step = 25
# └   loss = 22.203682f0
# ┌ Info: train
# │   epoch = 6
# │   step = 50
# └   loss = 20.36901f0
# ┌ Info: train
# │   epoch = 6
# │   step = 75
# └   loss = 21.243134f0
# ┌ Info: train
# │   epoch = 6
# │   step = 100
# └   loss = 21.106112f0
# ┌ Info: train
# │   epoch = 6
# │   step = 125
# └   loss = 23.82871f0
# ┌ Info: train
# │   epoch = 6
# │   step = 150
# └   loss = 22.493202f0
# ┌ Info: train
# │   epoch = 7
# │   step = 25
# └   loss = 21.290234f0
# ┌ Info: train
# │   epoch = 7
# │   step = 50
# └   loss = 18.923895f0
# ┌ Info: train
# │   epoch = 7
# │   step = 75
# └   loss = 22.832842f0
# ┌ Info: train
# │   epoch = 7
# │   step = 100
# └   loss = 24.057846f0
# ┌ Info: train
# │   epoch = 7
# │   step = 125
# └   loss = 18.94542f0
# ┌ Info: train
# │   epoch = 7
# │   step = 150
# └   loss = 21.881554f0
# ┌ Info: train
# │   epoch = 8
# │   step = 25
# └   loss = 22.718155f0
# ┌ Info: train
# │   epoch = 8
# │   step = 50
# └   loss = 25.733717f0
# ┌ Info: train
# │   epoch = 8
# │   step = 75
# └   loss = 19.073797f0
# ┌ Info: train
# │   epoch = 8
# │   step = 100
# └   loss = 23.92004f0
# ┌ Info: train
# │   epoch = 8
# │   step = 125
# └   loss = 23.047007f0
# ┌ Info: train
# │   epoch = 8
# │   step = 150
# └   loss = 23.872967f0
# ┌ Info: train
# │   epoch = 9
# │   step = 25
# └   loss = 27.382488f0
# ┌ Info: train
# │   epoch = 9
# │   step = 50
# └   loss = 21.645565f0
# ┌ Info: train
# │   epoch = 9
# │   step = 75
# └   loss = 22.287525f0
# ┌ Info: train
# │   epoch = 9
# │   step = 100
# └   loss = 20.113968f0
# ┌ Info: train
# │   epoch = 9
# │   step = 125
# └   loss = 25.087315f0
# ┌ Info: train
# │   epoch = 9
# │   step = 150
# └   loss = 19.874767f0
# ┌ Info: train
# │   epoch = 10
# │   step = 25
# └   loss = 20.860031f0
# ┌ Info: train
# │   epoch = 10
# │   step = 50
# └   loss = 20.602049f0
# ┌ Info: train
# │   epoch = 10
# │   step = 75
# └   loss = 22.410063f0
# ┌ Info: train
# │   epoch = 10
# │   step = 100
# └   loss = 10.562942f0
# ┌ Info: train
# │   epoch = 10
# │   step = 125
# └   loss = 21.848387f0
# ┌ Info: train
# │   epoch = 10
# │   step = 150
# └   loss = 21.861128f0
# ┌ Info: train
# │   epoch = 11
# │   step = 25
# └   loss = 21.541365f0
# ┌ Info: train
# │   epoch = 11
# │   step = 50
# └   loss = 23.236982f0
# ┌ Info: train
# │   epoch = 11
# │   step = 75
# └   loss = 19.957115f0
# ┌ Info: train
# │   epoch = 11
# │   step = 100
# └   loss = 22.865005f0
# ┌ Info: train
# │   epoch = 11
# │   step = 125
# └   loss = 22.583748f0
# ┌ Info: train
# │   epoch = 11
# │   step = 150
# └   loss = 22.02132f0
# ┌ Info: train
# │   epoch = 12
# │   step = 25
# └   loss = 24.584347f0
# ┌ Info: train
# │   epoch = 12
# │   step = 50
# └   loss = 22.580858f0
# ┌ Info: train
# │   epoch = 12
# │   step = 75
# └   loss = 22.981087f0
# ┌ Info: train
# │   epoch = 12
# │   step = 100
# └   loss = 22.591656f0
# ┌ Info: train
# │   epoch = 12
# │   step = 125
# └   loss = 25.066517f0
# ┌ Info: train
# │   epoch = 12
# │   step = 150
# └   loss = 24.051542f0
# ┌ Info: train
# │   epoch = 13
# │   step = 25
# └   loss = 25.067421f0
# ┌ Info: train
# │   epoch = 13
# │   step = 50
# └   loss = 23.05304f0
# ┌ Info: train
# │   epoch = 13
# │   step = 75
# └   loss = 23.487747f0
# ┌ Info: train
# │   epoch = 13
# │   step = 100
# └   loss = 20.222967f0
# ┌ Info: train
# │   epoch = 13
# │   step = 125
# └   loss = 20.143532f0
# ┌ Info: train
# │   epoch = 13
# │   step = 150
# └   loss = 22.575806f0
# ┌ Info: train
# │   epoch = 14
# │   step = 25
# └   loss = 24.158926f0
# ┌ Info: train
# │   epoch = 14
# │   step = 50
# └   loss = 22.09401f0
# ┌ Info: train
# │   epoch = 14
# │   step = 75
# └   loss = 23.851517f0
# ┌ Info: train
# │   epoch = 14
# │   step = 100
# └   loss = 23.892365f0
# ┌ Info: train
# │   epoch = 14
# │   step = 125
# └   loss = 22.7897f0
# ┌ Info: train
# │   epoch = 14
# │   step = 150
# └   loss = 21.985878f0
# ┌ Info: train
# │   epoch = 15
# │   step = 25
# └   loss = 22.019676f0
# ┌ Info: train
# │   epoch = 15
# │   step = 50
# └   loss = 21.797548f0
# ┌ Info: train
# │   epoch = 15
# │   step = 75
# └   loss = 22.55872f0
# ┌ Info: train
# │   epoch = 15
# │   step = 100
# └   loss = 20.278553f0
# ┌ Info: train
# │   epoch = 15
# │   step = 125
# └   loss = 20.254448f0
# ┌ Info: train
# │   epoch = 15
# │   step = 150
# └   loss = 23.536222f0
# ┌ Info: train
# │   epoch = 16
# │   step = 25
# └   loss = 23.821463f0
# ┌ Info: train
# │   epoch = 16
# │   step = 50
# └   loss = 17.80231f0
# ┌ Info: train
# │   epoch = 16
# │   step = 75
# └   loss = 21.376482f0
# ┌ Info: train
# │   epoch = 16
# │   step = 100
# └   loss = 23.044758f0
# ┌ Info: train
# │   epoch = 16
# │   step = 125
# └   loss = 21.442654f0
# ┌ Info: train
# │   epoch = 16
# │   step = 150
# └   loss = 20.176807f0
# ┌ Info: train
# │   epoch = 17
# │   step = 25
# └   loss = 23.091465f0
# ┌ Info: train
# │   epoch = 17
# │   step = 50
# └   loss = 25.013334f0
# ┌ Info: train
# │   epoch = 17
# │   step = 75
# └   loss = 21.81593f0
# ┌ Info: train
# │   epoch = 17
# │   step = 100
# └   loss = 22.212975f0
# ┌ Info: train
# │   epoch = 17
# │   step = 125
# └   loss = 21.84259f0
# ┌ Info: train
# │   epoch = 17
# │   step = 150
# └   loss = 20.185429f0
# ┌ Info: train
# │   epoch = 18
# │   step = 25
# └   loss = 20.470398f0
# ┌ Info: train
# │   epoch = 18
# │   step = 50
# └   loss = 21.427452f0
# ┌ Info: train
# │   epoch = 18
# │   step = 75
# └   loss = 22.94579f0
# ┌ Info: train
# │   epoch = 18
# │   step = 100
# └   loss = 21.695702f0
# ┌ Info: train
# │   epoch = 18
# │   step = 125
# └   loss = 19.645878f0
# ┌ Info: train
# │   epoch = 18
# │   step = 150
# └   loss = 22.073719f0
# ┌ Info: train
# │   epoch = 19
# │   step = 25
# └   loss = 21.841595f0
# ┌ Info: train
# │   epoch = 19
# │   step = 50
# └   loss = 22.278421f0
# ┌ Info: train
# │   epoch = 19
# │   step = 75
# └   loss = 21.68238f0
# ┌ Info: train
# │   epoch = 19
# │   step = 100
# └   loss = 26.269619f0
# ┌ Info: train
# │   epoch = 19
# │   step = 125
# └   loss = 23.283346f0
# ┌ Info: train
# │   epoch = 19
# │   step = 150
# └   loss = 23.181093f0
# ┌ Info: train
# │   epoch = 20
# │   step = 25
# └   loss = 23.541328f0
# ┌ Info: train
# │   epoch = 20
# │   step = 50
# └   loss = 21.628794f0
# ┌ Info: train
# │   epoch = 20
# │   step = 75
# └   loss = 18.634392f0
# ┌ Info: train
# │   epoch = 20
# │   step = 100
# └   loss = 21.7462f0
# ┌ Info: train
# │   epoch = 20
# │   step = 125
# └   loss = 23.353523f0
# ┌ Info: train
# │   epoch = 20
# │   step = 150
# └   loss = 20.927622f0
# ┌ Info: train
# │   epoch = 21
# │   step = 25
# └   loss = 23.720219f0
# ┌ Info: train
# │   epoch = 21
# │   step = 50
# └   loss = 25.47013f0
# ┌ Info: train
# │   epoch = 21
# │   step = 75
# └   loss = 22.810509f0
# ┌ Info: train
# │   epoch = 21
# │   step = 100
# └   loss = 22.401003f0
# ┌ Info: train
# │   epoch = 21
# │   step = 125
# └   loss = 22.512375f0
# ┌ Info: train
# │   epoch = 21
# │   step = 150
# └   loss = 23.377796f0
# ┌ Info: train
# │   epoch = 22
# │   step = 25
# └   loss = 21.350807f0
# ┌ Info: train
# │   epoch = 22
# │   step = 50
# └   loss = 16.468513f0
# ┌ Info: train
# │   epoch = 22
# │   step = 75
# └   loss = 24.804567f0
# ┌ Info: train
# │   epoch = 22
# │   step = 100
# └   loss = 24.310434f0
# ┌ Info: train
# │   epoch = 22
# │   step = 125
# └   loss = 22.925941f0
# ┌ Info: train
# │   epoch = 22
# │   step = 150
# └   loss = 22.39031f0
# ┌ Info: train
# │   epoch = 23
# │   step = 25
# └   loss = 22.91434f0
# ┌ Info: train
# │   epoch = 23
# │   step = 50
# └   loss = 22.262634f0
# ┌ Info: train
# │   epoch = 23
# │   step = 75
# └   loss = 20.324049f0
# ┌ Info: train
# │   epoch = 23
# │   step = 100
# └   loss = 21.413176f0
# ┌ Info: train
# │   epoch = 23
# │   step = 125
# └   loss = 27.26462f0
# ┌ Info: train
# │   epoch = 23
# │   step = 150
# └   loss = 24.746334f0
# ┌ Info: train
# │   epoch = 24
# │   step = 25
# └   loss = 21.85251f0
# ┌ Info: train
# │   epoch = 24
# │   step = 50
# └   loss = 22.560282f0
# ┌ Info: train
# │   epoch = 24
# │   step = 75
# └   loss = 20.03707f0
# ┌ Info: train
# │   epoch = 24
# │   step = 100
# └   loss = 24.268227f0
# ┌ Info: train
# │   epoch = 24
# │   step = 125
# └   loss = 25.471123f0
# ┌ Info: train
# │   epoch = 24
# │   step = 150
# └   loss = 24.593208f0
# ┌ Info: train
# │   epoch = 25
# │   step = 25
# └   loss = 22.767986f0
# ┌ Info: train
# │   epoch = 25
# │   step = 50
# └   loss = 23.076988f0
# ┌ Info: train
# │   epoch = 25
# │   step = 75
# └   loss = 23.13642f0
# ┌ Info: train
# │   epoch = 25
# │   step = 100
# └   loss = 24.121529f0
# ┌ Info: train
# │   epoch = 25
# │   step = 125
# └   loss = 25.215782f0
# ┌ Info: train
# │   epoch = 25
# │   step = 150
# └   loss = 19.73236f0
# ┌ Info: train
# │   epoch = 26
# │   step = 25
# └   loss = 21.485447f0
# ┌ Info: train
# │   epoch = 26
# │   step = 50
# └   loss = 22.659838f0
# ┌ Info: train
# │   epoch = 26
# │   step = 75
# └   loss = 23.290493f0
# ┌ Info: train
# │   epoch = 26
# │   step = 100
# └   loss = 16.489616f0
# ┌ Info: train
# │   epoch = 26
# │   step = 125
# └   loss = 21.764778f0
# ┌ Info: train
# │   epoch = 26
# │   step = 150
# └   loss = 22.014236f0
# ┌ Info: train
# │   epoch = 27
# │   step = 25
# └   loss = 23.763737f0
# ┌ Info: train
# │   epoch = 27
# │   step = 50
# └   loss = 19.692177f0
# ┌ Info: train
# │   epoch = 27
# │   step = 75
# └   loss = 23.253918f0
# ┌ Info: train
# │   epoch = 27
# │   step = 100
# └   loss = 23.51273f0
# ┌ Info: train
# │   epoch = 27
# │   step = 125
# └   loss = 20.86855f0
# ┌ Info: train
# │   epoch = 27
# │   step = 150
# └   loss = 21.306889f0
# ┌ Info: train
# │   epoch = 28
# │   step = 25
# └   loss = 22.108227f0
# ┌ Info: train
# │   epoch = 28
# │   step = 50
# └   loss = 25.949062f0
# ┌ Info: train
# │   epoch = 28
# │   step = 75
# └   loss = 20.045507f0
# ┌ Info: train
# │   epoch = 28
# │   step = 100
# └   loss = 19.165205f0
# ┌ Info: train
# │   epoch = 28
# │   step = 125
# └   loss = 12.919155f0
# ┌ Info: train
# │   epoch = 28
# │   step = 150
# └   loss = 20.903103f0
# ┌ Info: train
# │   epoch = 29
# │   step = 25
# └   loss = 22.889954f0
# ┌ Info: train
# │   epoch = 29
# │   step = 50
# └   loss = 20.677599f0
# ┌ Info: train
# │   epoch = 29
# │   step = 75
# └   loss = 22.235676f0
# ┌ Info: train
# │   epoch = 29
# │   step = 100
# └   loss = 24.818413f0
# ┌ Info: train
# │   epoch = 29
# │   step = 125
# └   loss = 21.454956f0
# ┌ Info: train
# │   epoch = 29
# │   step = 150
# └   loss = 21.443413f0
# ┌ Info: train
# │   epoch = 30
# │   step = 25
# └   loss = 21.767849f0
# ┌ Info: train
# │   epoch = 30
# │   step = 50
# └   loss = 22.12367f0
# ┌ Info: train
# │   epoch = 30
# │   step = 75
# └   loss = 21.95783f0
# ┌ Info: train
# │   epoch = 30
# │   step = 100
# └   loss = 21.690418f0
# ┌ Info: train
# │   epoch = 30
# │   step = 125
# └   loss = 23.498676f0
# ┌ Info: train
# │   epoch = 30
# │   step = 150
# └   loss = 23.116188f0
# ┌ Info: train
# │   epoch = 31
# │   step = 25
# └   loss = 25.376179f0
# ┌ Info: train
# │   epoch = 31
# │   step = 50
# └   loss = 22.445965f0
# ┌ Info: train
# │   epoch = 31
# │   step = 75
# └   loss = 20.826906f0
# ┌ Info: train
# │   epoch = 31
# │   step = 100
# └   loss = 23.523788f0
# ┌ Info: train
# │   epoch = 31
# │   step = 125
# └   loss = 16.482994f0
# ┌ Info: train
# │   epoch = 31
# │   step = 150
# └   loss = 23.550964f0
# ┌ Info: train
# │   epoch = 32
# │   step = 25
# └   loss = 21.193125f0
# ┌ Info: train
# │   epoch = 32
# │   step = 50
# └   loss = 23.838432f0
# ┌ Info: train
# │   epoch = 32
# │   step = 75
# └   loss = 23.289452f0
# ┌ Info: train
# │   epoch = 32
# │   step = 100
# └   loss = 22.098053f0
# ┌ Info: train
# │   epoch = 32
# │   step = 125
# └   loss = 21.513762f0
# ┌ Info: train
# │   epoch = 32
# │   step = 150
# └   loss = 21.862543f0
# ┌ Info: train
# │   epoch = 33
# │   step = 25
# └   loss = 16.810226f0
# ┌ Info: train
# │   epoch = 33
# │   step = 50
# └   loss = 22.037594f0
# ┌ Info: train
# │   epoch = 33
# │   step = 75
# └   loss = 20.468763f0
# ┌ Info: train
# │   epoch = 33
# │   step = 100
# └   loss = 20.604746f0
# ┌ Info: train
# │   epoch = 33
# │   step = 125
# └   loss = 22.249472f0
# ┌ Info: train
# │   epoch = 33
# │   step = 150
# └   loss = 22.916328f0
# ┌ Info: train
# │   epoch = 34
# │   step = 25
# └   loss = 23.879818f0
# ┌ Info: train
# │   epoch = 34
# │   step = 50
# └   loss = 23.453798f0
# ┌ Info: train
# │   epoch = 34
# │   step = 75
# └   loss = 22.617702f0
# ┌ Info: train
# │   epoch = 34
# │   step = 100
# └   loss = 20.713636f0
# ┌ Info: train
# │   epoch = 34
# │   step = 125
# └   loss = 21.131275f0
# ┌ Info: train
# │   epoch = 34
# │   step = 150
# └   loss = 22.763681f0
# ┌ Info: train
# │   epoch = 35
# │   step = 25
# └   loss = 23.138496f0
# ┌ Info: train
# │   epoch = 35
# │   step = 50
# └   loss = 22.24766f0
# ┌ Info: train
# │   epoch = 35
# │   step = 75
# └   loss = 24.000917f0
# ┌ Info: train
# │   epoch = 35
# │   step = 100
# └   loss = 21.266335f0
# ┌ Info: train
# │   epoch = 35
# │   step = 125
# └   loss = 22.831928f0
# ┌ Info: train
# │   epoch = 35
# │   step = 150
# └   loss = 23.104105f0
# ┌ Info: train
# │   epoch = 36
# │   step = 25
# └   loss = 23.901894f0
# ┌ Info: train
# │   epoch = 36
# │   step = 50
# └   loss = 19.866064f0
# ┌ Info: train
# │   epoch = 36
# │   step = 75
# └   loss = 18.89682f0
# ┌ Info: train
# │   epoch = 36
# │   step = 100
# └   loss = 21.663845f0
# ┌ Info: train
# │   epoch = 36
# │   step = 125
# └   loss = 20.070297f0
# ┌ Info: train
# │   epoch = 36
# │   step = 150
# └   loss = 24.728453f0
# ┌ Info: train
# │   epoch = 37
# │   step = 25
# └   loss = 22.615274f0
# ┌ Info: train
# │   epoch = 37
# │   step = 50
# └   loss = 19.564804f0
# ┌ Info: train
# │   epoch = 37
# │   step = 75
# └   loss = 21.089449f0
# ┌ Info: train
# │   epoch = 37
# │   step = 100
# └   loss = 21.273602f0
# ┌ Info: train
# │   epoch = 37
# │   step = 125
# └   loss = 23.159435f0
# ┌ Info: train
# │   epoch = 37
# │   step = 150
# └   loss = 21.562922f0
# ┌ Info: train
# │   epoch = 38
# │   step = 25
# └   loss = 22.734241f0
# ┌ Info: train
# │   epoch = 38
# │   step = 50
# └   loss = 22.008451f0
# ┌ Info: train
# │   epoch = 38
# │   step = 75
# └   loss = 8.860302f0
# ┌ Info: train
# │   epoch = 38
# │   step = 100
# └   loss = 21.15115f0
# ┌ Info: train
# │   epoch = 38
# │   step = 125
# └   loss = 22.32642f0
# ┌ Info: train
# │   epoch = 38
# │   step = 150
# └   loss = 21.513498f0
# ┌ Info: train
# │   epoch = 39
# │   step = 25
# └   loss = 19.381474f0
# ┌ Info: train
# │   epoch = 39
# │   step = 50
# └   loss = 22.2743f0
# ┌ Info: train
# │   epoch = 39
# │   step = 75
# └   loss = 21.010727f0
# ┌ Info: train
# │   epoch = 39
# │   step = 100
# └   loss = 24.264381f0
# ┌ Info: train
# │   epoch = 39
# │   step = 125
# └   loss = 20.826624f0
# ┌ Info: train
# │   epoch = 39
# │   step = 150
# └   loss = 20.921288f0
# ┌ Info: train
# │   epoch = 40
# │   step = 25
# └   loss = 23.755466f0
# ┌ Info: train
# │   epoch = 40
# │   step = 50
# └   loss = 23.364662f0
# ┌ Info: train
# │   epoch = 40
# │   step = 75
# └   loss = 24.126223f0
# ┌ Info: train
# │   epoch = 40
# │   step = 100
# └   loss = 21.64931f0
# ┌ Info: train
# │   epoch = 40
# │   step = 125
# └   loss = 22.564432f0
# ┌ Info: train
# │   epoch = 40
# │   step = 150
# └   loss = 21.728107f0
# ┌ Info: train
# │   epoch = 41
# │   step = 25
# └   loss = 17.909348f0
# ┌ Info: train
# │   epoch = 41
# │   step = 50
# └   loss = 20.832344f0
# ┌ Info: train
# │   epoch = 41
# │   step = 75
# └   loss = 21.323364f0
# ┌ Info: train
# │   epoch = 41
# │   step = 100
# └   loss = 21.952206f0
# ┌ Info: train
# │   epoch = 41
# │   step = 125
# └   loss = 23.968285f0
# ┌ Info: train
# │   epoch = 41
# │   step = 150
# └   loss = 21.83363f0
# ┌ Info: train
# │   epoch = 42
# │   step = 25
# └   loss = 20.986597f0
# ┌ Info: train
# │   epoch = 42
# │   step = 50
# └   loss = 21.239515f0
# ┌ Info: train
# │   epoch = 42
# │   step = 75
# └   loss = 21.450031f0
# ┌ Info: train
# │   epoch = 42
# │   step = 100
# └   loss = 20.893978f0
# ┌ Info: train
# │   epoch = 42
# │   step = 125
# └   loss = 21.543922f0
# ┌ Info: train
# │   epoch = 42
# │   step = 150
# └   loss = 19.674696f0
# ┌ Info: train
# │   epoch = 43
# │   step = 25
# └   loss = 22.830986f0
# ┌ Info: train
# │   epoch = 43
# │   step = 50
# └   loss = 20.515713f0
# ┌ Info: train
# │   epoch = 43
# │   step = 75
# └   loss = 21.128778f0
# ┌ Info: train
# │   epoch = 43
# │   step = 100
# └   loss = 22.751575f0
# ┌ Info: train
# │   epoch = 43
# │   step = 125
# └   loss = 19.633709f0
# ┌ Info: train
# │   epoch = 43
# │   step = 150
# └   loss = 19.873392f0
# ┌ Info: train
# │   epoch = 44
# │   step = 25
# └   loss = 19.810955f0
# ┌ Info: train
# │   epoch = 44
# │   step = 50
# └   loss = 24.402004f0
# ┌ Info: train
# │   epoch = 44
# │   step = 75
# └   loss = 20.716564f0
# ┌ Info: train
# │   epoch = 44
# │   step = 100
# └   loss = 17.452545f0
# ┌ Info: train
# │   epoch = 44
# │   step = 125
# └   loss = 16.890793f0
# ┌ Info: train
# │   epoch = 44
# │   step = 150
# └   loss = 24.448315f0
# ┌ Info: train
# │   epoch = 45
# │   step = 25
# └   loss = 21.888472f0
# ┌ Info: train
# │   epoch = 45
# │   step = 50
# └   loss = 21.899237f0
# ┌ Info: train
# │   epoch = 45
# │   step = 75
# └   loss = 24.195805f0
# ┌ Info: train
# │   epoch = 45
# │   step = 100
# └   loss = 22.420376f0
# ┌ Info: train
# │   epoch = 45
# │   step = 125
# └   loss = 24.594948f0
# ┌ Info: train
# │   epoch = 45
# │   step = 150
# └   loss = 9.004853f0
# ┌ Info: train
# │   epoch = 46
# │   step = 25
# └   loss = 24.887007f0
# ┌ Info: train
# │   epoch = 46
# │   step = 50
# └   loss = 18.23485f0
# ┌ Info: train
# │   epoch = 46
# │   step = 75
# └   loss = 21.913727f0
# ┌ Info: train
# │   epoch = 46
# │   step = 100
# └   loss = 22.218992f0
# ┌ Info: train
# │   epoch = 46
# │   step = 125
# └   loss = 18.94302f0
# ┌ Info: train
# │   epoch = 46
# │   step = 150
# └   loss = 21.745415f0
# ┌ Info: train
# │   epoch = 47
# │   step = 25
# └   loss = 20.451485f0
# ┌ Info: train
# │   epoch = 47
# │   step = 50
# └   loss = 23.83382f0
# ┌ Info: train
# │   epoch = 47
# │   step = 75
# └   loss = 21.155079f0
# ┌ Info: train
# │   epoch = 47
# │   step = 100
# └   loss = 18.894794f0
# ┌ Info: train
# │   epoch = 47
# │   step = 125
# └   loss = 23.932127f0
# ┌ Info: train
# │   epoch = 47
# │   step = 150
# └   loss = 20.041811f0
# ┌ Info: train
# │   epoch = 48
# │   step = 25
# └   loss = 18.656693f0
# ┌ Info: train
# │   epoch = 48
# │   step = 50
# └   loss = 18.531162f0
# ┌ Info: train
# │   epoch = 48
# │   step = 75
# └   loss = 23.119312f0
# ┌ Info: train
# │   epoch = 48
# │   step = 100
# └   loss = 24.319973f0
# ┌ Info: train
# │   epoch = 48
# │   step = 125
# └   loss = 21.268059f0
# ┌ Info: train
# │   epoch = 48
# │   step = 150
# └   loss = 21.691246f0
# ┌ Info: train
# │   epoch = 49
# │   step = 25
# └   loss = 21.474157f0
# ┌ Info: train
# │   epoch = 49
# │   step = 50
# └   loss = 20.733646f0
# ┌ Info: train
# │   epoch = 49
# │   step = 75
# └   loss = 24.136124f0
# ┌ Info: train
# │   epoch = 49
# │   step = 100
# └   loss = 17.320087f0
# ┌ Info: train
# │   epoch = 49
# │   step = 125
# └   loss = 23.540567f0
# ┌ Info: train
# │   epoch = 49
# │   step = 150
# └   loss = 19.147991f0
# ┌ Info: train
# │   epoch = 50
# │   step = 25
# └   loss = 18.83776f0
# ┌ Info: train
# │   epoch = 50
# │   step = 50
# └   loss = 21.327303f0
# ┌ Info: train
# │   epoch = 50
# │   step = 75
# └   loss = 19.39455f0
# ┌ Info: train
# │   epoch = 50
# │   step = 100
# └   loss = 22.208961f0
# ┌ Info: train
# │   epoch = 50
# │   step = 125
# └   loss = 21.616371f0
# ┌ Info: train
# │   epoch = 50
# │   step = 150
# └   loss = 23.594536f0
# ┌ Info: train
# │   epoch = 51
# │   step = 25
# └   loss = 23.58604f0
# ┌ Info: train
# │   epoch = 51
# │   step = 50
# └   loss = 21.868906f0
# ┌ Info: train
# │   epoch = 51
# │   step = 75
# └   loss = 20.821358f0
# ┌ Info: train
# │   epoch = 51
# │   step = 100
# └   loss = 22.95021f0
# ┌ Info: train
# │   epoch = 51
# │   step = 125
# └   loss = 23.622738f0
# ┌ Info: train
# │   epoch = 51
# │   step = 150
# └   loss = 22.146685f0
# ┌ Info: train
# │   epoch = 52
# │   step = 25
# └   loss = 22.15935f0
# ┌ Info: train
# │   epoch = 52
# │   step = 50
# └   loss = 25.340935f0
# ┌ Info: train
# │   epoch = 52
# │   step = 75
# └   loss = 21.693542f0
# ┌ Info: train
# │   epoch = 52
# │   step = 100
# └   loss = 20.80805f0
# ┌ Info: train
# │   epoch = 52
# │   step = 125
# └   loss = 26.283953f0
# ┌ Info: train
# │   epoch = 52
# │   step = 150
# └   loss = 22.714622f0
# ┌ Info: train
# │   epoch = 53
# │   step = 25
# └   loss = 23.754047f0
# ┌ Info: train
# │   epoch = 53
# │   step = 50
# └   loss = 22.48253f0
# ┌ Info: train
# │   epoch = 53
# │   step = 75
# └   loss = 23.189365f0
# ┌ Info: train
# │   epoch = 53
# │   step = 100
# └   loss = 18.135786f0
# ┌ Info: train
# │   epoch = 53
# │   step = 125
# └   loss = 20.220694f0
# ┌ Info: train
# │   epoch = 53
# │   step = 150
# └   loss = 22.33191f0
# ┌ Info: train
# │   epoch = 54
# │   step = 25
# └   loss = 21.619081f0
# ┌ Info: train
# │   epoch = 54
# │   step = 50
# └   loss = 20.133217f0
# ┌ Info: train
# │   epoch = 54
# │   step = 75
# └   loss = 21.216085f0
# ┌ Info: train
# │   epoch = 54
# │   step = 100
# └   loss = 23.81441f0
# ┌ Info: train
# │   epoch = 54
# │   step = 125
# └   loss = 20.997604f0
# ┌ Info: train
# │   epoch = 54
# │   step = 150
# └   loss = 24.05939f0
# ┌ Info: train
# │   epoch = 55
# │   step = 25
# └   loss = 16.644253f0
# ┌ Info: train
# │   epoch = 55
# │   step = 50
# └   loss = 21.239815f0
# ┌ Info: train
# │   epoch = 55
# │   step = 75
# └   loss = 21.43597f0
# ┌ Info: train
# │   epoch = 55
# │   step = 100
# └   loss = 16.8848f0
# ┌ Info: train
# │   epoch = 55
# │   step = 125
# └   loss = 20.401718f0
# ┌ Info: train
# │   epoch = 55
# │   step = 150
# └   loss = 19.64897f0
# ┌ Info: train
# │   epoch = 56
# │   step = 25
# └   loss = 20.992f0
# ┌ Info: train
# │   epoch = 56
# │   step = 50
# └   loss = 21.69675f0
# ┌ Info: train
# │   epoch = 56
# │   step = 75
# └   loss = 21.861366f0
# ┌ Info: train
# │   epoch = 56
# │   step = 100
# └   loss = 21.179195f0
# ┌ Info: train
# │   epoch = 56
# │   step = 125
# └   loss = -11.587956f0
# ┌ Info: train
# │   epoch = 56
# │   step = 150
# └   loss = 20.98692f0
# ┌ Info: train
# │   epoch = 57
# │   step = 25
# └   loss = 19.81665f0
# ┌ Info: train
# │   epoch = 57
# │   step = 50
# └   loss = 20.926167f0
# ┌ Info: train
# │   epoch = 57
# │   step = 75
# └   loss = 20.971962f0
# ┌ Info: train
# │   epoch = 57
# │   step = 100
# └   loss = 22.27145f0
# ┌ Info: train
# │   epoch = 57
# │   step = 125
# └   loss = 20.326494f0
# ┌ Info: train
# │   epoch = 57
# │   step = 150
# └   loss = 24.14252f0
# ┌ Info: train
# │   epoch = 58
# │   step = 25
# └   loss = 19.31263f0
# ┌ Info: train
# │   epoch = 58
# │   step = 50
# └   loss = 21.074333f0
# ┌ Info: train
# │   epoch = 58
# │   step = 75
# └   loss = 21.830984f0
# ┌ Info: train
# │   epoch = 58
# │   step = 100
# └   loss = 22.307228f0
# ┌ Info: train
# │   epoch = 58
# │   step = 125
# └   loss = 19.105434f0
# ┌ Info: train
# │   epoch = 58
# │   step = 150
# └   loss = 22.807196f0
# ┌ Info: train
# │   epoch = 59
# │   step = 25
# └   loss = 22.067299f0
# ┌ Info: train
# │   epoch = 59
# │   step = 50
# └   loss = 21.049335f0
# ┌ Info: train
# │   epoch = 59
# │   step = 75
# └   loss = 19.681822f0
# ┌ Info: train
# │   epoch = 59
# │   step = 100
# └   loss = 21.253326f0
# ┌ Info: train
# │   epoch = 59
# │   step = 125
# └   loss = 17.409986f0
# ┌ Info: train
# │   epoch = 59
# │   step = 150
# └   loss = 19.683414f0
# ┌ Info: train
# │   epoch = 60
# │   step = 25
# └   loss = 24.863966f0
# ┌ Info: train
# │   epoch = 60
# │   step = 50
# └   loss = 15.980584f0
# ┌ Info: train
# │   epoch = 60
# │   step = 75
# └   loss = 23.086948f0
# ┌ Info: train
# │   epoch = 60
# │   step = 100
# └   loss = 21.897078f0
# ┌ Info: train
# │   epoch = 60
# │   step = 125
# └   loss = 22.529032f0
# ┌ Info: train
# │   epoch = 60
# │   step = 150
# └   loss = 24.82579f0
# ┌ Info: train
# │   epoch = 61
# │   step = 25
# └   loss = 23.25418f0
# ┌ Info: train
# │   epoch = 61
# │   step = 50
# └   loss = 21.34762f0
# ┌ Info: train
# │   epoch = 61
# │   step = 75
# └   loss = 21.448723f0
# ┌ Info: train
# │   epoch = 61
# │   step = 100
# └   loss = 18.228636f0
# ┌ Info: train
# │   epoch = 61
# │   step = 125
# └   loss = 18.144558f0
# ┌ Info: train
# │   epoch = 61
# │   step = 150
# └   loss = 19.490255f0
# ┌ Info: train
# │   epoch = 62
# │   step = 25
# └   loss = 20.441963f0
# ┌ Info: train
# │   epoch = 62
# │   step = 50
# └   loss = 18.559408f0
# ┌ Info: train
# │   epoch = 62
# │   step = 75
# └   loss = 22.865923f0
# ┌ Info: train
# │   epoch = 62
# │   step = 100
# └   loss = 20.954279f0
# ┌ Info: train
# │   epoch = 62
# │   step = 125
# └   loss = 20.403667f0
# ┌ Info: train
# │   epoch = 62
# │   step = 150
# └   loss = 22.830547f0
# ┌ Info: train
# │   epoch = 63
# │   step = 25
# └   loss = 21.544434f0
# ┌ Info: train
# │   epoch = 63
# │   step = 50
# └   loss = 21.088642f0
# ┌ Info: train
# │   epoch = 63
# │   step = 75
# └   loss = 5.486371f0
# ┌ Info: train
# │   epoch = 63
# │   step = 100
# └   loss = 21.702126f0
# ┌ Info: train
# │   epoch = 63
# │   step = 125
# └   loss = 18.829082f0
# ┌ Info: train
# │   epoch = 63
# │   step = 150
# └   loss = 19.889729f0
# ┌ Info: train
# │   epoch = 64
# │   step = 25
# └   loss = 20.04778f0
# ┌ Info: train
# │   epoch = 64
# │   step = 50
# └   loss = 23.33698f0
# ┌ Info: train
# │   epoch = 64
# │   step = 75
# └   loss = 21.940506f0
# ┌ Info: train
# │   epoch = 64
# │   step = 100
# └   loss = 22.096375f0
# ┌ Info: train
# │   epoch = 64
# │   step = 125
# └   loss = 21.802752f0
# ┌ Info: train
# │   epoch = 64
# │   step = 150
# └   loss = 22.215298f0
# ┌ Info: train
# │   epoch = 65
# │   step = 25
# └   loss = 21.598557f0
# ┌ Info: train
# │   epoch = 65
# │   step = 50
# └   loss = 23.455418f0
# ┌ Info: train
# │   epoch = 65
# │   step = 75
# └   loss = 23.71409f0
# ┌ Info: train
# │   epoch = 65
# │   step = 100
# └   loss = 21.750744f0
# ┌ Info: train
# │   epoch = 65
# │   step = 125
# └   loss = 21.510859f0
# ┌ Info: train
# │   epoch = 65
# │   step = 150
# └   loss = 19.624943f0
# ┌ Info: train
# │   epoch = 66
# │   step = 25
# └   loss = 22.001049f0
# ┌ Info: train
# │   epoch = 66
# │   step = 50
# └   loss = 22.153976f0
# ┌ Info: train
# │   epoch = 66
# │   step = 75
# └   loss = 21.199299f0
# ┌ Info: train
# │   epoch = 66
# │   step = 100
# └   loss = 23.778515f0
# ┌ Info: train
# │   epoch = 66
# │   step = 125
# └   loss = 22.019203f0
# ┌ Info: train
# │   epoch = 66
# │   step = 150
# └   loss = 21.27776f0
# ┌ Info: train
# │   epoch = 67
# │   step = 25
# └   loss = 23.881886f0
# ┌ Info: train
# │   epoch = 67
# │   step = 50
# └   loss = 22.737415f0
# ┌ Info: train
# │   epoch = 67
# │   step = 75
# └   loss = 19.321026f0
# ┌ Info: train
# │   epoch = 67
# │   step = 100
# └   loss = 21.270313f0
# ┌ Info: train
# │   epoch = 67
# │   step = 125
# └   loss = 20.653442f0
# ┌ Info: train
# │   epoch = 67
# │   step = 150
# └   loss = 22.653757f0
# ┌ Info: train
# │   epoch = 68
# │   step = 25
# └   loss = 22.06898f0
# ┌ Info: train
# │   epoch = 68
# │   step = 50
# └   loss = 21.069595f0
# ┌ Info: train
# │   epoch = 68
# │   step = 75
# └   loss = 21.993654f0
# ┌ Info: train
# │   epoch = 68
# │   step = 100
# └   loss = 23.809895f0
# ┌ Info: train
# │   epoch = 68
# │   step = 125
# └   loss = 23.706173f0
# ┌ Info: train
# │   epoch = 68
# │   step = 150
# └   loss = 22.573029f0
# ┌ Info: train
# │   epoch = 69
# │   step = 25
# └   loss = 23.283886f0
# ┌ Info: train
# │   epoch = 69
# │   step = 50
# └   loss = 23.783833f0
# ┌ Info: train
# │   epoch = 69
# │   step = 75
# └   loss = 23.422552f0
# ┌ Info: train
# │   epoch = 69
# │   step = 100
# └   loss = 24.811619f0
# ┌ Info: train
# │   epoch = 69
# │   step = 125
# └   loss = 25.002556f0
# ┌ Info: train
# │   epoch = 69
# │   step = 150
# └   loss = 20.116966f0
# ┌ Info: train
# │   epoch = 70
# │   step = 25
# └   loss = 23.023243f0
# ┌ Info: train
# │   epoch = 70
# │   step = 50
# └   loss = 21.249037f0
# ┌ Info: train
# │   epoch = 70
# │   step = 75
# └   loss = 22.984207f0
# ┌ Info: train
# │   epoch = 70
# │   step = 100
# └   loss = 21.499313f0
# ┌ Info: train
# │   epoch = 70
# │   step = 125
# └   loss = 23.772282f0
# ┌ Info: train
# │   epoch = 70
# │   step = 150
# └   loss = 20.921055f0
# ┌ Info: train
# │   epoch = 71
# │   step = 25
# └   loss = 20.7816f0
# ┌ Info: train
# │   epoch = 71
# │   step = 50
# └   loss = 19.670277f0
# ┌ Info: train
# │   epoch = 71
# │   step = 75
# └   loss = 23.296196f0
# ┌ Info: train
# │   epoch = 71
# │   step = 100
# └   loss = 23.030935f0
# ┌ Info: train
# │   epoch = 71
# │   step = 125
# └   loss = 23.194506f0
# ┌ Info: train
# │   epoch = 71
# │   step = 150
# └   loss = 22.43831f0
# ┌ Info: train
# │   epoch = 72
# │   step = 25
# └   loss = 22.557142f0
# ┌ Info: train
# │   epoch = 72
# │   step = 50
# └   loss = 24.490828f0
# ┌ Info: train
# │   epoch = 72
# │   step = 75
# └   loss = 21.104092f0
# ┌ Info: train
# │   epoch = 72
# │   step = 100
# └   loss = 18.674341f0
# ┌ Info: train
# │   epoch = 72
# │   step = 125
# └   loss = 19.07388f0
# ┌ Info: train
# │   epoch = 72
# │   step = 150
# └   loss = 22.306126f0
# ┌ Info: train
# │   epoch = 73
# │   step = 25
# └   loss = 22.135044f0
# ┌ Info: train
# │   epoch = 73
# │   step = 50
# └   loss = 20.159412f0
# ┌ Info: train
# │   epoch = 73
# │   step = 75
# └   loss = 22.045418f0
# ┌ Info: train
# │   epoch = 73
# │   step = 100
# └   loss = 24.40194f0
# ┌ Info: train
# │   epoch = 73
# │   step = 125
# └   loss = 23.572552f0
# ┌ Info: train
# │   epoch = 73
# │   step = 150
# └   loss = 19.981903f0
# ┌ Info: train
# │   epoch = 74
# │   step = 25
# └   loss = 23.257917f0
# ┌ Info: train
# │   epoch = 74
# │   step = 50
# └   loss = 22.122993f0
# ┌ Info: train
# │   epoch = 74
# │   step = 75
# └   loss = 20.006748f0
# ┌ Info: train
# │   epoch = 74
# │   step = 100
# └   loss = 21.172253f0
# ┌ Info: train
# │   epoch = 74
# │   step = 125
# └   loss = 21.008356f0
# ┌ Info: train
# │   epoch = 74
# │   step = 150
# └   loss = 20.84019f0
# ┌ Info: train
# │   epoch = 75
# │   step = 25
# └   loss = 23.151068f0
# ┌ Info: train
# │   epoch = 75
# │   step = 50
# └   loss = 23.485172f0
# ┌ Info: train
# │   epoch = 75
# │   step = 75
# └   loss = 23.153769f0
# ┌ Info: train
# │   epoch = 75
# │   step = 100
# └   loss = 21.290163f0
# ┌ Info: train
# │   epoch = 75
# │   step = 125
# └   loss = 21.762228f0
# ┌ Info: train
# │   epoch = 75
# │   step = 150
# └   loss = 21.199116f0
# ┌ Info: train
# │   epoch = 76
# │   step = 25
# └   loss = 17.930504f0
# ┌ Info: train
# │   epoch = 76
# │   step = 50
# └   loss = 23.04787f0
# ┌ Info: train
# │   epoch = 76
# │   step = 75
# └   loss = 20.809868f0
# ┌ Info: train
# │   epoch = 76
# │   step = 100
# └   loss = 21.353975f0
# ┌ Info: train
# │   epoch = 76
# │   step = 125
# └   loss = 19.562157f0
# ┌ Info: train
# │   epoch = 76
# │   step = 150
# └   loss = 16.483915f0
# ┌ Info: train
# │   epoch = 77
# │   step = 25
# └   loss = 19.138283f0
# ┌ Info: train
# │   epoch = 77
# │   step = 50
# └   loss = 18.523014f0
# ┌ Info: train
# │   epoch = 77
# │   step = 75
# └   loss = 18.520844f0
# ┌ Info: train
# │   epoch = 77
# │   step = 100
# └   loss = 23.04196f0
# ┌ Info: train
# │   epoch = 77
# │   step = 125
# └   loss = 21.441517f0
# ┌ Info: train
# │   epoch = 77
# │   step = 150
# └   loss = 20.367897f0
# ┌ Info: train
# │   epoch = 78
# │   step = 25
# └   loss = 20.163624f0
# ┌ Info: train
# │   epoch = 78
# │   step = 50
# └   loss = 21.393862f0
# ┌ Info: train
# │   epoch = 78
# │   step = 75
# └   loss = 19.718964f0
# ┌ Info: train
# │   epoch = 78
# │   step = 100
# └   loss = 21.644243f0
# ┌ Info: train
# │   epoch = 78
# │   step = 125
# └   loss = 22.149078f0
# ┌ Info: train
# │   epoch = 78
# │   step = 150
# └   loss = 20.814312f0
# ┌ Info: train
# │   epoch = 79
# │   step = 25
# └   loss = 22.866508f0
# ┌ Info: train
# │   epoch = 79
# │   step = 50
# └   loss = 20.337425f0
# ┌ Info: train
# │   epoch = 79
# │   step = 75
# └   loss = 21.624027f0
# ┌ Info: train
# │   epoch = 79
# │   step = 100
# └   loss = 20.402237f0
# ┌ Info: train
# │   epoch = 79
# │   step = 125
# └   loss = 23.410057f0
# ┌ Info: train
# │   epoch = 79
# │   step = 150
# └   loss = 20.08833f0
# ┌ Info: train
# │   epoch = 80
# │   step = 25
# └   loss = 24.47953f0
# ┌ Info: train
# │   epoch = 80
# │   step = 50
# └   loss = 21.978199f0
# ┌ Info: train
# │   epoch = 80
# │   step = 75
# └   loss = 21.085361f0
# ┌ Info: train
# │   epoch = 80
# │   step = 100
# └   loss = 21.211655f0
# ┌ Info: train
# │   epoch = 80
# │   step = 125
# └   loss = 20.508362f0
# ┌ Info: train
# │   epoch = 80
# │   step = 150
# └   loss = 20.466614f0
# ┌ Info: train
# │   epoch = 81
# │   step = 25
# └   loss = 22.391834f0
# ┌ Info: train
# │   epoch = 81
# │   step = 50
# └   loss = 24.903198f0
# ┌ Info: train
# │   epoch = 81
# │   step = 75
# └   loss = 19.485249f0
# ┌ Info: train
# │   epoch = 81
# │   step = 100
# └   loss = 22.64059f0
# ┌ Info: train
# │   epoch = 81
# │   step = 125
# └   loss = 21.317387f0
# ┌ Info: train
# │   epoch = 81
# │   step = 150
# └   loss = 21.682806f0
# ┌ Info: train
# │   epoch = 82
# │   step = 25
# └   loss = 21.254333f0
# ┌ Info: train
# │   epoch = 82
# │   step = 50
# └   loss = 22.734877f0
# ┌ Info: train
# │   epoch = 82
# │   step = 75
# └   loss = 22.537487f0
# ┌ Info: train
# │   epoch = 82
# │   step = 100
# └   loss = 20.094929f0
# ┌ Info: train
# │   epoch = 82
# │   step = 125
# └   loss = 21.800623f0
# ┌ Info: train
# │   epoch = 82
# │   step = 150
# └   loss = 19.080275f0
# ┌ Info: train
# │   epoch = 83
# │   step = 25
# └   loss = 22.002201f0
# ┌ Info: train
# │   epoch = 83
# │   step = 50
# └   loss = 22.30722f0
# ┌ Info: train
# │   epoch = 83
# │   step = 75
# └   loss = 22.413658f0
# ┌ Info: train
# │   epoch = 83
# │   step = 100
# └   loss = 24.382023f0
# ┌ Info: train
# │   epoch = 83
# │   step = 125
# └   loss = 20.645979f0
# ┌ Info: train
# │   epoch = 83
# │   step = 150
# └   loss = 19.672878f0
# ┌ Info: train
# │   epoch = 84
# │   step = 25
# └   loss = 21.800962f0
# ┌ Info: train
# │   epoch = 84
# │   step = 50
# └   loss = 21.22847f0
# ┌ Info: train
# │   epoch = 84
# │   step = 75
# └   loss = 19.500309f0
# ┌ Info: train
# │   epoch = 84
# │   step = 100
# └   loss = 25.74908f0
# ┌ Info: train
# │   epoch = 84
# │   step = 125
# └   loss = 22.878939f0
# ┌ Info: train
# │   epoch = 84
# │   step = 150
# └   loss = 19.335938f0
# ┌ Info: train
# │   epoch = 85
# │   step = 25
# └   loss = 18.956377f0
# ┌ Info: train
# │   epoch = 85
# │   step = 50
# └   loss = 22.555515f0
# ┌ Info: train
# │   epoch = 85
# │   step = 75
# └   loss = 23.946405f0
# ┌ Info: train
# │   epoch = 85
# │   step = 100
# └   loss = 22.589813f0
# ┌ Info: train
# │   epoch = 85
# │   step = 125
# └   loss = 20.090248f0
# ┌ Info: train
# │   epoch = 85
# │   step = 150
# └   loss = 21.336586f0
# ┌ Info: train
# │   epoch = 86
# │   step = 25
# └   loss = 21.855642f0
# ┌ Info: train
# │   epoch = 86
# │   step = 50
# └   loss = 19.779556f0
# ┌ Info: train
# │   epoch = 86
# │   step = 75
# └   loss = 23.152008f0
# ┌ Info: train
# │   epoch = 86
# │   step = 100
# └   loss = 21.799198f0
# ┌ Info: train
# │   epoch = 86
# │   step = 125
# └   loss = 23.729807f0
# ┌ Info: train
# │   epoch = 86
# │   step = 150
# └   loss = 24.73042f0
# ┌ Info: train
# │   epoch = 87
# │   step = 25
# └   loss = 19.806095f0
# ┌ Info: train
# │   epoch = 87
# │   step = 50
# └   loss = 22.405361f0
# ┌ Info: train
# │   epoch = 87
# │   step = 75
# └   loss = 21.57449f0
# ┌ Info: train
# │   epoch = 87
# │   step = 100
# └   loss = 21.7407f0
# ┌ Info: train
# │   epoch = 87
# │   step = 125
# └   loss = 22.59734f0
# ┌ Info: train
# │   epoch = 87
# │   step = 150
# └   loss = 20.25967f0
# ┌ Info: train
# │   epoch = 88
# │   step = 25
# └   loss = 19.743744f0
# ┌ Info: train
# │   epoch = 88
# │   step = 50
# └   loss = 19.98431f0
# ┌ Info: train
# │   epoch = 88
# │   step = 75
# └   loss = 15.31344f0
# ┌ Info: train
# │   epoch = 88
# │   step = 100
# └   loss = 20.085484f0
# ┌ Info: train
# │   epoch = 88
# │   step = 125
# └   loss = 22.487297f0
# ┌ Info: train
# │   epoch = 88
# │   step = 150
# └   loss = 22.491331f0
# ┌ Info: train
# │   epoch = 89
# │   step = 25
# └   loss = 16.660719f0
# ┌ Info: train
# │   epoch = 89
# │   step = 50
# └   loss = 22.529898f0
# ┌ Info: train
# │   epoch = 89
# │   step = 75
# └   loss = 21.550985f0
# ┌ Info: train
# │   epoch = 89
# │   step = 100
# └   loss = 20.375748f0
# ┌ Info: train
# │   epoch = 89
# │   step = 125
# └   loss = 22.937206f0
# ┌ Info: train
# │   epoch = 89
# │   step = 150
# └   loss = 19.631706f0
# ┌ Info: train
# │   epoch = 90
# │   step = 25
# └   loss = 17.535595f0
# ┌ Info: train
# │   epoch = 90
# │   step = 50
# └   loss = 18.669437f0
# ┌ Info: train
# │   epoch = 90
# │   step = 75
# └   loss = 21.55685f0
# ┌ Info: train
# │   epoch = 90
# │   step = 100
# └   loss = 23.808851f0
# ┌ Info: train
# │   epoch = 90
# │   step = 125
# └   loss = 24.87554f0
# ┌ Info: train
# │   epoch = 90
# │   step = 150
# └   loss = 21.389326f0
# ┌ Info: train
# │   epoch = 91
# │   step = 25
# └   loss = 22.405817f0
# ┌ Info: train
# │   epoch = 91
# │   step = 50
# └   loss = 22.464638f0
# ┌ Info: train
# │   epoch = 91
# │   step = 75
# └   loss = 20.111252f0
# ┌ Info: train
# │   epoch = 91
# │   step = 100
# └   loss = 24.999516f0
# ┌ Info: train
# │   epoch = 91
# │   step = 125
# └   loss = 20.218391f0
# ┌ Info: train
# │   epoch = 91
# │   step = 150
# └   loss = 20.187355f0
# ┌ Info: train
# │   epoch = 92
# │   step = 25
# └   loss = 21.420967f0
# ┌ Info: train
# │   epoch = 92
# │   step = 50
# └   loss = 23.060745f0
# ┌ Info: train
# │   epoch = 92
# │   step = 75
# └   loss = 21.60073f0
# ┌ Info: train
# │   epoch = 92
# │   step = 100
# └   loss = 23.225628f0
# ┌ Info: train
# │   epoch = 92
# │   step = 125
# └   loss = 19.36546f0
# ┌ Info: train
# │   epoch = 92
# │   step = 150
# └   loss = 20.678913f0
# ┌ Info: train
# │   epoch = 93
# │   step = 25
# └   loss = 21.350622f0
# ┌ Info: train
# │   epoch = 93
# │   step = 50
# └   loss = 20.95152f0
# ┌ Info: train
# │   epoch = 93
# │   step = 75
# └   loss = 22.601427f0
# ┌ Info: train
# │   epoch = 93
# │   step = 100
# └   loss = 18.351856f0
# ┌ Info: train
# │   epoch = 93
# │   step = 125
# └   loss = 22.845188f0
# ┌ Info: train
# │   epoch = 93
# │   step = 150
# └   loss = 21.619637f0
# ┌ Info: train
# │   epoch = 94
# │   step = 25
# └   loss = 21.598852f0
# ┌ Info: train
# │   epoch = 94
# │   step = 50
# └   loss = 24.265049f0
# ┌ Info: train
# │   epoch = 94
# │   step = 75
# └   loss = 25.088186f0
# ┌ Info: train
# │   epoch = 94
# │   step = 100
# └   loss = 20.131905f0
# ┌ Info: train
# │   epoch = 94
# │   step = 125
# └   loss = 21.927309f0
# ┌ Info: train
# │   epoch = 94
# │   step = 150
# └   loss = 22.709093f0
# ┌ Info: train
# │   epoch = 95
# │   step = 25
# └   loss = 22.480736f0
# ┌ Info: train
# │   epoch = 95
# │   step = 50
# └   loss = 18.990673f0
# ┌ Info: train
# │   epoch = 95
# │   step = 75
# └   loss = 21.88835f0
# ┌ Info: train
# │   epoch = 95
# │   step = 100
# └   loss = 21.45876f0
# ┌ Info: train
# │   epoch = 95
# │   step = 125
# └   loss = 21.846493f0
# ┌ Info: train
# │   epoch = 95
# │   step = 150
# └   loss = 21.63565f0
# ┌ Info: train
# │   epoch = 96
# │   step = 25
# └   loss = 21.12495f0
# ┌ Info: train
# │   epoch = 96
# │   step = 50
# └   loss = 21.763638f0
# ┌ Info: train
# │   epoch = 96
# │   step = 75
# └   loss = 20.331306f0
# ┌ Info: train
# │   epoch = 96
# │   step = 100
# └   loss = 23.594742f0
# ┌ Info: train
# │   epoch = 96
# │   step = 125
# └   loss = 20.491268f0
# ┌ Info: train
# │   epoch = 96
# │   step = 150
# └   loss = 19.579607f0
# ┌ Info: train
# │   epoch = 97
# │   step = 25
# └   loss = 22.1447f0
# ┌ Info: train
# │   epoch = 97
# │   step = 50
# └   loss = 19.514366f0
# ┌ Info: train
# │   epoch = 97
# │   step = 75
# └   loss = 18.976524f0
# ┌ Info: train
# │   epoch = 97
# │   step = 100
# └   loss = 22.168167f0
# ┌ Info: train
# │   epoch = 97
# │   step = 125
# └   loss = 20.450222f0
# ┌ Info: train
# │   epoch = 97
# │   step = 150
# └   loss = 23.13343f0
# ┌ Info: train
# │   epoch = 98
# │   step = 25
# └   loss = 22.17472f0
# ┌ Info: train
# │   epoch = 98
# │   step = 50
# └   loss = 22.017311f0
# ┌ Info: train
# │   epoch = 98
# │   step = 75
# └   loss = 23.751623f0
# ┌ Info: train
# │   epoch = 98
# │   step = 100
# └   loss = 20.171782f0
# ┌ Info: train
# │   epoch = 98
# │   step = 125
# └   loss = 19.81949f0
# ┌ Info: train
# │   epoch = 98
# │   step = 150
# └   loss = 23.225515f0
# ┌ Info: train
# │   epoch = 99
# │   step = 25
# └   loss = 20.012215f0
# ┌ Info: train
# │   epoch = 99
# │   step = 50
# └   loss = 20.367924f0
# ┌ Info: train
# │   epoch = 99
# │   step = 75
# └   loss = 22.439997f0
# ┌ Info: train
# │   epoch = 99
# │   step = 100
# └   loss = 20.901167f0
# ┌ Info: train
# │   epoch = 99
# │   step = 125
# └   loss = 21.113953f0
# ┌ Info: train
# │   epoch = 99
# │   step = 150
# └   loss = 22.226475f0
# ┌ Info: train
# │   epoch = 100
# │   step = 25
# └   loss = 23.480293f0
# ┌ Info: train
# │   epoch = 100
# │   step = 50
# └   loss = 22.56205f0
# ┌ Info: train
# │   epoch = 100
# │   step = 75
# └   loss = 20.577469f0
# ┌ Info: train
# │   epoch = 100
# │   step = 100
# └   loss = 21.884739f0
# ┌ Info: train
# │   epoch = 100
# │   step = 125
# └   loss = 21.706923f0
# ┌ Info: train
# │   epoch = 100
# │   step = 150
# └   loss = 22.257725f0
# EditFlowModel(
#   Embedding(22 => 128),                 # 2_816 parameters
#   Chain(
#     RandomFourierFeatures{Float32, Matrix{Float32}}(Float32[4.107619 -1.6246507 … -3.6645346 -1.3967112]),
#     Dense(128 => 128),                  # 16_512 parameters
#   ),
#   [
#     TransformerBlock(
#       Attention(
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         identity,
#         identity,
#         Onion.var"#32#34"(),
#         16,
#         16,
#         8,
#         8,
#       ),
#       StarGLU(
#         Dense(128 => 512; bias=false),  # 65_536 parameters
#         Dense(512 => 128; bias=false),  # 65_536 parameters
#         Dense(128 => 512; bias=false),  # 65_536 parameters
#         NNlib.swish,
#       ),
#       AdaLN(
#         Onion.LayerNorm{Vector{Float32}, Vector{Float32}, Float32}(Float32[0.96080273, 0.93640083, 0.9547064, 0.8971493, 0.95765316, 0.92207366, 0.89724094, 0.9440924, 0.94302225, 0.94956416  …  0.94014513, 0.9212964, 0.91572565, 0.9039559, 0.9231686, 0.9042348, 0.9314332, 0.87426275, 0.8752597, 0.9407146], Float32[-0.025268404, 0.0020312557, -0.010115526, 0.020099802, 0.018506693, 0.0025694135, -0.023937318, -0.038941544, -0.038218282, -0.008356358  …  0.0045030406, 0.029052407, -0.039042093, -0.009993242, 0.003901428, -0.0070870365, -0.037610408, -0.06006574, 0.015338725, 0.011129025], 1.0f-6),  # 256 parameters
#         Dense(128 => 128),              # 16_512 parameters
#         Dense(128 => 128),              # 16_512 parameters
#       ),
#       AdaLN(
#         Onion.LayerNorm{Vector{Float32}, Vector{Float32}, Float32}(Float32[0.9615473, 0.97570944, 0.9112915, 0.96853894, 0.9237012, 0.9523371, 0.9733101, 0.9436969, 1.0086424, 0.98759335  …  0.96384525, 0.98503447, 0.9836052, 0.95819885, 0.969784, 0.9607591, 0.9873663, 1.0246212, 0.97779596, 0.963771], Float32[-0.027013712, -0.0054144724, 0.0071041402, -0.015267112, -0.05662798, -0.00019226706, 0.017086789, 0.010009103, 0.004368342, -0.022684177  …  0.008213096, 0.01543913, 0.008588103, -0.042858012, 0.005013047, -0.0087100575, -0.00035417278, -0.0044492367, -3.3963931f-6, -0.0070771035], 1.0f-6),  # 256 parameters
#         Dense(128 => 128),              # 16_512 parameters
#         Dense(128 => 128),              # 16_512 parameters
#       ),
#       identity,
#     ),
#     TransformerBlock(
#       Attention(
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         identity,
#         identity,
#         Onion.var"#32#34"(),
#         16,
#         16,
#         8,
#         8,
#       ),
#       StarGLU(
#         Dense(128 => 512; bias=false),  # 65_536 parameters
#         Dense(512 => 128; bias=false),  # 65_536 parameters
#         Dense(128 => 512; bias=false),  # 65_536 parameters
#         NNlib.swish,
#       ),
#       AdaLN(
#         Onion.LayerNorm{Vector{Float32}, Vector{Float32}, Float32}(Float32[0.94601697, 0.97375804, 0.9406857, 0.953404, 0.95697165, 0.9183645, 0.93461883, 0.93530893, 0.98690313, 0.92145735  …  0.8612234, 0.87250346, 0.98907375, 0.956685, 0.9498322, 0.9437079, 0.9624967, 0.949929, 0.97197264, 0.97001827], Float32[0.0011167054, -0.014636964, 0.0022019444, 0.0121619, -0.013723163, 0.001547043, 0.011414896, -0.0012122085, -0.006493586, -0.021626603  …  0.069353715, -0.012018405, 0.004048702, 0.004974579, -0.017438088, -0.010104225, -0.009309289, 4.483607f-5, -0.012501754, -0.006304365], 1.0f-6),  # 256 parameters
#         Dense(128 => 128),              # 16_512 parameters
#         Dense(128 => 128),              # 16_512 parameters
#       ),
#       AdaLN(
#         Onion.LayerNorm{Vector{Float32}, Vector{Float32}, Float32}(Float32[0.97332007, 1.0309724, 0.9687911, 0.97576725, 0.96835095, 0.9971229, 0.993208, 0.9710502, 1.003863, 0.9820828  …  0.982708, 0.92708766, 1.0036467, 0.9794132, 0.99849373, 0.9908135, 0.9964946, 1.0093178, 0.9900424, 0.9617081], Float32[-0.016477505, -0.014338043, 0.040039297, -0.029744757, -0.029461078, -0.041657545, 0.027084501, 0.041064046, -0.025039643, 0.0060120723  …  0.0095715625, -0.0138390735, 0.0026735286, -0.050670695, -0.024575308, 0.006731998, -0.007667666, -6.0379556f-5, -0.0033010722, -0.048479233], 1.0f-6),  # 256 parameters
#         Dense(128 => 128),              # 16_512 parameters
#         Dense(128 => 128),              # 16_512 parameters
#       ),
#       identity,
#     ),
#     TransformerBlock(
#       Attention(
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         identity,
#         identity,
#         Onion.var"#32#34"(),
#         16,
#         16,
#         8,
#         8,
#       ),
#       StarGLU(
#         Dense(128 => 512; bias=false),  # 65_536 parameters
#         Dense(512 => 128; bias=false),  # 65_536 parameters
#         Dense(128 => 512; bias=false),  # 65_536 parameters
#         NNlib.swish,
#       ),
#       AdaLN(
#         Onion.LayerNorm{Vector{Float32}, Vector{Float32}, Float32}(Float32[0.94413495, 0.9591206, 0.9815761, 0.9860674, 0.9643858, 0.99948543, 0.95805496, 0.9728332, 0.9892072, 0.93138975  …  0.92429256, 1.0070444, 0.9443377, 0.9681403, 0.9447193, 0.9323913, 0.9746358, 0.99652237, 0.96340334, 0.97654444], Float32[-0.03537166, -0.006217378, -0.007379122, 0.009719772, -0.0314247, 0.016313963, -0.0015389565, 0.021076221, 0.010470716, -0.02639406  …  0.0006755494, 0.005295955, 0.017049158, -0.0132954335, 0.005307746, 0.02653267, -0.008163272, 0.009826559, 0.030178566, -0.0014013725], 1.0f-6),  # 256 parameters
#         Dense(128 => 128),              # 16_512 parameters
#         Dense(128 => 128),              # 16_512 parameters
#       ),
#       AdaLN(
#         Onion.LayerNorm{Vector{Float32}, Vector{Float32}, Float32}(Float32[0.93666166, 1.0321827, 0.9726321, 0.98780626, 0.9613221, 1.0248475, 1.0161513, 0.96915793, 0.9948018, 1.0429728  …  1.0270013, 1.0185184, 1.0062677, 0.9811149, 1.0302101, 1.0181782, 1.0179951, 1.0333631, 1.0274625, 0.9702701], Float32[-0.06427912, 0.002420664, 0.047289338, -0.034010448, -0.03299984, -0.013876393, 0.023457177, 0.020834371, 0.010680823, -0.032694057  …  -0.003318202, -0.0250829, 0.027400794, -0.031808987, -0.024685763, -0.00258377, -0.011304101, -0.01021114, -0.0004895934, -0.020227717], 1.0f-6),  # 256 parameters
#         Dense(128 => 128),              # 16_512 parameters
#         Dense(128 => 128),              # 16_512 parameters
#       ),
#       identity,
#     ),
#     TransformerBlock(
#       Attention(
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         identity,
#         identity,
#         Onion.var"#32#34"(),
#         16,
#         16,
#         8,
#         8,
#       ),
#       StarGLU(
#         Dense(128 => 512; bias=false),  # 65_536 parameters
#         Dense(512 => 128; bias=false),  # 65_536 parameters
#         Dense(128 => 512; bias=false),  # 65_536 parameters
#         NNlib.swish,
#       ),
#       AdaLN(
#         Onion.LayerNorm{Vector{Float32}, Vector{Float32}, Float32}(Float32[0.98147184, 0.9223102, 1.0042982, 0.97599345, 0.98011535, 0.9964276, 0.9762427, 0.94932944, 0.96026486, 0.95611215  …  0.9575027, 0.9455124, 0.99811995, 0.9754665, 0.9862882, 0.9942666, 0.9694813, 0.96348906, 0.95470506, 0.9039463], Float32[-0.014831864, 9.283005f-5, -0.008477221, 0.040162712, 0.022272639, 0.0436828, -0.009014154, 0.055058725, 0.030263849, -0.040652655  …  -0.010325852, -0.023909276, 0.009594226, 0.00861934, -0.0045753345, -0.015833346, 0.019944627, 0.011142825, 0.025711212, 0.026980491], 1.0f-6),  # 256 parameters
#         Dense(128 => 128),              # 16_512 parameters
#         Dense(128 => 128),              # 16_512 parameters
#       ),
#       AdaLN(
#         Onion.LayerNorm{Vector{Float32}, Vector{Float32}, Float32}(Float32[0.9566518, 1.0749155, 1.0178746, 1.0410086, 1.0265093, 1.0722593, 1.0385908, 1.0496945, 1.1038729, 1.003326  …  1.0357652, 1.005023, 1.0573806, 1.0052382, 0.98908836, 1.0178303, 1.110416, 1.0397507, 1.0142217, 1.0475482], Float32[-0.08760491, 0.051100586, 0.08073487, -0.080240734, -0.037350997, -0.064348176, 0.01896439, 0.012915793, 0.041853514, -0.02849257  …  -0.012428334, -0.040537376, 0.026203565, -0.026402708, -0.039873, -0.0071864277, 0.023559058, -0.015315336, 0.05209827, -0.06641875], 1.0f-6),  # 256 parameters
#         Dense(128 => 128),              # 16_512 parameters
#         Dense(128 => 128),              # 16_512 parameters
#       ),
#       identity,
#     ),
#   ],
#   Dense(128 => 41; bias=false),         # 5_248 parameters
#   RoPE{Matrix{Float32}}(Float32[1.0 0.5403023 … -0.87528455 -0.065975994; 1.0 0.95041525 … 0.9552474 0.8159282; … ; 1.0 0.9999995 … -0.57972294 -0.5789079; 1.0 0.99999994 … 0.2726629 0.27235872], Float32[0.0 0.84147096 … -0.48360822 -0.9978212; 0.0 0.3109836 … 0.29580808 0.5781532; … ; 0.0 0.0009999999 … -0.8148137 -0.8153929; 0.0 0.0003162278 … 0.9621096 0.9621958]),
#   20,
# )         # Total: 80 trainable arrays, 1_339_392 parameters,
#           # plus 3 non-trainable, 65_600 parameters, summarysize 5.364 MiB.

# %%
# Sampling and Levenshtein plot
using Random
n = 1000
# 100 model samples (final states → strings)
model_samples_any = sample_gen_n(P, model; n=n, ts=0f0:0.01f0:1f0, rng=Random.MersenneTwister(42))
model_final_states = map(final_state_from_gen, model_samples_any)
model_strings = [state_to_PM_string(P, s) for s in model_final_states]

# Build training strings from PM parents (the data PM was built on)
train_states = [FF.DiscreteState(P.k, sample(PM; rng=Random.MersenneTwister(1000+i))) for i in 1:100]
train_strings = [state_to_PM_string(P, s) for s in train_states]

# Independent validation strings sampled from PM
val_states = [FF.DiscreteState(P.k, sample(PM; rng=Random.MersenneTwister(1000+i+2*n))) for i in 1:n]
val_strings = [state_to_PM_string(P, s) for s in val_states]
#val_strings = [s for s in val_strings if !(s in train_strings)]

# Plot normalized Levenshtein vs. training set (distinct val/train)
plt = plot_lev_dist("model_vs_true", val_strings, model_strings, train_strings; title="Model vs True (normalized Levenshtein)")
display(plt)

# %%
model_strings_bos = [">" * state_to_PM_string(P, s) for s in model_final_states]
plt = plot_lev_dist("model_vs_true", val_strings, model_strings_bos, train_strings; title="Model vs True (normalized Levenshtein)")
display(plt)

# %%
pAA = plot_AA_dist("model_vs_true_AA", val_strings, model_strings; title="AA frequency: Natural vs Generated")
display(pAA)

pLen = plot_len_dist("model_vs_true_len", val_strings, model_strings; title="Length distribution: Natural vs Generated")
display(pLen)

# %%
println("Natural 'A' frequency: ", (isdefined(Main, :val_strings) ? sum(count(==('A'), s) for s in val_strings) / sum(length.(val_strings)) : sum(count(==('A'), s) for s in val_strings) / sum(length.(val_strings))))
# Out:
# Natural 'A' frequency: 0.047142480905978404

# %%
println("Natural 'A' frequency: ", (isdefined(Main, :model_strings) ? sum(count(==('A'), s) for s in model_strings) / sum(length.(model_strings)) : sum(count(==('A'), s) for s in model_strings) / sum(length.(model_strings))))
# Out:
# Natural 'A' frequency: 0.04109772423025435
