# %%
using Pkg
Pkg.activate(@__DIR__)
Pkg.instantiate()
using Revise

using Random
using Statistics
using Adapt
using Functors
using Flux
using Onion
using RandomFeatureMaps
using Zygote

Pkg.develop(path=joinpath(@__DIR__, ".."))
using Flowfusion
const FF = Flowfusion

include(joinpath(@__DIR__, "prob_model.jl"))
include(joinpath(@__DIR__, "helper_funcs.jl"))
# Out:
#   Activating project at `~/dev/Flowfusion.jl/editflow_code`
#    Resolving package versions...
#   No Changes to `~/dev/Flowfusion.jl/editflow_code/Project.toml`
#   No Changes to `~/dev/Flowfusion.jl/editflow_code/Manifest.toml`
# WARNING: using StatsBase.sample in module Main conflicts with an existing identifier.
# plot_len_dist (generic function with 1 method)

# %%
import CUDA

# Device helpers
const _gpu_enabled = try
    CUDA.has_cuda()
catch
    false
end

to_dev(x) = _gpu_enabled ? Adapt.adapt(CUDA.CuArray, x) : x
to_cpu(x) = _gpu_enabled ? Adapt.adapt(Array, x) : x
# move x to the same device type as y (Array or CuArray)
to_same_device(x, y) = (_gpu_enabled && (y isa CUDA.CuArray)) ? Adapt.adapt(CUDA.CuArray, x) : Adapt.adapt(Array, x)
# Out:
# to_same_device (generic function with 1 method)

# %%
# Minibatch builder (uses true PM)
function make_minibatch(B::Int, P::FF.EditFlow; rng=Random.default_rng())
    K = P.k
    x0s = Vector{FF.DiscreteState}(undef, B)
    x1s = Vector{FF.DiscreteState}(undef, B)
    for b in 1:B
        # x1 from true PM
        seq1 = sample(PM; rng=rng)
        @assert all(1 .<= seq1 .<= K)
        x1s[b] = FF.DiscreteState(K, seq1)
        # x0: uniform tokens with random length in 1:10 (no BOS in x0)
        L0 = rand(rng, 1:10)
        seq0 = rand(rng, 1:K, L0)
        x0s[b] = FF.DiscreteState(K, seq0)
    end
    ts = rand(rng, Float32, B)
    return x0s, x1s, ts
end
# Out:
# make_minibatch (generic function with 1 method)

# %%
# Model definition
struct EditFlowModel{L}
    layers::L
end
Flux.@layer EditFlowModel
#=
function EditFlowModel(; d=128, num_heads=8, nlayers=6, rff_dim=128, cond_dim=128, K::Int)
    embedding   = Flux.Embedding(K + 2 => d)
    time_embed  = Flux.Chain(RandomFourierFeatures(1 => rff_dim, 1.0f0), Dense(rff_dim => cond_dim))
    blocks      = [Onion.AdaTransformerBlock(d, cond_dim, num_heads) for _ in 1:nlayers]
    head_combined = Dense(d => 2K + 1, bias=false)
    rope        = RoPE(d ÷ num_heads, 4096)
    return EditFlowModel((; embedding, time_embed, blocks, head_combined, rope, K))
end
=#
function EditFlowModel(; d=128, num_heads=8, nlayers=6, rff_dim=128, cond_dim=128, K::Int)
    embedding   = Flux.Embedding(K + 2 => d)
    time_embed  = Flux.Chain(RandomFourierFeatures(1 => rff_dim, 1.0f0), Dense(rff_dim => cond_dim))
    blocks      = [Onion.AdaTransformerBlock(d, cond_dim, num_heads) for _ in 1:nlayers]
    ins_q = Dense(d => K, bias=false)
    sub_q = Dense(d => K, bias=false)
    ins_lambda = Dense(d => 1, bias=false)
    sub_lambda = Dense(d => 1, bias=false)
    del_lambda = Dense(d => 1, bias=false)
    rope        = RoPE(d ÷ num_heads, 4096)
    return EditFlowModel((; embedding, time_embed, blocks, ins_q, sub_q, ins_lambda, sub_lambda, del_lambda, rope, K))
end
# Out:
# EditFlowModel

# %%
# Forward pass
function (model::EditFlowModel)(t, Xt_ms)
    m = model.layers
    X = FF.tensor(Xt_ms)
    X = ndims(X) == 1 ? reshape(X, :, 1) : X
    L, B = size(X)

    pmask = Zygote.@ignore FF.getlmask(Xt_ms)
    Xp = X .+ 1
    #println("min/max X: ", minimum(X), " / ", maximum(X), "  pad=", P.padding_token, "  lat=", P.latent_token)
    if maximum(X) > P.padding_token
        error("X contains values greater than the padding token; illegal token values in input")
    end

    H = m.embedding(Xp)

    t = ndims(t) == 0 ? fill(Float32(t), B) : Float32.(t)
    cond = m.time_embed(reshape(t, 1, B))

    cond  = to_same_device(cond, H)
    pmask = Zygote.@ignore to_same_device(pmask, H)
    rope  = Zygote.@ignore to_same_device(m.rope[1:L], H)

    for blk in m.blocks
        H = blk(H; cond, rope, kpad_mask=pmask)
    end

    ins_head = m.ins_q(H)
    sub_head = m.sub_q(H)
    lambda_ins = m.ins_lambda(H)
    lambda_sub = m.sub_lambda(H)
    lambda_del = m.del_lambda(H)
    return (ins_head, sub_head, lambda_ins, lambda_sub, lambda_del)
end

# %%
# Forward pass
# function (model::EditFlowModel)(t, Xt_ms)
#     m = model.layers
#     X = FF.tensor(Xt_ms)
#     X = ndims(X) == 1 ? reshape(X, :, 1) : X
#     L, B = size(X)

#     pmask = Zygote.@ignore FF.getlmask(Xt_ms)
#     Xp = X .+ 1
#     #println("min/max X: ", minimum(X), " / ", maximum(X), "  pad=", P.padding_token, "  lat=", P.latent_token)
#     #@assert all((0 .<= X) .& (X .<= P.padding_token))
#     mX = Zygote.@ignore maximum(X)
#     nX = Zygote.@ignore minimum(X)
#     @assert (0 <= nX) && (mX <= P.padding_token)

    
#     H = m.embedding(Xp)

#     t = ndims(t) == 0 ? fill(Float32(t), B) : Float32.(t)
#     cond = m.time_embed(reshape(t, 1, B))

#     cond  = to_same_device(cond, H)
#     pmask = Zygote.@ignore to_same_device(pmask, H)
#     rope  = Zygote.@ignore to_same_device(m.rope[1:L], H)

#     for blk in m.blocks
#         H = blk(H; cond, rope, kpad_mask=pmask)
#     end
#     return m.head_combined(H)
# end

# %%
# Training (GPU if available)
function train_editflow!(P::FF.EditFlow,
                        model;
                        epochs::Int=1,
                        steps_per_epoch::Int=100,
                        batch_size::Int=64,
                        lr::Float32=1f-2,
                        seed::Int=42,
                        print_every::Int=25)

    rng = Random.MersenneTwister(seed)
    Random.seed!(seed)

    # Move model to device (GPU if available)
    model = Functors.fmap(to_dev, model)
    opt_state = Flux.setup(Flux.Adam(lr), model)

    for epoch in 1:epochs
        for step in 1:steps_per_epoch

            # 1) Minibatch Sampling
            x0s, x1s, ts = make_minibatch(batch_size, P; rng=rng)

            # 2) Align and batch
            Z0, Z1 = FF.align_and_batch(P, x0s, x1s)

            # 3) Interpolate
            Zt, Xt = FF.interpolate_Z_elementwise(P, Z0, Z1, ts)

            # 4) Prepend BOS
            bos = P.bos_token
            Zt = vcat(fill(bos, 1, batch_size), Zt)
            Xt = vcat(fill(bos, 1, batch_size), Xt)
            Z1 = vcat(fill(bos, 1, batch_size), Z1)
            
            # 5) Masks and multipliers
            transition_mask = FF.transition_mask_from_Xt(P, Xt)
            edit_multiplier = FF.remaining_edits(P, Zt, Z1, Xt)
            #@assert size(transition_mask) == size(edit_multiplier)

            # 6) Scheduler scaling
            den = 1f0 .- P.κ.(ts)
            den = max.(den, 1f-3)
            scheduler_scaling = P.dκ.(ts) ./ den

            # 7) Masked state
            lmask = Xt .!= P.padding_token
            cmask = trues(size(lmask))
            Xt_ms = FF.MaskedState(FF.DiscreteState(P.k, Xt), cmask, lmask)

            ts_d    = to_dev(ts)
            Xt_ms_d = to_dev(Xt_ms)
            Tmask_d = to_dev(transition_mask)
            Emult_d = to_dev(edit_multiplier)
            sched_d = to_dev(reshape(Float32.(scheduler_scaling), 1, 1, :))

            # 8) Forward + loss + update
            loss, grad = Flux.withgradient(model) do m
                M = m(ts_d, Xt_ms_d)
                l = FF.edit_loss(P, M, Tmask_d, Emult_d, sched_d; eps=1f-8)
                if isnan(l)
                    println("Maximum element of M: ", maximum(M))
                end
                l
            end
            Flux.update!(opt_state, model, grad[1])

            if step % print_every == 0
                @info "train" epoch step loss=Float32(loss)
            end
        end
    end

    return Functors.fmap(to_cpu, model)
end
# Out:
# train_editflow! (generic function with 1 method)

# %%
# Init process and model
K = PM.K
P = FF.EditFlow(K; bos_token=0, impl="positionwise_reparam")
model = EditFlowModel(; d=128, num_heads=8, nlayers=4, rff_dim=128, cond_dim=128, K=K)
nothing

# %%
model = train_editflow!(P, model; epochs=100, steps_per_epoch=150, batch_size=256, lr=1f-4)
# Out:
# ┌ Info: train
# │   epoch = 1
# │   step = 25
# └   loss = 82.07346f0
# ┌ Info: train
# │   epoch = 1
# │   step = 50
# └   loss = 62.159813f0
# ┌ Info: train
# │   epoch = 1
# │   step = 75
# └   loss = 54.437492f0
# ┌ Info: train
# │   epoch = 1
# │   step = 100
# └   loss = 52.70323f0
# ┌ Info: train
# │   epoch = 1
# │   step = 125
# └   loss = 46.34868f0
# ┌ Info: train
# │   epoch = 1
# │   step = 150
# └   loss = 47.708572f0
# ┌ Info: train
# │   epoch = 2
# │   step = 25
# └   loss = 46.801437f0
# ┌ Info: train
# │   epoch = 2
# │   step = 50
# └   loss = 43.88524f0
# ┌ Info: train
# │   epoch = 2
# │   step = 75
# └   loss = 46.17478f0
# ┌ Info: train
# │   epoch = 2
# │   step = 100
# └   loss = 46.61335f0
# ┌ Info: train
# │   epoch = 2
# │   step = 125
# └   loss = 44.934906f0
# ┌ Info: train
# │   epoch = 2
# │   step = 150
# └   loss = 41.69713f0
# ┌ Info: train
# │   epoch = 3
# │   step = 25
# └   loss = 45.287468f0
# ┌ Info: train
# │   epoch = 3
# │   step = 50
# └   loss = 43.52704f0
# ┌ Info: train
# │   epoch = 3
# │   step = 75
# └   loss = 39.66895f0
# ┌ Info: train
# │   epoch = 3
# │   step = 100
# └   loss = 39.165527f0
# ┌ Info: train
# │   epoch = 3
# │   step = 125
# └   loss = 40.31173f0
# ┌ Info: train
# │   epoch = 3
# │   step = 150
# └   loss = 36.59504f0
# ┌ Info: train
# │   epoch = 4
# │   step = 25
# └   loss = 40.564255f0
# ┌ Info: train
# │   epoch = 4
# │   step = 50
# └   loss = 37.86731f0
# ┌ Info: train
# │   epoch = 4
# │   step = 75
# └   loss = 40.385826f0
# ┌ Info: train
# │   epoch = 4
# │   step = 100
# └   loss = 40.322083f0
# ┌ Info: train
# │   epoch = 4
# │   step = 125
# └   loss = 39.391945f0
# ┌ Info: train
# │   epoch = 4
# │   step = 150
# └   loss = 34.939816f0
# ┌ Info: train
# │   epoch = 5
# │   step = 25
# └   loss = 35.111343f0
# ┌ Info: train
# │   epoch = 5
# │   step = 50
# └   loss = 35.31593f0
# ┌ Info: train
# │   epoch = 5
# │   step = 75
# └   loss = 37.190735f0
# ┌ Info: train
# │   epoch = 5
# │   step = 100
# └   loss = 36.458412f0
# ┌ Info: train
# │   epoch = 5
# │   step = 125
# └   loss = 39.276863f0
# ┌ Info: train
# │   epoch = 5
# │   step = 150
# └   loss = 38.577705f0
# ┌ Info: train
# │   epoch = 6
# │   step = 25
# └   loss = 37.672207f0
# ┌ Info: train
# │   epoch = 6
# │   step = 50
# └   loss = 33.816956f0
# ┌ Info: train
# │   epoch = 6
# │   step = 75
# └   loss = 35.438004f0
# ┌ Info: train
# │   epoch = 6
# │   step = 100
# └   loss = 36.36937f0
# ┌ Info: train
# │   epoch = 6
# │   step = 125
# └   loss = 33.889923f0
# ┌ Info: train
# │   epoch = 6
# │   step = 150
# └   loss = 34.536453f0
# ┌ Info: train
# │   epoch = 7
# │   step = 25
# └   loss = 34.919273f0
# ┌ Info: train
# │   epoch = 7
# │   step = 50
# └   loss = 33.35535f0
# ┌ Info: train
# │   epoch = 7
# │   step = 75
# └   loss = 34.92321f0
# ┌ Info: train
# │   epoch = 7
# │   step = 100
# └   loss = 37.54946f0
# ┌ Info: train
# │   epoch = 7
# │   step = 125
# └   loss = 32.466896f0
# ┌ Info: train
# │   epoch = 7
# │   step = 150
# └   loss = 36.90836f0
# ┌ Info: train
# │   epoch = 8
# │   step = 25
# └   loss = 36.573483f0
# ┌ Info: train
# │   epoch = 8
# │   step = 50
# └   loss = 30.769262f0
# ┌ Info: train
# │   epoch = 8
# │   step = 75
# └   loss = 34.593307f0
# ┌ Info: train
# │   epoch = 8
# │   step = 100
# └   loss = 25.809368f0
# ┌ Info: train
# │   epoch = 8
# │   step = 125
# └   loss = 34.314964f0
# ┌ Info: train
# │   epoch = 8
# │   step = 150
# └   loss = 34.868347f0
# ┌ Info: train
# │   epoch = 9
# │   step = 25
# └   loss = 32.30793f0
# ┌ Info: train
# │   epoch = 9
# │   step = 50
# └   loss = 35.449608f0
# ┌ Info: train
# │   epoch = 9
# │   step = 75
# └   loss = 32.058853f0
# ┌ Info: train
# │   epoch = 9
# │   step = 100
# └   loss = 32.30246f0
# ┌ Info: train
# │   epoch = 9
# │   step = 125
# └   loss = 35.396187f0
# ┌ Info: train
# │   epoch = 9
# │   step = 150
# └   loss = 32.03281f0
# ┌ Info: train
# │   epoch = 10
# │   step = 25
# └   loss = 32.141605f0
# ┌ Info: train
# │   epoch = 10
# │   step = 50
# └   loss = 34.48079f0
# ┌ Info: train
# │   epoch = 10
# │   step = 75
# └   loss = 31.728176f0
# ┌ Info: train
# │   epoch = 10
# │   step = 100
# └   loss = 30.799397f0
# ┌ Info: train
# │   epoch = 10
# │   step = 125
# └   loss = 34.22338f0
# ┌ Info: train
# │   epoch = 10
# │   step = 150
# └   loss = 30.56803f0
# ┌ Info: train
# │   epoch = 11
# │   step = 25
# └   loss = 31.286154f0
# ┌ Info: train
# │   epoch = 11
# │   step = 50
# └   loss = 31.165651f0
# ┌ Info: train
# │   epoch = 11
# │   step = 75
# └   loss = 31.54279f0
# ┌ Info: train
# │   epoch = 11
# │   step = 100
# └   loss = 33.8528f0
# ┌ Info: train
# │   epoch = 11
# │   step = 125
# └   loss = 31.07912f0
# ┌ Info: train
# │   epoch = 11
# │   step = 150
# └   loss = 31.126358f0
# ┌ Info: train
# │   epoch = 12
# │   step = 25
# └   loss = 34.789497f0
# ┌ Info: train
# │   epoch = 12
# │   step = 50
# └   loss = 33.40204f0
# ┌ Info: train
# │   epoch = 12
# │   step = 75
# └   loss = 33.934967f0
# ┌ Info: train
# │   epoch = 12
# │   step = 100
# └   loss = 32.35504f0
# ┌ Info: train
# │   epoch = 12
# │   step = 125
# └   loss = 34.06865f0
# ┌ Info: train
# │   epoch = 12
# │   step = 150
# └   loss = 32.93891f0
# ┌ Info: train
# │   epoch = 13
# │   step = 25
# └   loss = 30.98565f0
# ┌ Info: train
# │   epoch = 13
# │   step = 50
# └   loss = 33.669083f0
# ┌ Info: train
# │   epoch = 13
# │   step = 75
# └   loss = 30.357887f0
# ┌ Info: train
# │   epoch = 13
# │   step = 100
# └   loss = 33.41867f0
# ┌ Info: train
# │   epoch = 13
# │   step = 125
# └   loss = 32.702007f0
# ┌ Info: train
# │   epoch = 13
# │   step = 150
# └   loss = 30.948685f0
# ┌ Info: train
# │   epoch = 14
# │   step = 25
# └   loss = 32.02884f0
# ┌ Info: train
# │   epoch = 14
# │   step = 50
# └   loss = 29.43153f0
# ┌ Info: train
# │   epoch = 14
# │   step = 75
# └   loss = 31.269884f0
# ┌ Info: train
# │   epoch = 14
# │   step = 100
# └   loss = 31.48836f0
# ┌ Info: train
# │   epoch = 14
# │   step = 125
# └   loss = 27.304775f0
# ┌ Info: train
# │   epoch = 14
# │   step = 150
# └   loss = 28.295242f0
# ┌ Info: train
# │   epoch = 15
# │   step = 25
# └   loss = 31.564354f0
# ┌ Info: train
# │   epoch = 15
# │   step = 50
# └   loss = 31.63555f0
# ┌ Info: train
# │   epoch = 15
# │   step = 75
# └   loss = 32.694923f0
# ┌ Info: train
# │   epoch = 15
# │   step = 100
# └   loss = 29.10176f0
# ┌ Info: train
# │   epoch = 15
# │   step = 125
# └   loss = 28.823997f0
# ┌ Info: train
# │   epoch = 15
# │   step = 150
# └   loss = 31.046465f0
# ┌ Info: train
# │   epoch = 16
# │   step = 25
# └   loss = 33.151978f0
# ┌ Info: train
# │   epoch = 16
# │   step = 50
# └   loss = 27.241508f0
# ┌ Info: train
# │   epoch = 16
# │   step = 75
# └   loss = 30.599903f0
# ┌ Info: train
# │   epoch = 16
# │   step = 100
# └   loss = 32.371204f0
# ┌ Info: train
# │   epoch = 16
# │   step = 125
# └   loss = 27.115711f0
# ┌ Info: train
# │   epoch = 16
# │   step = 150
# └   loss = 30.063667f0
# ┌ Info: train
# │   epoch = 17
# │   step = 25
# └   loss = 30.288649f0
# ┌ Info: train
# │   epoch = 17
# │   step = 50
# └   loss = 30.17442f0
# ┌ Info: train
# │   epoch = 17
# │   step = 75
# └   loss = 27.832388f0
# ┌ Info: train
# │   epoch = 17
# │   step = 100
# └   loss = 28.63764f0
# ┌ Info: train
# │   epoch = 17
# │   step = 125
# └   loss = 29.523653f0
# ┌ Info: train
# │   epoch = 17
# │   step = 150
# └   loss = 28.578972f0
# ┌ Info: train
# │   epoch = 18
# │   step = 25
# └   loss = 26.127888f0
# ┌ Info: train
# │   epoch = 18
# │   step = 50
# └   loss = 31.43596f0
# ┌ Info: train
# │   epoch = 18
# │   step = 75
# └   loss = 30.935762f0
# ┌ Info: train
# │   epoch = 18
# │   step = 100
# └   loss = 26.834002f0
# ┌ Info: train
# │   epoch = 18
# │   step = 125
# └   loss = 27.114868f0
# ┌ Info: train
# │   epoch = 18
# │   step = 150
# └   loss = 29.446186f0
# ┌ Info: train
# │   epoch = 19
# │   step = 25
# └   loss = 24.983818f0
# ┌ Info: train
# │   epoch = 19
# │   step = 50
# └   loss = 28.701529f0
# ┌ Info: train
# │   epoch = 19
# │   step = 75
# └   loss = 29.964905f0
# ┌ Info: train
# │   epoch = 19
# │   step = 100
# └   loss = 33.798264f0
# ┌ Info: train
# │   epoch = 19
# │   step = 125
# └   loss = 31.764925f0
# ┌ Info: train
# │   epoch = 19
# │   step = 150
# └   loss = 29.253445f0
# ┌ Info: train
# │   epoch = 20
# │   step = 25
# └   loss = 31.058111f0
# ┌ Info: train
# │   epoch = 20
# │   step = 50
# └   loss = 26.854343f0
# ┌ Info: train
# │   epoch = 20
# │   step = 75
# └   loss = 26.131287f0
# ┌ Info: train
# │   epoch = 20
# │   step = 100
# └   loss = 31.974604f0
# ┌ Info: train
# │   epoch = 20
# │   step = 125
# └   loss = 30.332983f0
# ┌ Info: train
# │   epoch = 20
# │   step = 150
# └   loss = 29.150225f0
# ┌ Info: train
# │   epoch = 21
# │   step = 25
# └   loss = 28.560247f0
# ┌ Info: train
# │   epoch = 21
# │   step = 50
# └   loss = 31.277634f0
# ┌ Info: train
# │   epoch = 21
# │   step = 75
# └   loss = 28.871674f0
# ┌ Info: train
# │   epoch = 21
# │   step = 100
# └   loss = 28.280323f0
# ┌ Info: train
# │   epoch = 21
# │   step = 125
# └   loss = 31.3564f0
# ┌ Info: train
# │   epoch = 21
# │   step = 150
# └   loss = 27.779842f0
# ┌ Info: train
# │   epoch = 22
# │   step = 25
# └   loss = 28.763954f0
# ┌ Info: train
# │   epoch = 22
# │   step = 50
# └   loss = 27.29353f0
# ┌ Info: train
# │   epoch = 22
# │   step = 75
# └   loss = 29.820616f0
# ┌ Info: train
# │   epoch = 22
# │   step = 100
# └   loss = 28.870682f0
# ┌ Info: train
# │   epoch = 22
# │   step = 125
# └   loss = 28.851711f0
# ┌ Info: train
# │   epoch = 22
# │   step = 150
# └   loss = 29.26233f0
# ┌ Info: train
# │   epoch = 23
# │   step = 25
# └   loss = 30.022175f0
# ┌ Info: train
# │   epoch = 23
# │   step = 50
# └   loss = 28.356493f0
# ┌ Info: train
# │   epoch = 23
# │   step = 75
# └   loss = 26.398968f0
# ┌ Info: train
# │   epoch = 23
# │   step = 100
# └   loss = 29.326962f0
# ┌ Info: train
# │   epoch = 23
# │   step = 125
# └   loss = 26.917953f0
# ┌ Info: train
# │   epoch = 23
# │   step = 150
# └   loss = 29.692986f0
# ┌ Info: train
# │   epoch = 24
# │   step = 25
# └   loss = 28.146017f0
# ┌ Info: train
# │   epoch = 24
# │   step = 50
# └   loss = 28.466309f0
# ┌ Info: train
# │   epoch = 24
# │   step = 75
# └   loss = 26.152166f0
# ┌ Info: train
# │   epoch = 24
# │   step = 100
# └   loss = 30.562721f0
# ┌ Info: train
# │   epoch = 24
# │   step = 125
# └   loss = 30.2849f0
# ┌ Info: train
# │   epoch = 24
# │   step = 150
# └   loss = 31.194546f0
# ┌ Info: train
# │   epoch = 25
# │   step = 25
# └   loss = 29.014896f0
# ┌ Info: train
# │   epoch = 25
# │   step = 50
# └   loss = 28.774408f0
# ┌ Info: train
# │   epoch = 25
# │   step = 75
# └   loss = 29.552523f0
# ┌ Info: train
# │   epoch = 25
# │   step = 100
# └   loss = 28.040781f0
# ┌ Info: train
# │   epoch = 25
# │   step = 125
# └   loss = 29.373951f0
# ┌ Info: train
# │   epoch = 25
# │   step = 150
# └   loss = 26.159891f0
# ┌ Info: train
# │   epoch = 26
# │   step = 25
# └   loss = 23.581429f0
# ┌ Info: train
# │   epoch = 26
# │   step = 50
# └   loss = 27.509647f0
# ┌ Info: train
# │   epoch = 26
# │   step = 75
# └   loss = 28.619043f0
# ┌ Info: train
# │   epoch = 26
# │   step = 100
# └   loss = 26.09383f0
# ┌ Info: train
# │   epoch = 26
# │   step = 125
# └   loss = 30.292168f0
# ┌ Info: train
# │   epoch = 26
# │   step = 150
# └   loss = 29.818909f0
# ┌ Info: train
# │   epoch = 27
# │   step = 25
# └   loss = 30.22113f0
# ┌ Info: train
# │   epoch = 27
# │   step = 50
# └   loss = 27.000816f0
# ┌ Info: train
# │   epoch = 27
# │   step = 75
# └   loss = 27.185415f0
# ┌ Info: train
# │   epoch = 27
# │   step = 100
# └   loss = 29.700916f0
# ┌ Info: train
# │   epoch = 27
# │   step = 125
# └   loss = 27.716354f0
# ┌ Info: train
# │   epoch = 27
# │   step = 150
# └   loss = 27.38358f0
# ┌ Info: train
# │   epoch = 28
# │   step = 25
# └   loss = 27.860315f0
# ┌ Info: train
# │   epoch = 28
# │   step = 50
# └   loss = 27.69223f0
# ┌ Info: train
# │   epoch = 28
# │   step = 75
# └   loss = 27.02826f0
# ┌ Info: train
# │   epoch = 28
# │   step = 100
# └   loss = 27.024052f0
# ┌ Info: train
# │   epoch = 28
# │   step = 125
# └   loss = 25.986008f0
# ┌ Info: train
# │   epoch = 28
# │   step = 150
# └   loss = 25.56084f0
# ┌ Info: train
# │   epoch = 29
# │   step = 25
# └   loss = 27.256157f0
# ┌ Info: train
# │   epoch = 29
# │   step = 50
# └   loss = 23.557503f0
# ┌ Info: train
# │   epoch = 29
# │   step = 75
# └   loss = 26.805897f0
# ┌ Info: train
# │   epoch = 29
# │   step = 100
# └   loss = 28.765497f0
# ┌ Info: train
# │   epoch = 29
# │   step = 125
# └   loss = 25.463768f0
# ┌ Info: train
# │   epoch = 29
# │   step = 150
# └   loss = 26.466944f0
# ┌ Info: train
# │   epoch = 30
# │   step = 25
# └   loss = 20.504349f0
# ┌ Info: train
# │   epoch = 30
# │   step = 50
# └   loss = 28.668938f0
# ┌ Info: train
# │   epoch = 30
# │   step = 75
# └   loss = 28.541996f0
# ┌ Info: train
# │   epoch = 30
# │   step = 100
# └   loss = 25.095675f0
# ┌ Info: train
# │   epoch = 30
# │   step = 125
# └   loss = 28.885004f0
# ┌ Info: train
# │   epoch = 30
# │   step = 150
# └   loss = 26.725517f0
# ┌ Info: train
# │   epoch = 31
# │   step = 25
# └   loss = 30.679646f0
# ┌ Info: train
# │   epoch = 31
# │   step = 50
# └   loss = 28.332363f0
# ┌ Info: train
# │   epoch = 31
# │   step = 75
# └   loss = 27.44205f0
# ┌ Info: train
# │   epoch = 31
# │   step = 100
# └   loss = 28.786064f0
# ┌ Info: train
# │   epoch = 31
# │   step = 125
# └   loss = 26.905752f0
# ┌ Info: train
# │   epoch = 31
# │   step = 150
# └   loss = 27.435757f0
# ┌ Info: train
# │   epoch = 32
# │   step = 25
# └   loss = 28.278011f0
# ┌ Info: train
# │   epoch = 32
# │   step = 50
# └   loss = 29.903355f0
# ┌ Info: train
# │   epoch = 32
# │   step = 75
# └   loss = 28.621813f0
# ┌ Info: train
# │   epoch = 32
# │   step = 100
# └   loss = 26.800285f0
# ┌ Info: train
# │   epoch = 32
# │   step = 125
# └   loss = 26.840708f0
# ┌ Info: train
# │   epoch = 32
# │   step = 150
# └   loss = 26.018559f0
# ┌ Info: train
# │   epoch = 33
# │   step = 25
# └   loss = 24.744186f0
# ┌ Info: train
# │   epoch = 33
# │   step = 50
# └   loss = 24.735939f0
# ┌ Info: train
# │   epoch = 33
# │   step = 75
# └   loss = 25.753193f0
# ┌ Info: train
# │   epoch = 33
# │   step = 100
# └   loss = 24.21335f0
# ┌ Info: train
# │   epoch = 33
# │   step = 125
# └   loss = 28.902012f0
# ┌ Info: train
# │   epoch = 33
# │   step = 150
# └   loss = 28.089495f0
# ┌ Info: train
# │   epoch = 34
# │   step = 25
# └   loss = 28.58031f0
# ┌ Info: train
# │   epoch = 34
# │   step = 50
# └   loss = 27.263393f0
# ┌ Info: train
# │   epoch = 34
# │   step = 75
# └   loss = 27.389595f0
# ┌ Info: train
# │   epoch = 34
# │   step = 100
# └   loss = 28.411808f0
# ┌ Info: train
# │   epoch = 34
# │   step = 125
# └   loss = 27.020435f0
# ┌ Info: train
# │   epoch = 34
# │   step = 150
# └   loss = 29.144455f0
# ┌ Info: train
# │   epoch = 35
# │   step = 25
# └   loss = 29.2962f0
# ┌ Info: train
# │   epoch = 35
# │   step = 50
# └   loss = 26.897776f0
# ┌ Info: train
# │   epoch = 35
# │   step = 75
# └   loss = 26.124271f0
# ┌ Info: train
# │   epoch = 35
# │   step = 100
# └   loss = 27.111145f0
# ┌ Info: train
# │   epoch = 35
# │   step = 125
# └   loss = 27.478966f0
# ┌ Info: train
# │   epoch = 35
# │   step = 150
# └   loss = 26.792439f0
# ┌ Info: train
# │   epoch = 36
# │   step = 25
# └   loss = 27.627457f0
# ┌ Info: train
# │   epoch = 36
# │   step = 50
# └   loss = 26.22819f0
# ┌ Info: train
# │   epoch = 36
# │   step = 75
# └   loss = 25.252316f0
# ┌ Info: train
# │   epoch = 36
# │   step = 100
# └   loss = 24.160707f0
# ┌ Info: train
# │   epoch = 36
# │   step = 125
# └   loss = 25.44091f0
# ┌ Info: train
# │   epoch = 36
# │   step = 150
# └   loss = 26.25015f0
# ┌ Info: train
# │   epoch = 37
# │   step = 25
# └   loss = 27.912188f0
# ┌ Info: train
# │   epoch = 37
# │   step = 50
# └   loss = 23.750805f0
# ┌ Info: train
# │   epoch = 37
# │   step = 75
# └   loss = 27.955189f0
# ┌ Info: train
# │   epoch = 37
# │   step = 100
# └   loss = 28.026106f0
# ┌ Info: train
# │   epoch = 37
# │   step = 125
# └   loss = 28.814238f0
# ┌ Info: train
# │   epoch = 37
# │   step = 150
# └   loss = 26.040257f0
# ┌ Info: train
# │   epoch = 38
# │   step = 25
# └   loss = 27.69309f0
# ┌ Info: train
# │   epoch = 38
# │   step = 50
# └   loss = 24.04459f0
# ┌ Info: train
# │   epoch = 38
# │   step = 75
# └   loss = 26.733395f0
# ┌ Info: train
# │   epoch = 38
# │   step = 100
# └   loss = 27.58453f0
# ┌ Info: train
# │   epoch = 38
# │   step = 125
# └   loss = 27.76516f0
# ┌ Info: train
# │   epoch = 38
# │   step = 150
# └   loss = 26.80672f0
# ┌ Info: train
# │   epoch = 39
# │   step = 25
# └   loss = 26.192831f0
# ┌ Info: train
# │   epoch = 39
# │   step = 50
# └   loss = 28.523682f0
# ┌ Info: train
# │   epoch = 39
# │   step = 75
# └   loss = 26.81498f0
# ┌ Info: train
# │   epoch = 39
# │   step = 100
# └   loss = 29.908417f0
# ┌ Info: train
# │   epoch = 39
# │   step = 125
# └   loss = 28.202335f0
# ┌ Info: train
# │   epoch = 39
# │   step = 150
# └   loss = 26.47245f0
# ┌ Info: train
# │   epoch = 40
# │   step = 25
# └   loss = 28.739391f0
# ┌ Info: train
# │   epoch = 40
# │   step = 50
# └   loss = 21.068176f0
# ┌ Info: train
# │   epoch = 40
# │   step = 75
# └   loss = 28.204624f0
# ┌ Info: train
# │   epoch = 40
# │   step = 100
# └   loss = 27.831722f0
# ┌ Info: train
# │   epoch = 40
# │   step = 125
# └   loss = 28.325375f0
# ┌ Info: train
# │   epoch = 40
# │   step = 150
# └   loss = 25.1208f0
# ┌ Info: train
# │   epoch = 41
# │   step = 25
# └   loss = 23.505514f0
# ┌ Info: train
# │   epoch = 41
# │   step = 50
# └   loss = 24.5488f0
# ┌ Info: train
# │   epoch = 41
# │   step = 75
# └   loss = 24.15102f0
# ┌ Info: train
# │   epoch = 41
# │   step = 100
# └   loss = 23.176058f0
# ┌ Info: train
# │   epoch = 41
# │   step = 125
# └   loss = 26.531853f0
# ┌ Info: train
# │   epoch = 41
# │   step = 150
# └   loss = 25.99091f0
# ┌ Info: train
# │   epoch = 42
# │   step = 25
# └   loss = 26.7192f0
# ┌ Info: train
# │   epoch = 42
# │   step = 50
# └   loss = 25.728962f0
# ┌ Info: train
# │   epoch = 42
# │   step = 75
# └   loss = 25.610317f0
# ┌ Info: train
# │   epoch = 42
# │   step = 100
# └   loss = 23.416164f0
# ┌ Info: train
# │   epoch = 42
# │   step = 125
# └   loss = 26.267582f0
# ┌ Info: train
# │   epoch = 42
# │   step = 150
# └   loss = 22.809444f0
# ┌ Info: train
# │   epoch = 43
# │   step = 25
# └   loss = 29.121967f0
# ┌ Info: train
# │   epoch = 43
# │   step = 50
# └   loss = 26.335537f0
# ┌ Info: train
# │   epoch = 43
# │   step = 75
# └   loss = 26.019642f0
# ┌ Info: train
# │   epoch = 43
# │   step = 100
# └   loss = 27.637943f0
# ┌ Info: train
# │   epoch = 43
# │   step = 125
# └   loss = 24.238605f0
# ┌ Info: train
# │   epoch = 43
# │   step = 150
# └   loss = 25.979734f0
# ┌ Info: train
# │   epoch = 44
# │   step = 25
# └   loss = 26.764843f0
# ┌ Info: train
# │   epoch = 44
# │   step = 50
# └   loss = 28.702675f0
# ┌ Info: train
# │   epoch = 44
# │   step = 75
# └   loss = 24.530308f0
# ┌ Info: train
# │   epoch = 44
# │   step = 100
# └   loss = 24.94001f0
# ┌ Info: train
# │   epoch = 44
# │   step = 125
# └   loss = 22.980862f0
# ┌ Info: train
# │   epoch = 44
# │   step = 150
# └   loss = 23.945194f0
# ┌ Info: train
# │   epoch = 45
# │   step = 25
# └   loss = 28.208347f0
# ┌ Info: train
# │   epoch = 45
# │   step = 50
# └   loss = 24.52969f0
# ┌ Info: train
# │   epoch = 45
# │   step = 75
# └   loss = 26.940765f0
# ┌ Info: train
# │   epoch = 45
# │   step = 100
# └   loss = 26.146969f0
# ┌ Info: train
# │   epoch = 45
# │   step = 125
# └   loss = 27.750103f0
# ┌ Info: train
# │   epoch = 45
# │   step = 150
# └   loss = 25.741966f0
# ┌ Info: train
# │   epoch = 46
# │   step = 25
# └   loss = 27.725286f0
# ┌ Info: train
# │   epoch = 46
# │   step = 50
# └   loss = 26.318342f0
# ┌ Info: train
# │   epoch = 46
# │   step = 75
# └   loss = 27.266163f0
# ┌ Info: train
# │   epoch = 46
# │   step = 100
# └   loss = 26.628586f0
# ┌ Info: train
# │   epoch = 46
# │   step = 125
# └   loss = 25.748112f0
# ┌ Info: train
# │   epoch = 46
# │   step = 150
# └   loss = 26.119446f0
# ┌ Info: train
# │   epoch = 47
# │   step = 25
# └   loss = 25.42128f0
# ┌ Info: train
# │   epoch = 47
# │   step = 50
# └   loss = 28.901266f0
# ┌ Info: train
# │   epoch = 47
# │   step = 75
# └   loss = 23.349586f0
# ┌ Info: train
# │   epoch = 47
# │   step = 100
# └   loss = 25.926575f0
# ┌ Info: train
# │   epoch = 47
# │   step = 125
# └   loss = 25.67647f0
# ┌ Info: train
# │   epoch = 47
# │   step = 150
# └   loss = 25.600336f0
# ┌ Info: train
# │   epoch = 48
# │   step = 25
# └   loss = 25.054993f0
# ┌ Info: train
# │   epoch = 48
# │   step = 50
# └   loss = 25.485657f0
# ┌ Info: train
# │   epoch = 48
# │   step = 75
# └   loss = 25.708344f0
# ┌ Info: train
# │   epoch = 48
# │   step = 100
# └   loss = 27.638538f0
# ┌ Info: train
# │   epoch = 48
# │   step = 125
# └   loss = 25.087189f0
# ┌ Info: train
# │   epoch = 48
# │   step = 150
# └   loss = 26.382866f0
# ┌ Info: train
# │   epoch = 49
# │   step = 25
# └   loss = 21.803917f0
# ┌ Info: train
# │   epoch = 49
# │   step = 50
# └   loss = 23.354397f0
# ┌ Info: train
# │   epoch = 49
# │   step = 75
# └   loss = 26.697845f0
# ┌ Info: train
# │   epoch = 49
# │   step = 100
# └   loss = 22.903067f0
# ┌ Info: train
# │   epoch = 49
# │   step = 125
# └   loss = 28.217096f0
# ┌ Info: train
# │   epoch = 49
# │   step = 150
# └   loss = 28.466969f0
# ┌ Info: train
# │   epoch = 50
# │   step = 25
# └   loss = 29.123995f0
# ┌ Info: train
# │   epoch = 50
# │   step = 50
# └   loss = 26.66383f0
# ┌ Info: train
# │   epoch = 50
# │   step = 75
# └   loss = 26.066828f0
# ┌ Info: train
# │   epoch = 50
# │   step = 100
# └   loss = 26.641502f0
# ┌ Info: train
# │   epoch = 50
# │   step = 125
# └   loss = 24.865017f0
# ┌ Info: train
# │   epoch = 50
# │   step = 150
# └   loss = 24.352922f0
# ┌ Info: train
# │   epoch = 51
# │   step = 25
# └   loss = 27.092247f0
# ┌ Info: train
# │   epoch = 51
# │   step = 50
# └   loss = 28.752254f0
# ┌ Info: train
# │   epoch = 51
# │   step = 75
# └   loss = 25.05304f0
# ┌ Info: train
# │   epoch = 51
# │   step = 100
# └   loss = 27.390366f0
# ┌ Info: train
# │   epoch = 51
# │   step = 125
# └   loss = 27.090763f0
# ┌ Info: train
# │   epoch = 51
# │   step = 150
# └   loss = 26.176765f0
# ┌ Info: train
# │   epoch = 52
# │   step = 25
# └   loss = 27.52108f0
# ┌ Info: train
# │   epoch = 52
# │   step = 50
# └   loss = 27.761932f0
# ┌ Info: train
# │   epoch = 52
# │   step = 75
# └   loss = 25.511892f0
# ┌ Info: train
# │   epoch = 52
# │   step = 100
# └   loss = 24.29064f0
# ┌ Info: train
# │   epoch = 52
# │   step = 125
# └   loss = 28.123562f0
# ┌ Info: train
# │   epoch = 52
# │   step = 150
# └   loss = 25.654358f0
# ┌ Info: train
# │   epoch = 53
# │   step = 25
# └   loss = 24.53424f0
# ┌ Info: train
# │   epoch = 53
# │   step = 50
# └   loss = 26.85925f0
# ┌ Info: train
# │   epoch = 53
# │   step = 75
# └   loss = 26.881779f0
# ┌ Info: train
# │   epoch = 53
# │   step = 100
# └   loss = 18.724129f0
# ┌ Info: train
# │   epoch = 53
# │   step = 125
# └   loss = 24.388699f0
# ┌ Info: train
# │   epoch = 53
# │   step = 150
# └   loss = 27.270184f0
# ┌ Info: train
# │   epoch = 54
# │   step = 25
# └   loss = 24.898977f0
# ┌ Info: train
# │   epoch = 54
# │   step = 50
# └   loss = 24.655685f0
# ┌ Info: train
# │   epoch = 54
# │   step = 75
# └   loss = 24.33598f0
# ┌ Info: train
# │   epoch = 54
# │   step = 100
# └   loss = 26.403103f0
# ┌ Info: train
# │   epoch = 54
# │   step = 125
# └   loss = 24.912945f0
# ┌ Info: train
# │   epoch = 54
# │   step = 150
# └   loss = 24.995174f0
# ┌ Info: train
# │   epoch = 55
# │   step = 25
# └   loss = 27.486912f0
# ┌ Info: train
# │   epoch = 55
# │   step = 50
# └   loss = 25.728872f0
# ┌ Info: train
# │   epoch = 55
# │   step = 75
# └   loss = 25.981642f0
# ┌ Info: train
# │   epoch = 55
# │   step = 100
# └   loss = 26.466846f0
# ┌ Info: train
# │   epoch = 55
# │   step = 125
# └   loss = 23.494558f0
# ┌ Info: train
# │   epoch = 55
# │   step = 150
# └   loss = 27.157269f0
# ┌ Info: train
# │   epoch = 56
# │   step = 25
# └   loss = 25.891315f0
# ┌ Info: train
# │   epoch = 56
# │   step = 50
# └   loss = 24.81565f0
# ┌ Info: train
# │   epoch = 56
# │   step = 75
# └   loss = 25.700804f0
# ┌ Info: train
# │   epoch = 56
# │   step = 100
# └   loss = 27.016748f0
# ┌ Info: train
# │   epoch = 56
# │   step = 125
# └   loss = 12.17991f0
# ┌ Info: train
# │   epoch = 56
# │   step = 150
# └   loss = 25.762886f0
# ┌ Info: train
# │   epoch = 57
# │   step = 25
# └   loss = 24.146517f0
# ┌ Info: train
# │   epoch = 57
# │   step = 50
# └   loss = 22.501875f0
# ┌ Info: train
# │   epoch = 57
# │   step = 75
# └   loss = 25.152218f0
# ┌ Info: train
# │   epoch = 57
# │   step = 100
# └   loss = 21.110748f0
# ┌ Info: train
# │   epoch = 57
# │   step = 125
# └   loss = 28.041103f0
# ┌ Info: train
# │   epoch = 57
# │   step = 150
# └   loss = 28.101912f0
# ┌ Info: train
# │   epoch = 58
# │   step = 25
# └   loss = 24.75323f0
# ┌ Info: train
# │   epoch = 58
# │   step = 50
# └   loss = 25.365854f0
# ┌ Info: train
# │   epoch = 58
# │   step = 75
# └   loss = 27.630274f0
# ┌ Info: train
# │   epoch = 58
# │   step = 100
# └   loss = 26.837723f0
# ┌ Info: train
# │   epoch = 58
# │   step = 125
# └   loss = 24.288212f0
# ┌ Info: train
# │   epoch = 58
# │   step = 150
# └   loss = 26.135359f0
# ┌ Info: train
# │   epoch = 59
# │   step = 25
# └   loss = 26.50134f0
# ┌ Info: train
# │   epoch = 59
# │   step = 50
# └   loss = 21.57468f0
# ┌ Info: train
# │   epoch = 59
# │   step = 75
# └   loss = 25.161716f0
# ┌ Info: train
# │   epoch = 59
# │   step = 100
# └   loss = 25.87622f0
# ┌ Info: train
# │   epoch = 59
# │   step = 125
# └   loss = 20.94062f0
# ┌ Info: train
# │   epoch = 59
# │   step = 150
# └   loss = 24.8095f0
# ┌ Info: train
# │   epoch = 60
# │   step = 25
# └   loss = 22.677917f0
# ┌ Info: train
# │   epoch = 60
# │   step = 50
# └   loss = 26.46408f0
# ┌ Info: train
# │   epoch = 60
# │   step = 75
# └   loss = 23.636616f0
# ┌ Info: train
# │   epoch = 60
# │   step = 100
# └   loss = 23.922928f0
# ┌ Info: train
# │   epoch = 60
# │   step = 125
# └   loss = 26.925663f0
# ┌ Info: train
# │   epoch = 60
# │   step = 150
# └   loss = 25.531475f0
# ┌ Info: train
# │   epoch = 61
# │   step = 25
# └   loss = 27.56285f0
# ┌ Info: train
# │   epoch = 61
# │   step = 50
# └   loss = 27.698103f0
# ┌ Info: train
# │   epoch = 61
# │   step = 75
# └   loss = 23.562912f0
# ┌ Info: train
# │   epoch = 61
# │   step = 100
# └   loss = 24.336823f0
# ┌ Info: train
# │   epoch = 61
# │   step = 125
# └   loss = 24.004013f0
# ┌ Info: train
# │   epoch = 61
# │   step = 150
# └   loss = 25.274128f0
# ┌ Info: train
# │   epoch = 62
# │   step = 25
# └   loss = 22.192417f0
# ┌ Info: train
# │   epoch = 62
# │   step = 50
# └   loss = 24.432222f0
# ┌ Info: train
# │   epoch = 62
# │   step = 75
# └   loss = 23.7392f0
# ┌ Info: train
# │   epoch = 62
# │   step = 100
# └   loss = 22.985062f0
# ┌ Info: train
# │   epoch = 62
# │   step = 125
# └   loss = 23.17378f0
# ┌ Info: train
# │   epoch = 62
# │   step = 150
# └   loss = 28.799166f0
# ┌ Info: train
# │   epoch = 63
# │   step = 25
# └   loss = 24.425634f0
# ┌ Info: train
# │   epoch = 63
# │   step = 50
# └   loss = 25.468296f0
# ┌ Info: train
# │   epoch = 63
# │   step = 75
# └   loss = -5.995845f0
# ┌ Info: train
# │   epoch = 63
# │   step = 100
# └   loss = 22.998158f0
# ┌ Info: train
# │   epoch = 63
# │   step = 125
# └   loss = 23.038448f0
# ┌ Info: train
# │   epoch = 63
# │   step = 150
# └   loss = 27.033749f0
# ┌ Info: train
# │   epoch = 64
# │   step = 25
# └   loss = 26.00533f0
# ┌ Info: train
# │   epoch = 64
# │   step = 50
# └   loss = 25.06829f0
# ┌ Info: train
# │   epoch = 64
# │   step = 75
# └   loss = 22.032722f0
# ┌ Info: train
# │   epoch = 64
# │   step = 100
# └   loss = 27.024298f0
# ┌ Info: train
# │   epoch = 64
# │   step = 125
# └   loss = 24.170773f0
# ┌ Info: train
# │   epoch = 64
# │   step = 150
# └   loss = 24.376472f0
# ┌ Info: train
# │   epoch = 65
# │   step = 25
# └   loss = 24.3689f0
# ┌ Info: train
# │   epoch = 65
# │   step = 50
# └   loss = 27.082571f0
# ┌ Info: train
# │   epoch = 65
# │   step = 75
# └   loss = 26.11168f0
# ┌ Info: train
# │   epoch = 65
# │   step = 100
# └   loss = 22.405136f0
# ┌ Info: train
# │   epoch = 65
# │   step = 125
# └   loss = 26.619356f0
# ┌ Info: train
# │   epoch = 65
# │   step = 150
# └   loss = 24.924015f0
# ┌ Info: train
# │   epoch = 66
# │   step = 25
# └   loss = 22.195768f0
# ┌ Info: train
# │   epoch = 66
# │   step = 50
# └   loss = 23.6123f0
# ┌ Info: train
# │   epoch = 66
# │   step = 75
# └   loss = 24.629646f0
# ┌ Info: train
# │   epoch = 66
# │   step = 100
# └   loss = 27.263647f0
# ┌ Info: train
# │   epoch = 66
# │   step = 125
# └   loss = 23.222168f0
# ┌ Info: train
# │   epoch = 66
# │   step = 150
# └   loss = 23.27013f0
# ┌ Info: train
# │   epoch = 67
# │   step = 25
# └   loss = 27.022396f0
# ┌ Info: train
# │   epoch = 67
# │   step = 50
# └   loss = 25.813812f0
# ┌ Info: train
# │   epoch = 67
# │   step = 75
# └   loss = 23.486214f0
# ┌ Info: train
# │   epoch = 67
# │   step = 100
# └   loss = 23.982243f0
# ┌ Info: train
# │   epoch = 67
# │   step = 125
# └   loss = 23.693348f0
# ┌ Info: train
# │   epoch = 67
# │   step = 150
# └   loss = 24.587395f0
# ┌ Info: train
# │   epoch = 68
# │   step = 25
# └   loss = 25.629896f0
# ┌ Info: train
# │   epoch = 68
# │   step = 50
# └   loss = 24.485079f0
# ┌ Info: train
# │   epoch = 68
# │   step = 75
# └   loss = 25.933212f0
# ┌ Info: train
# │   epoch = 68
# │   step = 100
# └   loss = 25.13412f0
# ┌ Info: train
# │   epoch = 68
# │   step = 125
# └   loss = 26.339632f0
# ┌ Info: train
# │   epoch = 68
# │   step = 150
# └   loss = 23.508022f0
# ┌ Info: train
# │   epoch = 69
# │   step = 25
# └   loss = 27.1389f0
# ┌ Info: train
# │   epoch = 69
# │   step = 50
# └   loss = 24.179682f0
# ┌ Info: train
# │   epoch = 69
# │   step = 75
# └   loss = 25.82854f0
# ┌ Info: train
# │   epoch = 69
# │   step = 100
# └   loss = 25.925406f0
# ┌ Info: train
# │   epoch = 69
# │   step = 125
# └   loss = 28.995193f0
# ┌ Info: train
# │   epoch = 69
# │   step = 150
# └   loss = 21.171566f0
# ┌ Info: train
# │   epoch = 70
# │   step = 25
# └   loss = 25.341312f0
# ┌ Info: train
# │   epoch = 70
# │   step = 50
# └   loss = 20.789955f0
# ┌ Info: train
# │   epoch = 70
# │   step = 75
# └   loss = 20.980728f0
# ┌ Info: train
# │   epoch = 70
# │   step = 100
# └   loss = 24.528828f0
# ┌ Info: train
# │   epoch = 70
# │   step = 125
# └   loss = 27.014193f0
# ┌ Info: train
# │   epoch = 70
# │   step = 150
# └   loss = 21.833584f0
# ┌ Info: train
# │   epoch = 71
# │   step = 25
# └   loss = 24.698025f0
# ┌ Info: train
# │   epoch = 71
# │   step = 50
# └   loss = 24.143219f0
# ┌ Info: train
# │   epoch = 71
# │   step = 75
# └   loss = 25.284584f0
# ┌ Info: train
# │   epoch = 71
# │   step = 100
# └   loss = 25.312044f0
# ┌ Info: train
# │   epoch = 71
# │   step = 125
# └   loss = 24.3766f0
# ┌ Info: train
# │   epoch = 71
# │   step = 150
# └   loss = 26.132614f0
# ┌ Info: train
# │   epoch = 72
# │   step = 25
# └   loss = 25.464508f0
# ┌ Info: train
# │   epoch = 72
# │   step = 50
# └   loss = 26.122822f0
# ┌ Info: train
# │   epoch = 72
# │   step = 75
# └   loss = 24.225592f0
# ┌ Info: train
# │   epoch = 72
# │   step = 100
# └   loss = 22.98212f0
# ┌ Info: train
# │   epoch = 72
# │   step = 125
# └   loss = 25.111795f0
# ┌ Info: train
# │   epoch = 72
# │   step = 150
# └   loss = 25.57614f0
# ┌ Info: train
# │   epoch = 73
# │   step = 25
# └   loss = 26.375362f0
# ┌ Info: train
# │   epoch = 73
# │   step = 50
# └   loss = 24.394024f0
# ┌ Info: train
# │   epoch = 73
# │   step = 75
# └   loss = 27.27369f0
# ┌ Info: train
# │   epoch = 73
# │   step = 100
# └   loss = 25.573868f0
# ┌ Info: train
# │   epoch = 73
# │   step = 125
# └   loss = 23.740505f0
# ┌ Info: train
# │   epoch = 73
# │   step = 150
# └   loss = 22.441765f0
# ┌ Info: train
# │   epoch = 74
# │   step = 25
# └   loss = 24.771257f0
# ┌ Info: train
# │   epoch = 74
# │   step = 50
# └   loss = 25.316023f0
# ┌ Info: train
# │   epoch = 74
# │   step = 75
# └   loss = 18.580448f0
# ┌ Info: train
# │   epoch = 74
# │   step = 100
# └   loss = 24.979656f0
# ┌ Info: train
# │   epoch = 74
# │   step = 125
# └   loss = 23.400307f0
# ┌ Info: train
# │   epoch = 74
# │   step = 150
# └   loss = 23.783073f0
# ┌ Info: train
# │   epoch = 75
# │   step = 25
# └   loss = 21.628641f0
# ┌ Info: train
# │   epoch = 75
# │   step = 50
# └   loss = 25.261189f0
# ┌ Info: train
# │   epoch = 75
# │   step = 75
# └   loss = 23.686115f0
# ┌ Info: train
# │   epoch = 75
# │   step = 100
# └   loss = 26.199797f0
# ┌ Info: train
# │   epoch = 75
# │   step = 125
# └   loss = 24.52521f0
# ┌ Info: train
# │   epoch = 75
# │   step = 150
# └   loss = 26.92347f0
# ┌ Info: train
# │   epoch = 76
# │   step = 25
# └   loss = 23.527836f0
# ┌ Info: train
# │   epoch = 76
# │   step = 50
# └   loss = 23.664387f0
# ┌ Info: train
# │   epoch = 76
# │   step = 75
# └   loss = 23.153656f0
# ┌ Info: train
# │   epoch = 76
# │   step = 100
# └   loss = 25.139687f0
# ┌ Info: train
# │   epoch = 76
# │   step = 125
# └   loss = 24.865797f0
# ┌ Info: train
# │   epoch = 76
# │   step = 150
# └   loss = 22.617004f0
# ┌ Info: train
# │   epoch = 77
# │   step = 25
# └   loss = 23.611313f0
# ┌ Info: train
# │   epoch = 77
# │   step = 50
# └   loss = 20.56675f0
# ┌ Info: train
# │   epoch = 77
# │   step = 75
# └   loss = 21.861835f0
# ┌ Info: train
# │   epoch = 77
# │   step = 100
# └   loss = 26.752243f0
# ┌ Info: train
# │   epoch = 77
# │   step = 125
# └   loss = 24.810802f0
# ┌ Info: train
# │   epoch = 77
# │   step = 150
# └   loss = 18.026962f0
# ┌ Info: train
# │   epoch = 78
# │   step = 25
# └   loss = 24.86181f0
# ┌ Info: train
# │   epoch = 78
# │   step = 50
# └   loss = 23.10205f0
# ┌ Info: train
# │   epoch = 78
# │   step = 75
# └   loss = 25.015896f0
# ┌ Info: train
# │   epoch = 78
# │   step = 100
# └   loss = 27.185467f0
# ┌ Info: train
# │   epoch = 78
# │   step = 125
# └   loss = 24.688988f0
# ┌ Info: train
# │   epoch = 78
# │   step = 150
# └   loss = 23.525013f0
# ┌ Info: train
# │   epoch = 79
# │   step = 25
# └   loss = 27.49948f0
# ┌ Info: train
# │   epoch = 79
# │   step = 50
# └   loss = 26.364954f0
# ┌ Info: train
# │   epoch = 79
# │   step = 75
# └   loss = 24.283792f0
# ┌ Info: train
# │   epoch = 79
# │   step = 100
# └   loss = 24.86265f0
# ┌ Info: train
# │   epoch = 79
# │   step = 125
# └   loss = 25.039726f0
# ┌ Info: train
# │   epoch = 79
# │   step = 150
# └   loss = 22.208265f0
# ┌ Info: train
# │   epoch = 80
# │   step = 25
# └   loss = 29.437443f0
# ┌ Info: train
# │   epoch = 80
# │   step = 50
# └   loss = 26.15319f0
# ┌ Info: train
# │   epoch = 80
# │   step = 75
# └   loss = 25.790619f0
# ┌ Info: train
# │   epoch = 80
# │   step = 100
# └   loss = 24.035023f0
# ┌ Info: train
# │   epoch = 80
# │   step = 125
# └   loss = 23.27858f0
# ┌ Info: train
# │   epoch = 80
# │   step = 150
# └   loss = 25.90172f0
# ┌ Info: train
# │   epoch = 81
# │   step = 25
# └   loss = 25.833107f0
# ┌ Info: train
# │   epoch = 81
# │   step = 50
# └   loss = 27.40643f0
# ┌ Info: train
# │   epoch = 81
# │   step = 75
# └   loss = 21.92462f0
# ┌ Info: train
# │   epoch = 81
# │   step = 100
# └   loss = 26.017815f0
# ┌ Info: train
# │   epoch = 81
# │   step = 125
# └   loss = 25.769001f0
# ┌ Info: train
# │   epoch = 81
# │   step = 150
# └   loss = 21.803432f0
# ┌ Info: train
# │   epoch = 82
# │   step = 25
# └   loss = 22.338768f0
# ┌ Info: train
# │   epoch = 82
# │   step = 50
# └   loss = 25.840986f0
# ┌ Info: train
# │   epoch = 82
# │   step = 75
# └   loss = 24.032543f0
# ┌ Info: train
# │   epoch = 82
# │   step = 100
# └   loss = 22.793646f0
# ┌ Info: train
# │   epoch = 82
# │   step = 125
# └   loss = 25.137222f0
# ┌ Info: train
# │   epoch = 82
# │   step = 150
# └   loss = 25.951649f0
# ┌ Info: train
# │   epoch = 83
# │   step = 25
# └   loss = 24.809486f0
# ┌ Info: train
# │   epoch = 83
# │   step = 50
# └   loss = 26.11989f0
# ┌ Info: train
# │   epoch = 83
# │   step = 75
# └   loss = 25.108162f0
# ┌ Info: train
# │   epoch = 83
# │   step = 100
# └   loss = 25.218895f0
# ┌ Info: train
# │   epoch = 83
# │   step = 125
# └   loss = 26.576492f0
# ┌ Info: train
# │   epoch = 83
# │   step = 150
# └   loss = 21.534967f0
# ┌ Info: train
# │   epoch = 84
# │   step = 25
# └   loss = 22.878292f0
# ┌ Info: train
# │   epoch = 84
# │   step = 50
# └   loss = 24.561852f0
# ┌ Info: train
# │   epoch = 84
# │   step = 75
# └   loss = 21.066605f0
# ┌ Info: train
# │   epoch = 84
# │   step = 100
# └   loss = 27.652271f0
# ┌ Info: train
# │   epoch = 84
# │   step = 125
# └   loss = 27.827291f0
# ┌ Info: train
# │   epoch = 84
# │   step = 150
# └   loss = 22.628416f0
# ┌ Info: train
# │   epoch = 85
# │   step = 25
# └   loss = 23.40998f0
# ┌ Info: train
# │   epoch = 85
# │   step = 50
# └   loss = 23.966393f0
# ┌ Info: train
# │   epoch = 85
# │   step = 75
# └   loss = 21.59112f0
# ┌ Info: train
# │   epoch = 85
# │   step = 100
# └   loss = 25.124773f0
# ┌ Info: train
# │   epoch = 85
# │   step = 125
# └   loss = 20.860865f0
# ┌ Info: train
# │   epoch = 85
# │   step = 150
# └   loss = 20.764847f0
# ┌ Info: train
# │   epoch = 86
# │   step = 25
# └   loss = 24.170559f0
# ┌ Info: train
# │   epoch = 86
# │   step = 50
# └   loss = 21.344856f0
# ┌ Info: train
# │   epoch = 86
# │   step = 75
# └   loss = 25.094692f0
# ┌ Info: train
# │   epoch = 86
# │   step = 100
# └   loss = 24.650303f0
# ┌ Info: train
# │   epoch = 86
# │   step = 125
# └   loss = 26.443104f0
# ┌ Info: train
# │   epoch = 86
# │   step = 150
# └   loss = 26.755693f0
# ┌ Info: train
# │   epoch = 87
# │   step = 25
# └   loss = 25.28392f0
# ┌ Info: train
# │   epoch = 87
# │   step = 50
# └   loss = 22.591637f0
# ┌ Info: train
# │   epoch = 87
# │   step = 75
# └   loss = 24.558187f0
# ┌ Info: train
# │   epoch = 87
# │   step = 100
# └   loss = 23.37761f0
# ┌ Info: train
# │   epoch = 87
# │   step = 125
# └   loss = 22.453766f0
# ┌ Info: train
# │   epoch = 87
# │   step = 150
# └   loss = 23.134775f0
# ┌ Info: train
# │   epoch = 88
# │   step = 25
# └   loss = 22.580048f0
# ┌ Info: train
# │   epoch = 88
# │   step = 50
# └   loss = 23.17911f0
# ┌ Info: train
# │   epoch = 88
# │   step = 75
# └   loss = 24.458458f0
# ┌ Info: train
# │   epoch = 88
# │   step = 100
# └   loss = 22.700092f0
# ┌ Info: train
# │   epoch = 88
# │   step = 125
# └   loss = 28.836933f0
# ┌ Info: train
# │   epoch = 88
# │   step = 150
# └   loss = 25.738186f0
# ┌ Info: train
# │   epoch = 89
# │   step = 25
# └   loss = 24.815561f0
# ┌ Info: train
# │   epoch = 89
# │   step = 50
# └   loss = 22.215977f0
# ┌ Info: train
# │   epoch = 89
# │   step = 75
# └   loss = 22.129654f0
# ┌ Info: train
# │   epoch = 89
# │   step = 100
# └   loss = 24.794102f0
# ┌ Info: train
# │   epoch = 89
# │   step = 125
# └   loss = 24.125484f0
# ┌ Info: train
# │   epoch = 89
# │   step = 150
# └   loss = 21.227345f0
# ┌ Info: train
# │   epoch = 90
# │   step = 25
# └   loss = 22.045433f0
# ┌ Info: train
# │   epoch = 90
# │   step = 50
# └   loss = 23.293316f0
# ┌ Info: train
# │   epoch = 90
# │   step = 75
# └   loss = 24.518925f0
# ┌ Info: train
# │   epoch = 90
# │   step = 100
# └   loss = 25.422106f0
# ┌ Info: train
# │   epoch = 90
# │   step = 125
# └   loss = 25.499228f0
# ┌ Info: train
# │   epoch = 90
# │   step = 150
# └   loss = 22.184135f0
# ┌ Info: train
# │   epoch = 91
# │   step = 25
# └   loss = 24.26989f0
# ┌ Info: train
# │   epoch = 91
# │   step = 50
# └   loss = 23.96262f0
# ┌ Info: train
# │   epoch = 91
# │   step = 75
# └   loss = 23.837223f0
# ┌ Info: train
# │   epoch = 91
# │   step = 100
# └   loss = 23.046673f0
# ┌ Info: train
# │   epoch = 91
# │   step = 125
# └   loss = 24.653591f0
# ┌ Info: train
# │   epoch = 91
# │   step = 150
# └   loss = 22.075289f0
# ┌ Info: train
# │   epoch = 92
# │   step = 25
# └   loss = 24.342976f0
# ┌ Info: train
# │   epoch = 92
# │   step = 50
# └   loss = 23.946255f0
# ┌ Info: train
# │   epoch = 92
# │   step = 75
# └   loss = 23.191769f0
# ┌ Info: train
# │   epoch = 92
# │   step = 100
# └   loss = 26.609737f0
# ┌ Info: train
# │   epoch = 92
# │   step = 125
# └   loss = 17.93655f0
# ┌ Info: train
# │   epoch = 92
# │   step = 150
# └   loss = 21.087547f0
# ┌ Info: train
# │   epoch = 93
# │   step = 25
# └   loss = 24.67813f0
# ┌ Info: train
# │   epoch = 93
# │   step = 50
# └   loss = 19.700335f0
# ┌ Info: train
# │   epoch = 93
# │   step = 75
# └   loss = 26.010113f0
# ┌ Info: train
# │   epoch = 93
# │   step = 100
# └   loss = 25.786858f0
# ┌ Info: train
# │   epoch = 93
# │   step = 125
# └   loss = 25.679712f0
# ┌ Info: train
# │   epoch = 93
# │   step = 150
# └   loss = 22.27972f0
# ┌ Info: train
# │   epoch = 94
# │   step = 25
# └   loss = 24.283361f0
# ┌ Info: train
# │   epoch = 94
# │   step = 50
# └   loss = 26.018883f0
# ┌ Info: train
# │   epoch = 94
# │   step = 75
# └   loss = 26.054487f0
# ┌ Info: train
# │   epoch = 94
# │   step = 100
# └   loss = 18.607964f0
# ┌ Info: train
# │   epoch = 94
# │   step = 125
# └   loss = 24.42205f0
# ┌ Info: train
# │   epoch = 94
# │   step = 150
# └   loss = 25.083143f0
# ┌ Info: train
# │   epoch = 95
# │   step = 25
# └   loss = 22.265385f0
# ┌ Info: train
# │   epoch = 95
# │   step = 50
# └   loss = 25.279564f0
# ┌ Info: train
# │   epoch = 95
# │   step = 75
# └   loss = 23.667408f0
# ┌ Info: train
# │   epoch = 95
# │   step = 100
# └   loss = 21.51435f0
# ┌ Info: train
# │   epoch = 95
# │   step = 125
# └   loss = 23.896326f0
# ┌ Info: train
# │   epoch = 95
# │   step = 150
# └   loss = 23.182985f0
# ┌ Info: train
# │   epoch = 96
# │   step = 25
# └   loss = 22.115044f0
# ┌ Info: train
# │   epoch = 96
# │   step = 50
# └   loss = 25.596788f0
# ┌ Info: train
# │   epoch = 96
# │   step = 75
# └   loss = 23.342295f0
# ┌ Info: train
# │   epoch = 96
# │   step = 100
# └   loss = 23.938116f0
# ┌ Info: train
# │   epoch = 96
# │   step = 125
# └   loss = 21.91387f0
# ┌ Info: train
# │   epoch = 96
# │   step = 150
# └   loss = 25.638369f0
# ┌ Info: train
# │   epoch = 97
# │   step = 25
# └   loss = 24.230114f0
# ┌ Info: train
# │   epoch = 97
# │   step = 50
# └   loss = 24.580563f0
# ┌ Info: train
# │   epoch = 97
# │   step = 75
# └   loss = 25.14f0
# ┌ Info: train
# │   epoch = 97
# │   step = 100
# └   loss = 25.359524f0
# ┌ Info: train
# │   epoch = 97
# │   step = 125
# └   loss = 21.14893f0
# ┌ Info: train
# │   epoch = 97
# │   step = 150
# └   loss = 28.068623f0
# ┌ Info: train
# │   epoch = 98
# │   step = 25
# └   loss = 26.713148f0
# ┌ Info: train
# │   epoch = 98
# │   step = 50
# └   loss = 24.837017f0
# ┌ Info: train
# │   epoch = 98
# │   step = 75
# └   loss = 23.895924f0
# ┌ Info: train
# │   epoch = 98
# │   step = 100
# └   loss = 22.283958f0
# ┌ Info: train
# │   epoch = 98
# │   step = 125
# └   loss = 21.11446f0
# ┌ Info: train
# │   epoch = 98
# │   step = 150
# └   loss = 24.290411f0
# ┌ Info: train
# │   epoch = 99
# │   step = 25
# └   loss = 23.527283f0
# ┌ Info: train
# │   epoch = 99
# │   step = 50
# └   loss = 20.730885f0
# ┌ Info: train
# │   epoch = 99
# │   step = 75
# └   loss = 25.029686f0
# ┌ Info: train
# │   epoch = 99
# │   step = 100
# └   loss = 24.297504f0
# ┌ Info: train
# │   epoch = 99
# │   step = 125
# └   loss = 26.37918f0
# ┌ Info: train
# │   epoch = 99
# │   step = 150
# └   loss = 26.384432f0
# ┌ Info: train
# │   epoch = 100
# │   step = 25
# └   loss = 24.19099f0
# ┌ Info: train
# │   epoch = 100
# │   step = 50
# └   loss = 25.480999f0
# ┌ Info: train
# │   epoch = 100
# │   step = 75
# └   loss = 24.165169f0
# ┌ Info: train
# │   epoch = 100
# │   step = 100
# └   loss = 24.805332f0
# ┌ Info: train
# │   epoch = 100
# │   step = 125
# └   loss = 20.753227f0
# ┌ Info: train
# │   epoch = 100
# │   step = 150
# └   loss = 24.786406f0
# EditFlowModel(
#   Embedding(22 => 128),                 # 2_816 parameters
#   Chain(
#     RandomFourierFeatures{Float32, Matrix{Float32}}(Float32[7.531563 7.089197 … 2.0401998 3.328936]),
#     Dense(128 => 128),                  # 16_512 parameters
#   ),
#   [
#     TransformerBlock(
#       Attention(
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         identity,
#         identity,
#         Onion.var"#32#34"(),
#         16,
#         16,
#         8,
#         8,
#       ),
#       StarGLU(
#         Dense(128 => 512; bias=false),  # 65_536 parameters
#         Dense(512 => 128; bias=false),  # 65_536 parameters
#         Dense(128 => 512; bias=false),  # 65_536 parameters
#         NNlib.swish,
#       ),
#       AdaLN(
#         Onion.LayerNorm{Vector{Float32}, Vector{Float32}, Float32}(Float32[0.9836579, 0.9530255, 0.9908016, 0.96244663, 0.99054164, 0.98432475, 0.9993702, 0.97146636, 0.9746882, 0.97592133  …  0.96757305, 0.98850816, 0.9889486, 0.9910423, 0.9700498, 0.9524227, 0.9703022, 0.9919154, 0.9982276, 0.98223925], Float32[-0.0059723244, -0.026827456, -0.005359013, 0.005184757, -0.015056814, 0.0036728473, -0.00411119, 0.014544279, -0.013788157, -0.0062612076  …  -0.008408193, 0.007813087, 0.0057916404, -0.002667083, -0.0019434843, 0.0012296549, 0.0013133418, 0.0023761056, 0.00048080317, 0.006975226], 1.0f-6),  # 256 parameters
#         Dense(128 => 128),              # 16_512 parameters
#         Dense(128 => 128),              # 16_512 parameters
#       ),
#       AdaLN(
#         Onion.LayerNorm{Vector{Float32}, Vector{Float32}, Float32}(Float32[0.9946981, 0.9968043, 0.98153776, 0.9809628, 0.99675304, 0.93618464, 0.9842954, 0.9745212, 1.0101839, 1.0036527  …  1.0099263, 0.99696696, 0.9861587, 0.9825586, 0.9812812, 0.97964483, 0.98476547, 0.98760384, 0.9870029, 0.979692], Float32[0.006245078, 0.00454478, -0.015628312, 0.006516256, -0.009261778, -0.01909565, 0.005845533, 0.008189242, -0.00068665465, 0.0016260961  …  -0.0041808817, -0.00029761743, 0.0026925767, -0.007287982, -0.01596789, 0.00494587, -0.00235075, -0.0046186335, 0.0087447725, -0.0045568403], 1.0f-6),  # 256 parameters
#         Dense(128 => 128),              # 16_512 parameters
#         Dense(128 => 128),              # 16_512 parameters
#       ),
#       identity,
#     ),
#     TransformerBlock(
#       Attention(
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         identity,
#         identity,
#         Onion.var"#32#34"(),
#         16,
#         16,
#         8,
#         8,
#       ),
#       StarGLU(
#         Dense(128 => 512; bias=false),  # 65_536 parameters
#         Dense(512 => 128; bias=false),  # 65_536 parameters
#         Dense(128 => 512; bias=false),  # 65_536 parameters
#         NNlib.swish,
#       ),
#       AdaLN(
#         Onion.LayerNorm{Vector{Float32}, Vector{Float32}, Float32}(Float32[0.97298455, 0.9863549, 0.9892886, 0.9950389, 0.9884353, 0.9859241, 0.94629824, 0.9905537, 0.997098, 0.9910578  …  0.98902434, 0.9732674, 0.993341, 0.98686963, 0.97267485, 0.9891902, 0.9939604, 0.98106074, 0.989807, 0.9971157], Float32[0.0012234193, 0.0013402402, -0.0051020766, -0.0023925323, 0.0024530701, -0.007705464, 0.027468415, -0.0025647462, -0.0012954248, -0.0012756804  …  -0.0062676566, -0.004466568, -0.005843617, -0.0037935532, -0.0069217044, -0.0014938526, 0.0044353334, -0.0068317032, -0.001554352, -0.006626264], 1.0f-6),  # 256 parameters
#         Dense(128 => 128),              # 16_512 parameters
#         Dense(128 => 128),              # 16_512 parameters
#       ),
#       AdaLN(
#         Onion.LayerNorm{Vector{Float32}, Vector{Float32}, Float32}(Float32[0.98990935, 0.9927325, 0.99345046, 0.9694228, 1.0037662, 0.98568547, 0.99712723, 0.9872776, 1.0082906, 1.0044862  …  0.99839866, 1.0037067, 0.99369234, 0.99665964, 0.9925385, 0.958198, 0.97938985, 0.99434316, 1.0101033, 0.9903174], Float32[0.0046547917, -0.019893773, -0.009588573, 0.0028432165, 0.0047589364, -0.0028043785, 0.00833395, 0.009257588, 0.0071648816, 0.006460758  …  -0.0042559416, -0.0088890875, -0.0017841165, -0.0037446455, -0.0112923, -0.05279327, 0.018110534, -0.0060070534, 0.005424199, -0.009653852], 1.0f-6),  # 256 parameters
#         Dense(128 => 128),              # 16_512 parameters
#         Dense(128 => 128),              # 16_512 parameters
#       ),
#       identity,
#     ),
#     TransformerBlock(
#       Attention(
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         identity,
#         identity,
#         Onion.var"#32#34"(),
#         16,
#         16,
#         8,
#         8,
#       ),
#       StarGLU(
#         Dense(128 => 512; bias=false),  # 65_536 parameters
#         Dense(512 => 128; bias=false),  # 65_536 parameters
#         Dense(128 => 512; bias=false),  # 65_536 parameters
#         NNlib.swish,
#       ),
#       AdaLN(
#         Onion.LayerNorm{Vector{Float32}, Vector{Float32}, Float32}(Float32[0.9813191, 0.97900933, 0.99497646, 0.9740931, 0.99270153, 0.9512806, 0.98416686, 0.98227394, 0.99777186, 0.9847334  …  0.97772944, 0.99356306, 0.99567527, 0.9884459, 0.99413466, 0.9872411, 0.9937668, 0.9934419, 0.9858429, 1.0006208], Float32[-0.008844349, -0.003362618, 0.007866318, 0.007047815, -0.0043394393, -0.011138873, 0.011454338, 0.0073125726, -0.0019595535, -0.005712127  …  0.0042020027, 0.012437841, 0.008444573, -0.010965995, 0.0033074883, 0.0013927073, -0.0025926381, 0.004861451, 0.0003271947, 0.0013459908], 1.0f-6),  # 256 parameters
#         Dense(128 => 128),              # 16_512 parameters
#         Dense(128 => 128),              # 16_512 parameters
#       ),
#       AdaLN(
#         Onion.LayerNorm{Vector{Float32}, Vector{Float32}, Float32}(Float32[0.99184936, 1.0132029, 0.9949654, 0.99911726, 0.9930749, 1.004498, 1.0130638, 1.0191455, 1.0075065, 0.97904897  …  1.0130671, 1.0166669, 1.0298382, 1.0103947, 0.99601674, 0.97281563, 0.99154127, 1.0031415, 1.0141926, 0.9984006], Float32[0.0064145937, -0.012695074, -0.024113664, 0.0008978927, 0.008383268, -0.0046254005, 0.0058898213, -0.00048160343, 0.011751346, -0.001727852  …  -0.011738534, -0.008813223, -0.0048925155, -0.002928767, -0.007028266, -0.028897885, 0.016255967, -0.008061163, -0.0006376766, -0.011933948], 1.0f-6),  # 256 parameters
#         Dense(128 => 128),              # 16_512 parameters
#         Dense(128 => 128),              # 16_512 parameters
#       ),
#       identity,
#     ),
#     TransformerBlock(
#       Attention(
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         Dense(128 => 128; bias=false),  # 16_384 parameters
#         identity,
#         identity,
#         Onion.var"#32#34"(),
#         16,
#         16,
#         8,
#         8,
#       ),
#       StarGLU(
#         Dense(128 => 512; bias=false),  # 65_536 parameters
#         Dense(512 => 128; bias=false),  # 65_536 parameters
#         Dense(128 => 512; bias=false),  # 65_536 parameters
#         NNlib.swish,
#       ),
#       AdaLN(
#         Onion.LayerNorm{Vector{Float32}, Vector{Float32}, Float32}(Float32[0.9871817, 0.97967505, 0.9925497, 0.9899778, 0.9875628, 1.0040362, 0.9646963, 0.98949474, 0.98805684, 0.9880806  …  1.0172434, 0.9862294, 1.0149201, 0.94580567, 1.0022846, 0.98350805, 0.99963933, 0.9940302, 1.0096109, 0.97280717], Float32[0.002797166, -0.00076662557, 0.00028469562, -0.0044771708, -0.0028138815, 0.003455172, 0.0049372525, 0.005800529, 0.0032799544, 0.0068818713  …  0.02613455, 0.006609633, 0.0013952806, 0.011928056, -0.008288531, -0.016250463, 0.006419934, -0.0055078357, -0.01332255, -0.016116258], 1.0f-6),  # 256 parameters
#         Dense(128 => 128),              # 16_512 parameters
#         Dense(128 => 128),              # 16_512 parameters
#       ),
#       AdaLN(
#         Onion.LayerNorm{Vector{Float32}, Vector{Float32}, Float32}(Float32[1.0026083, 0.9906121, 1.0252106, 0.9807042, 1.0165613, 0.9926678, 1.0275302, 1.0164462, 1.0170248, 1.0145394  …  1.0104992, 1.0050902, 1.0078901, 1.0107113, 1.0065619, 0.99085945, 0.99034745, 1.0093502, 1.0229908, 0.9981014], Float32[0.00017921702, -0.014748752, 0.0016491384, 0.0112701375, 0.008428353, 0.0039549926, 0.016354358, -0.0023426865, 0.0004367487, 0.0045339833  …  0.0015938681, 0.0045206565, -0.00032513068, 0.0024292, 0.005038348, -0.020209014, -0.0013112819, 0.0021825603, -0.00091132557, 0.0007438597], 1.0f-6),  # 256 parameters
#         Dense(128 => 128),              # 16_512 parameters
#         Dense(128 => 128),              # 16_512 parameters
#       ),
#       identity,
#     ),
#   ],
#   Dense(128 => 20; bias=false),         # 2_560 parameters
#   Dense(128 => 20; bias=false),         # 2_560 parameters
#   Dense(128 => 1; bias=false),          # 128 parameters
#   Dense(128 => 1; bias=false),          # 128 parameters
#   Dense(128 => 1; bias=false),          # 128 parameters
#   RoPE{Matrix{Float32}}(Float32[1.0 0.5403023 … -0.87528455 -0.065975994; 1.0 0.95041525 … 0.9552474 0.8159282; … ; 1.0 0.9999995 … -0.57972294 -0.5789079; 1.0 0.99999994 … 0.2726629 0.27235872], Float32[0.0 0.84147096 … -0.48360822 -0.9978212; 0.0 0.3109836 … 0.29580808 0.5781532; … ; 0.0 0.0009999999 … -0.8148137 -0.8153929; 0.0 0.0003162278 … 0.9621096 0.9621958]),
#   20,
# )         # Total: 84 trainable arrays, 1_339_648 parameters,
#           # plus 3 non-trainable, 65_600 parameters, summarysize 5.365 MiB.

# %%
rng=Random.MersenneTwister(42)
# Out:
# MersenneTwister(42)

# %%
model_samples_any = sample_gen_n(P, model; n=10, ts=0f0:0.01f0:1f0, rng)
model_final_states = map(final_state_from_gen, model_samples_any)
model_strings = [state_to_PM_string(P, s) for s in model_final_states]
# Out:
# 10-element Vector{String}:
#  "QVQLVQSGAEVKKPGA"
#  "QVLVQSGAGAVKKPRASVKV"
#  "QVQLVKSGEVLVKP"
#  "EVQLMESGGPYKP"
#  "QVQLVQSGAEVKKPGASVKV"
#  "QVQLVQSGTMVKKPGASS"
#  "QVQVVESGGGAVVQPGA"
#  "QVQLVQSGAEVEKPGA"
#  "QVQLVESGGGVVSQLGS"
#  "QVQWYQYGGPVKK"

# %%
train_states = [FF.DiscreteState(P.k, sample(PM; rng=rng)) for i in 1:10]
train_strings = [state_to_PM_string(P, s) for s in train_states]
# Out:
# 10-element Vector{String}:
#  "EVQLVESGGGLVKPPGQLR"
#  "QVQLVQSKAEVKKPGASVKV"
#  "EGQRVECGGGGGQRG"
#  "EVQLVESGGGLV"
#  "QVQLVQSGAAV"
#  "EVQLVESGGGLVQPGGSLTL"
#  "QVQLVESGGGVVQPCR"
#  "QVLLVQSGTEVFKPGASMKV"
#  "QVLLVQSTAEVKK"
#  "QITLKESDPTLVKP"

# %%
# Sampling and Levenshtein plot
using Random
n = 1000
# 100 model samples (final states → strings)
model_samples_any = sample_gen_n(P, model; n=n, ts=0f0:0.01f0:1f0, rng=rng)
model_final_states = map(final_state_from_gen, model_samples_any)
model_strings = [state_to_PM_string(P, s) for s in model_final_states]
# Out:
# 1000-element Vector{String}:
#  "QVQLVESGGRV"
#  "QLQLGQSGAVV"
#  "QVQLVESGGGVVQPGR"
#  "QITLKESYPTLVKPS"
#  "EVQLVLESGGLVQPGASLRL"
#  "EEQLVESGGGVVQPG"
#  "QVQLVQSGAEVK"
#  "QVQLVQSGGEPGCVGTLRL"
#  "QQLTQKYGTAVKEGASVHV"
#  "QVQLVLSSAEVKKP"
#  "QLQLQESGPGLVKP"
#  "EVQLVESGGYLVQPGG"
#  "QLQLQESGPGVVQPGRSL"
#  ⋮
#  "QVQLVQSGAEVK"
#  "QVQLVESGGGVKPGR"
#  "EVHLVESGGGLVKPGGS"
#  "Q"
#  "QVQLVQYGANVVKPGASVKV"
#  "QVLLVQSGAEVKKYGTSVHV"
#  "QVQLVESSQGHVMQQPGR"
#  "QVQRAQAGAESKKPGTSVKV"
#  "QIQIKETGPGLFK"
#  "QVQLQKSGPGLVK"
#  "QVVQLQQPGAYVK"
#  "MVLVQSGAEV"

# %%
m = 100
p=100000
# Build training strings from PM parents (the data PM was built on)
train_states = [FF.DiscreteState(P.k, sample(PM; rng=rng)) for i in 1:m]
train_strings = [state_to_PM_string(P, s) for s in train_states]

# Independent validation strings sampled from PM
val_states = [FF.DiscreteState(P.k, sample(PM; rng=rng)) for i in 1:p]
val_strings = [state_to_PM_string(P, s) for s in val_states]
#val_strings = [s for s in val_strings if !(s in train_strings)]

# Plot normalized Levenshtein vs. training set (distinct val/train)
plt = plot_lev_dist("model_vs_true", val_strings, model_strings, train_strings; title="Model vs True (normalized Levenshtein)")
display(plt)
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:00

# %%
model_strings_bos = [">" * state_to_PM_string(P, s) for s in model_final_states]
plt = plot_lev_dist("model_vs_true", val_strings, model_strings_bos, train_strings; title="Model vs True (normalized Levenshtein)")
display(plt)

# %%
n=1000000
val_states = [FF.DiscreteState(P.k, sample(PM; rng)) for i in 1:n]
val_strings = [state_to_PM_string(P, s) for s in val_states]



pLen = plot_len_dist("model_vs_true_len", val_strings, model_strings; title="Length distribution: Natural vs Generated")
display(pLen)

pAA = plot_AA_dist("model_vs_true_AA", val_strings, model_strings; title="AA frequency: Natural vs Generated")
display(pAA)

# %%
println("Natural 'A' frequency: ", (isdefined(Main, :val_strings) ? sum(count(==('A'), s) for s in val_strings) / sum(length.(val_strings)) : sum(count(==('A'), s) for s in val_strings) / sum(length.(val_strings))))
# Out:
# Natural 'A' frequency: 0.047142480905978404

# %%
println("Natural 'A' frequency: ", (isdefined(Main, :model_strings) ? sum(count(==('A'), s) for s in model_strings) / sum(length.(model_strings)) : sum(count(==('A'), s) for s in model_strings) / sum(length.(model_strings))))
# Out:
# Natural 'A' frequency: 0.04109772423025435

# %%
rng = Random.MersenneTwister(42)
# Out:
# MersenneTwister(42)

# %%
n=1000000
val_states = [FF.DiscreteState(P.k, sample(PM; rng)) for i in 1:n]
val_strings = [state_to_PM_string(P, s) for s in val_states]
pLen = plot_len_dist("model_vs_true_len", val_strings, val_strings; title="Length distribution: Natural vs Generated")
